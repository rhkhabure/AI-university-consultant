# %% [markdown]
# # AI CONSULTANT 2.0

# %%
# So i wann connect to the knowledge base
import sqlite3
conn = sqlite3.connect("faculty_evaluation.db")
cursor = conn.cursor()

# then i just wanna confirm that its the right db that ive connected to
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print(cursor.fetchall())
# Out:
# [('sqlite_sequence',), ('Deans',), ('Faculty',), ('Courses',), ('Sections',), ('TeachingAssignments',), ('Evaluations',), ('FeedbackCorpus',)]

# %%
# then let me verify the schema of the FeedbackCorpus table
cursor.execute("PRAGMA table_info(FeedbackCorpus)")
print(cursor.fetchall())
# Out:
# [(0, 'feedback_id', 'INTEGER', 0, None, 1), (1, 'faculty_id', 'INTEGER', 0, None, 0), (2, 'instructor', 'TEXT', 0, None, 0), (3, 'course_code', 'TEXT', 0, None, 0), (4, 'section_code', 'TEXT', 0, None, 0), (5, 'semester', 'TEXT', 0, None, 0), (6, 'comment_type', 'TEXT', 0, None, 0), (7, 'comment_text', 'TEXT', 0, None, 0)]

# %% [markdown]
# Ayt im connected to the right db. Lets now move forward

# %%
# Just gotta perform a quick test
import sqlite3
conn = sqlite3.connect("faculty_evaluation.db")
cursor = conn.cursor()

# Preview Faculty table
cursor.execute("SELECT * FROM Faculty LIMIT 5")
print(cursor.fetchall())
# Out:
# [(600716, 'Mohamed, Mwanashehe S.', 'MS', 'Master of Business Admin', 'Y', 2, 75), (620040, 'Owuor, John David_Ouma', 'MR', 'Master of Business Admin', 'Y', 3, 132), (620489, 'Gitahi, Jesse Elikanah_Machirah', 'MR', 'Master of Business Admin', 'Y', 4, 123), (657923, 'Odoyo, Fredrick', 'DR', 'Doctor of Business Admin', 'N', 1, 38), (611121, 'Gatumo, Francis Mambo', 'MR', 'Master of Business Admin', 'N', 4, 94)]

# %% [markdown]
# ok thats good lets move forward

# %%
import sqlite3

# Connect to the correct DB
conn = sqlite3.connect("faculty_evaluation.db")
cursor = conn.cursor()

# Quick sanity check
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print("Tables:", cursor.fetchall())
# Out:
# Tables: [('sqlite_sequence',), ('Deans',), ('Faculty',), ('Courses',), ('Sections',), ('TeachingAssignments',), ('Evaluations',), ('FeedbackCorpus',)]

# %% [markdown]
# thats good we got all tables present

# %%
cursor.execute("PRAGMA table_info(Evaluations)")
print(cursor.fetchall())
# Out:
# [(0, 'faculty_id', 'INTEGER', 0, None, 0), (1, 'full_name', 'TEXT', 0, None, 0), (2, 'course_code', 'TEXT', 0, None, 0), (3, 'section_code', 'TEXT', 0, None, 0), (4, 'total_students', 'INTEGER', 0, None, 0), (5, 'total_respondents', 'INTEGER', 0, None, 0), (6, 'response_rate', 'REAL', 0, None, 0), (7, 'mean_score', 'REAL', 0, None, 0), (8, 'percent_score', 'REAL', 0, None, 0), (9, 'letter_grade', 'TEXT', 0, None, 0), (10, 'section_id', 'TEXT', 0, None, 0)]

# %%
cursor.execute("PRAGMA table_info(Faculty)")
print(cursor.fetchall())
# Out:
# [(0, 'faculty_id', 'INTEGER', 0, None, 0), (1, 'full_name', 'TEXT', 0, None, 0), (2, 'title', 'TEXT', 0, None, 0), (3, 'highest_degree', 'TEXT', 0, None, 0), (4, 'adjunct_flag', 'TEXT', 0, None, 0), (5, 'total_classes_taught', 'INTEGER', 0, None, 0), (6, 'total_students_taught', 'INTEGER', 0, None, 0)]

# %%
import re

def extract_name(user_input):
    # crude heuristic: take last word if it's capitalized or looks like a surname
    tokens = user_input.replace("?", "").split()
    # look for capitalized tokens
    candidates = [t.strip(",.") for t in tokens if t[0].isupper()]
    if candidates:
        return candidates[-1]  # last capitalized token
    return user_input  # fallback

def get_instructor_evaluation(user_input):
    name = extract_name(user_input)

    query = """
    SELECT f.full_name, e.mean_score, e.letter_grade
    FROM Faculty f
    JOIN TeachingAssignments ta ON f.faculty_id = ta.faculty_id
    JOIN Sections s ON ta.section_id = s.section_id
    JOIN Evaluations e ON s.section_id = e.section_id
    WHERE f.full_name LIKE ?
    """
    cursor.execute(query, (f"%{name}%",))
    rows = cursor.fetchall()

    if rows:
        return "\n".join(
            f"Based on evaluations, {full_name} received a grade of {grade} with a mean score of {score:.2f}."
            for full_name, score, grade in rows
        )
    return f"No evaluation data found for {name}."

# %%
def get_top_performers(n=5):
    query = """
    SELECT f.full_name, AVG(e.mean_score) as avg_score, e.letter_grade
    FROM Faculty f
    JOIN TeachingAssignments ta ON f.faculty_id = ta.faculty_id
    JOIN Sections s ON ta.section_id = s.section_id
    JOIN Evaluations e ON s.section_id = e.section_id
    GROUP BY f.full_name
    ORDER BY avg_score DESC
    LIMIT ?
    """
    cursor.execute(query, (n,))
    rows = cursor.fetchall()

    if rows:
        response = [f"Top {n} performers:"]
        for full_name, score, grade in rows:
            response.append(f"- {full_name}: {score:.2f} ({grade})")
        return "\n".join(response)
    return f"No data available for top {n} performers."

# %%
def get_instructors_above_score(threshold):
    query = """
    SELECT f.full_name, AVG(e.mean_score) as avg_score, e.letter_grade
    FROM Faculty f
    JOIN TeachingAssignments ta ON f.faculty_id = ta.faculty_id
    JOIN Sections s ON ta.section_id = s.section_id
    JOIN Evaluations e ON s.section_id = e.section_id
    GROUP BY f.full_name
    HAVING avg_score > ?
    ORDER BY avg_score DESC
    """
    cursor.execute(query, (threshold,))
    rows = cursor.fetchall()

    if rows:
        response = [f"Instructors with scores above {threshold}:"]
        for full_name, score, grade in rows:
            response.append(f"- {full_name}: {score:.2f} ({grade})")
        return "\n".join(response)
    return f"No instructors scored above {threshold}."

# %%
def get_instructors_by_grade(grade):
    query = """
    SELECT f.full_name, AVG(e.mean_score) as avg_score
    FROM Faculty f
    JOIN TeachingAssignments ta ON f.faculty_id = ta.faculty_id
    JOIN Sections s ON ta.section_id = s.section_id
    JOIN Evaluations e ON s.section_id = e.section_id
    WHERE e.letter_grade = ?
    GROUP BY f.full_name
    ORDER BY avg_score DESC
    """
    cursor.execute(query, (grade,))
    rows = cursor.fetchall()

    if rows:
        response = [f"Instructors with grade {grade}:"]
        for full_name, score in rows:
            response.append(f"- {full_name}: {score:.2f}")
        return "\n".join(response)
    return f"No instructors found with grade {grade}."

# %%
# then an intent parser
import re

def parse_intent(user_input):
    text = user_input.lower()

    if "top" in text and re.search(r"\d+", text):
        count = int(re.search(r"\d+", text).group())
        return {"intent": "top_ranked", "count": count}

    if "score" in text and "above" in text:
        threshold = float(re.search(r"\d+(\.\d+)?", text).group())
        return {"intent": "score_filter", "threshold": threshold}

    if "grade" in text or "got an" in text:
        grade = re.search(r"[abc]", text).group().upper()
        return {"intent": "grade_filter", "grade": grade}

    if "how did" in text or "tell me about" in text or "evaluation for" in text:
        return {"intent": "lookup", "name": user_input}

    return {"intent": "unknown"}

# %%
# a response engine is next
def get_consultant_response(user_query):
    intent = parse_intent(user_query)

    if intent["intent"] == "top_ranked":
        return get_top_performers(intent["count"])

    elif intent["intent"] == "score_filter":
        return get_instructors_above_score(intent["threshold"])

    elif intent["intent"] == "grade_filter":
        return get_instructors_by_grade(intent["grade"])

    elif intent["intent"] == "lookup":
        return get_instructor_evaluation(intent["name"])

    return "I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers."

# %%
# then we finally test each one
print(get_consultant_response("How did Afundi perform this semester?"))
print(get_consultant_response("Who scored above 4.5?"))
print(get_consultant_response("Top 5 performers"))
print(get_consultant_response("Which instructors got an A?"))
# Out:
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.04.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.15.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of A- with a mean score of 4.35.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.12.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B+ with a mean score of 4.18.
# Instructors with scores above 4.5:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
# - Achoki, George: 4.54 (A-)
# - Koshal, Jeremiah Ntaloi_Ole: 4.54 (A)
# - Kabongah, George Odhiambo: 4.54 (A)
# - Brown, Dana Basnight: 4.53 (A)
# - Were, Jamen H.: 4.53 (A)
# - Ali, Fatuma Ahmed: 4.53 (A-)
# - Kimotho, Stephen Gichuhi: 4.53 (A)
# - Namuye, Maria: 4.52 (A)
# - Ndungu, Francis Gitonga: 4.51 (A)
# - Nakamura, Katsuji: 4.51 (A-)
# - F   Iraki, Fredrick Kang'ethe: 4.51 (A)
# Top 5 performers:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
# Instructors with grade C:
# - Githua, Oscar Wanyutu: 3.65
# - Kamuri, Simon: 3.64
# - Namuye, Silvester: 3.62
# - Machoka, Philip Gichaba: 3.62
# - Arasa, Josephine: 3.62
# - Nyarigoti, Naom Moraa: 3.60
# - Gitau, Samuel: 3.57
# - Njenga, Edward Gachangi: 3.55

# %% [markdown]
# bet so thats good. Let me add in fuzzy matching so that it can recongize ppl buy their names

# %%
# Well be using rapid fuzz
from rapidfuzz import fuzz

def lookup_instructor_evaluation(user_input, threshold=70):
    # Normalize input
    q = user_input.lower()

    # Get all faculty names
    cursor.execute("SELECT faculty_id, full_name FROM Faculty")
    faculty_rows = cursor.fetchall()

    best = None
    best_score = -1

    for fid, name in faculty_rows:
        sim = max(fuzz.partial_ratio(q, name.lower()), fuzz.token_set_ratio(q, name.lower()))
        if sim > best_score:
            best_score = sim
            best = (fid, name)

    if best and best_score >= threshold:
        fid, full_name = best

        # Now join to evaluations
        query = """
        SELECT AVG(e.mean_score), e.letter_grade
        FROM TeachingAssignments ta
        JOIN Sections s ON ta.section_id = s.section_id
        JOIN Evaluations e ON s.section_id = e.section_id
        WHERE ta.faculty_id = ?
        """
        cursor.execute(query, (fid,))
        row = cursor.fetchone()

        if row and row[0]:
            score, grade = row
            return f"Based on evaluations, {full_name} received a grade of {grade} with a mean score of {score:.2f}."

    return f"No evaluation data found for {user_input}."

# %%
def get_feedback_summary(fid, limit=3):
    try:
        query = """
        SELECT comment_text
        FROM FeedbackCorpus
        WHERE faculty_id = ?
        LIMIT ?
        """
        cursor.execute(query, (fid, limit))
        rows = cursor.fetchall()
        if rows:
            return "Sample feedback:\n" + "\n".join(f"- {r[0]}" for r in rows)
        return "No qualitative feedback available."
    except sqlite3.OperationalError as e:
        return f"Database error: {e}"

# %%
from rapidfuzz import fuzz

DEBUG = True

def log(*args):
    if DEBUG:
        print("[DEBUG]", *args)

def lookup_instructor_evaluation(user_input, threshold=70):
    q = user_input.lower()
    cursor.execute("SELECT faculty_id, full_name FROM Faculty")
    faculty_rows = cursor.fetchall()

    best = None
    best_score = -1

    for fid, name in faculty_rows:
        sim = max(fuzz.partial_ratio(q, name.lower()), fuzz.token_set_ratio(q, name.lower()))
        log("Comparing:", q, "vs", name, "-> similarity:", sim)
        if sim > best_score:
            best_score = sim
            best = (fid, name)

    if best and best_score >= threshold:
        fid, full_name = best
        log("Best match:", full_name, "with score:", best_score)

        # Numeric evaluation
        query = """
        SELECT AVG(e.mean_score), e.letter_grade
        FROM TeachingAssignments ta
        JOIN Sections s ON ta.section_id = s.section_id
        JOIN Evaluations e ON s.section_id = e.section_id
        WHERE ta.faculty_id = ?
        """
        cursor.execute(query, (fid,))
        row = cursor.fetchone()

        if row and row[0]:
            score, grade = row
            response = f"Based on evaluations, {full_name} received a grade of {grade} with a mean score of {score:.2f}."

            # Add feedback
            feedback = get_feedback_summary(fid)
            return response + "\n" + feedback

    return f"No evaluation data found for {user_input}."

# %% [markdown]
# # Stress testing

# %%
# Stress test queries
test_queries = [
    "Tell me about Afundi",
    "What’s the evaluation for Mohamed, Mwanashehe S.?",
    "How did Gitahi perform?",
    "Results for Odoyo",
    "Evaluation of Gatumo, Francis Mambo",
    "Who scored above 4.8?",
    "List instructors with scores below 3.5",
    "Which instructors scored exactly 4.0?",
    "Which instructors got an A?",
    "Show me all with grade B",
    "Who received a C?",
    "Top 10 performers",
    "Top 3 instructors this semester",
    "Top 20 performers",
    "What feedback did students give Afundi?",
    "Summarize feedback for Mohamed",
    "Show sample feedback for Odoyo",
    "How did Alo perform?",   # typo test
    "Tell me about Basweti",  # partial match
    "Evaluation for a nonexistent instructor"
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: Tell me about Afundi
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.04.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.15.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of A- with a mean score of 4.35.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.12.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B+ with a mean score of 4.18.
#
# Query: What’s the evaluation for Mohamed, Mwanashehe S.?
# Based on evaluations, Mohamed, Mwanashehe S. received a grade of B+ with a mean score of 4.28.
# Based on evaluations, Mohamed, Mwanashehe S. received a grade of B with a mean score of 4.17.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of B with a mean score of 4.04.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of A- with a mean score of 4.43.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of A with a mean score of 4.49.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of B with a mean score of 4.17.
# Based on evaluations, Gatumo, Francis Mambo received a grade of A- with a mean score of 4.41.
# Based on evaluations, Gatumo, Francis Mambo received a grade of A- with a mean score of 4.36.
# Based on evaluations, Gatumo, Francis Mambo received a grade of A with a mean score of 4.53.
# Based on evaluations, Gatumo, Francis Mambo received a grade of A- with a mean score of 4.45.
# Based on evaluations, Ogada, Agnes Owuor received a grade of A- with a mean score of 4.34.
# Based on evaluations, Ogada, Agnes Owuor received a grade of A with a mean score of 4.52.
# Based on evaluations, Ogada, Agnes Owuor received a grade of B- with a mean score of 3.93.
# Based on evaluations, Ogada, Agnes Owuor received a grade of C- with a mean score of 3.33.
# Based on evaluations, Njuguna, Amos Gitau received a grade of B with a mean score of 4.15.
# Based on evaluations, Njuguna, Amos Gitau received a grade of A- with a mean score of 4.40.
# Based on evaluations, Njuguna, Amos Gitau received a grade of A- with a mean score of 4.43.
# Based on evaluations, Njuguna, Amos Gitau received a grade of A with a mean score of 4.52.
# Based on evaluations, Namuye, Silvester received a grade of C with a mean score of 3.62.
# Based on evaluations, Namuye, Silvester received a grade of B- with a mean score of 3.97.
# Based on evaluations, Namuye, Silvester received a grade of B- with a mean score of 3.97.
# Based on evaluations, Ndiege, Joshua Rumo received a grade of B+ with a mean score of 4.24.
# Based on evaluations, Ndiege, Joshua Rumo received a grade of B with a mean score of 4.08.
# Based on evaluations, Ndiege, Joshua Rumo received a grade of B+ with a mean score of 4.23.
# Based on evaluations, Basweti, Kevin Ogachi received a grade of C+ with a mean score of 3.77.
# Based on evaluations, Basweti, Kevin Ogachi received a grade of C+ with a mean score of 3.82.
# Based on evaluations, Basweti, Kevin Ogachi received a grade of B with a mean score of 4.03.
# Based on evaluations, Aloo, Linus Alwal received a grade of A- with a mean score of 4.45.
# Based on evaluations, Aloo, Linus Alwal received a grade of A- with a mean score of 4.34.
# Based on evaluations, Aloo, Linus Alwal received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Makhaso, Byron Chesoli received a grade of B+ with a mean score of 4.21.
# Based on evaluations, Makhaso, Byron Chesoli received a grade of B with a mean score of 3.98.
# Based on evaluations, Gachanga, Esther Wanjiru received a grade of B+ with a mean score of 4.18.
# Based on evaluations, Gachanga, Esther Wanjiru received a grade of A- with a mean score of 4.39.
# Based on evaluations, Gachanga, Esther Wanjiru received a grade of B with a mean score of 4.03.
# Based on evaluations, Mwalili, Tobias Mbithi received a grade of B with a mean score of 4.07.
# Based on evaluations, Mwalili, Tobias Mbithi received a grade of B with a mean score of 4.17.
# Based on evaluations, Ondiek, Collins Oduor received a grade of A- with a mean score of 4.41.
# Based on evaluations, Ondiek, Collins Oduor received a grade of A with a mean score of 4.55.
# Based on evaluations, Ondiek, Collins Oduor received a grade of B with a mean score of 4.17.
# Based on evaluations, Ondiek, Collins Oduor received a grade of A- with a mean score of 4.38.
# Based on evaluations, Ondiek, Collins Oduor received a grade of A- with a mean score of 4.36.
# Based on evaluations, Githinji, Stanley Muturi,, Dr. received a grade of A- with a mean score of 4.33.
# Based on evaluations, Githinji, Stanley Muturi,, Dr. received a grade of B+ with a mean score of 4.25.
# Based on evaluations, Githinji, Stanley Muturi,, Dr. received a grade of A with a mean score of 4.48.
# Based on evaluations, Kayeyia, Ernest Madara received a grade of A- with a mean score of 4.33.
# Based on evaluations, Okanya, Patrick Wafula_Simiyu received a grade of B+ with a mean score of 4.23.
# Based on evaluations, Kamuri, Simon received a grade of B with a mean score of 4.12.
# Based on evaluations, Kamuri, Simon received a grade of C with a mean score of 3.64.
# Based on evaluations, Gitoho, Salome Wanjiru received a grade of B with a mean score of 4.16.
# Based on evaluations, Gitoho, Salome Wanjiru received a grade of B+ with a mean score of 4.31.
# Based on evaluations, Kimathi, George Eliphas received a grade of B+ with a mean score of 4.21.
# Based on evaluations, Kimathi, George Eliphas received a grade of B+ with a mean score of 4.24.
# Based on evaluations, Kimathi, George Eliphas received a grade of B+ with a mean score of 4.32.
# Based on evaluations, Misawo, Florence Awuor received a grade of A- with a mean score of 4.40.
# Based on evaluations, Misawo, Florence Awuor received a grade of B+ with a mean score of 4.23.
# Based on evaluations, Misawo, Florence Awuor received a grade of A- with a mean score of 4.40.
# Based on evaluations, Odendo, Moses received a grade of B with a mean score of 4.02.
# Based on evaluations, Odendo, Moses received a grade of B- with a mean score of 3.95.
# Based on evaluations, Odendo, Moses received a grade of B with a mean score of 4.17.
# Based on evaluations, Karimi, James Mark,, Ngari received a grade of B+ with a mean score of 4.20.
# Based on evaluations, Karimi, James Mark,, Ngari received a grade of A with a mean score of 4.63.
# Based on evaluations, Karimi, James Mark,, Ngari received a grade of B+ with a mean score of 4.23.
# Based on evaluations, Karimi, James Mark,, Ngari received a grade of A with a mean score of 4.48.
# Based on evaluations, Karimi, James Mark,, Ngari received a grade of B+ with a mean score of 4.27.
# Based on evaluations, Akuma, Samson Mainye received a grade of A- with a mean score of 4.43.
# Based on evaluations, Akuma, Samson Mainye received a grade of A with a mean score of 4.49.
# Based on evaluations, Akuma, Samson Mainye received a grade of A- with a mean score of 4.42.
# Based on evaluations, Akuma, Samson Mainye received a grade of A- with a mean score of 4.46.
# Based on evaluations, Wetiba, Johnson Kwanusu received a grade of A- with a mean score of 4.46.
# Based on evaluations, Wetiba, Johnson Kwanusu received a grade of A with a mean score of 4.58.
# Based on evaluations, Wetiba, Johnson Kwanusu received a grade of A- with a mean score of 4.45.
# Based on evaluations, Njui, Francis received a grade of B with a mean score of 4.16.
# Based on evaluations, Njui, Francis received a grade of B with a mean score of 4.09.
# Based on evaluations, Ochola, Phares B received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Ochola, Phares B received a grade of A- with a mean score of 4.34.
# Based on evaluations, Musuva, Gladys Mwende received a grade of B+ with a mean score of 4.31.
# Based on evaluations, Mbere, Sarah Wanjiru received a grade of B+ with a mean score of 4.18.
# Based on evaluations, Mbere, Sarah Wanjiru received a grade of B+ with a mean score of 4.29.
# Based on evaluations, Mosoti, Zachary received a grade of A- with a mean score of 4.46.
# Based on evaluations, Mosoti, Zachary received a grade of A with a mean score of 4.48.
# Based on evaluations, Mosoti, Zachary received a grade of A- with a mean score of 4.40.
# Based on evaluations, Musebe, Edward Achieng received a grade of A- with a mean score of 4.34.
# Based on evaluations, Musebe, Edward Achieng received a grade of A with a mean score of 4.51.
# Based on evaluations, Musebe, Edward Achieng received a grade of A- with a mean score of 4.38.
# Based on evaluations, Sule, Odhiambo F.E. received a grade of B with a mean score of 3.98.
# Based on evaluations, Sule, Odhiambo F.E. received a grade of A with a mean score of 4.53.
# Based on evaluations, Joseph, Muchina received a grade of C+ with a mean score of 3.73.
# Based on evaluations, Kamau, Joseph received a grade of A- with a mean score of 4.39.
# Based on evaluations, Kamau, Joseph received a grade of A- with a mean score of 4.42.
# Based on evaluations, Kamau, Joseph received a grade of A with a mean score of 4.71.
# Based on evaluations, Kamau, Joseph received a grade of B with a mean score of 4.02.
# Based on evaluations, S   Kiruthu, Lucy Nyaguthii received a grade of A with a mean score of 4.52.
# Based on evaluations, S   Kiruthu, Lucy Nyaguthii received a grade of A- with a mean score of 4.33.
# Based on evaluations, Mburu, Esther Njambi received a grade of A with a mean score of 4.58.
# Based on evaluations, Mburu, Esther Njambi received a grade of A- with a mean score of 4.37.
# Based on evaluations, Mburu, Esther Njambi received a grade of A- with a mean score of 4.34.
# Based on evaluations, F   Wambalaba, Francis received a grade of A with a mean score of 4.48.
# Based on evaluations, F   Wambalaba, Francis received a grade of B+ with a mean score of 4.32.
# Based on evaluations, F   Wambalaba, Francis received a grade of A- with a mean score of 4.33.
# Based on evaluations, F   Wambalaba, Francis received a grade of A- with a mean score of 4.45.
# Based on evaluations, Otieno, Symon_Peter Victor received a grade of B with a mean score of 4.02.
# Based on evaluations, Otieno, Symon_Peter Victor received a grade of A- with a mean score of 4.45.
# Based on evaluations, Osiro, Moses Adama received a grade of C+ with a mean score of 3.73.
# Based on evaluations, Osiro, Moses Adama received a grade of B with a mean score of 4.05.
# Based on evaluations, Asembo, Kenedy Onyango received a grade of B+ with a mean score of 4.21.
# Based on evaluations, Asembo, Kenedy Onyango received a grade of A- with a mean score of 4.36.
# Based on evaluations, Onyango, Resila received a grade of B with a mean score of 4.09.
# Based on evaluations, Sungi, Simeon P. received a grade of A- with a mean score of 4.41.
# Based on evaluations, Sungi, Simeon P. received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Sungi, Simeon P. received a grade of A- with a mean score of 4.45.
# Based on evaluations, Arasa, Josephine received a grade of A- with a mean score of 4.41.
# Based on evaluations, Arasa, Josephine received a grade of A- with a mean score of 4.40.
# Based on evaluations, Arasa, Josephine received a grade of B- with a mean score of 3.92.
# Based on evaluations, Arasa, Josephine received a grade of B- with a mean score of 3.85.
# Based on evaluations, Arasa, Josephine received a grade of C with a mean score of 3.62.
# Based on evaluations, Newa, Elsie Opiyo received a grade of B with a mean score of 4.10.
# Based on evaluations, Newa, Elsie Opiyo received a grade of B with a mean score of 4.05.
# Based on evaluations, Newa, Elsie Opiyo received a grade of A- with a mean score of 4.40.
# Based on evaluations, Newa, Elsie Opiyo received a grade of B+ with a mean score of 4.27.
# Based on evaluations, Mohamed, Hussein Abdi received a grade of A- with a mean score of 4.35.
# Based on evaluations, Mohamed, Hussein Abdi received a grade of A- with a mean score of 4.34.
# Based on evaluations, Mohamed, Hussein Abdi received a grade of B with a mean score of 4.03.
# Based on evaluations, Mwangi, Peterson Kimiru received a grade of B+ with a mean score of 4.29.
# Based on evaluations, Mwangi, Peterson Kimiru received a grade of B with a mean score of 4.17.
# Based on evaluations, Mwangi, Peterson Kimiru received a grade of B with a mean score of 4.06.
# Based on evaluations, Mwangi, Peterson Kimiru received a grade of B with a mean score of 4.16.
# Based on evaluations, Lio, Sammy A.N. received a grade of A- with a mean score of 4.38.
# Based on evaluations, Lio, Sammy A.N. received a grade of B+ with a mean score of 4.19.
# Based on evaluations, Lio, Sammy A.N. received a grade of B+ with a mean score of 4.24.
# Based on evaluations, Lio, Sammy A.N. received a grade of B with a mean score of 4.13.
# Based on evaluations, Lio, Sammy A.N. received a grade of B with a mean score of 4.06.
# Based on evaluations, Kakumu, Muema Pius received a grade of A- with a mean score of 4.41.
# Based on evaluations, Kakumu, Muema Pius received a grade of A with a mean score of 4.55.
# Based on evaluations, Kakumu, Muema Pius received a grade of A- with a mean score of 4.47.
# Based on evaluations, Koshal, Jeremiah Ntaloi_Ole received a grade of A with a mean score of 4.54.
# Based on evaluations, Sikolia, Geoffrey Serede,, Dr. received a grade of A with a mean score of 4.75.
# Based on evaluations, Sikolia, Geoffrey Serede,, Dr. received a grade of B with a mean score of 4.13.
# Based on evaluations, Oduol, Charles received a grade of A with a mean score of 4.49.
# Based on evaluations, Ambiyo, Sarah received a grade of B with a mean score of 4.17.
# Based on evaluations, Ambiyo, Sarah received a grade of B+ with a mean score of 4.20.
# Based on evaluations, Ambiyo, Sarah received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Nyamasyo, Eunice A. received a grade of B with a mean score of 3.98.
# Based on evaluations, Nyamasyo, Eunice A. received a grade of B with a mean score of 4.15.
# Based on evaluations, Scott, Bellows J received a grade of B+ with a mean score of 4.30.
# Based on evaluations, Scott, Bellows J received a grade of A with a mean score of 4.49.
# Based on evaluations, Scott, Bellows J received a grade of A- with a mean score of 4.42.
# Based on evaluations, Scott, Bellows J received a grade of A- with a mean score of 4.33.
# Based on evaluations, Scott, Bellows J received a grade of B with a mean score of 4.16.
# Based on evaluations, Scott, Bellows J received a grade of A with a mean score of 4.56.
# Based on evaluations, Njeri, Teresia received a grade of B with a mean score of 4.17.
# Based on evaluations, Njeri, Teresia received a grade of B with a mean score of 4.08.
# Based on evaluations, Onsomu, Clive Mochiemo received a grade of B+ with a mean score of 4.20.
# Based on evaluations, Onsomu, Clive Mochiemo received a grade of B- with a mean score of 3.92.
# Based on evaluations, Kioni, Benson Muthoga received a grade of A- with a mean score of 4.40.
# Based on evaluations, Wainaina, Samuel received a grade of B with a mean score of 4.01.
# Based on evaluations, Wainaina, Samuel received a grade of B with a mean score of 4.02.
# Based on evaluations, Wainaina, Samuel received a grade of A- with a mean score of 4.38.
# Based on evaluations, Wainaina, Samuel received a grade of B with a mean score of 4.07.
# Based on evaluations, Ngugi, Wilson Mbugua received a grade of B with a mean score of 4.16.
# Based on evaluations, Gatauwa,, James M. received a grade of B+ with a mean score of 4.25.
# Based on evaluations, Joseph, Bertha B received a grade of B+ with a mean score of 4.27.
# Based on evaluations, Bii, Cosmas K received a grade of C+ with a mean score of 3.75.
# Based on evaluations, Mulwa, Harrison Munyao received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Mulwa, Harrison Munyao received a grade of A- with a mean score of 4.33.
# Based on evaluations, Mulwa, Harrison Munyao received a grade of B with a mean score of 4.17.
# Based on evaluations, Akosa, E. Wambalaba received a grade of A- with a mean score of 4.38.
# Based on evaluations, Akosa, E. Wambalaba received a grade of A- with a mean score of 4.33.
# Based on evaluations, Akosa, E. Wambalaba received a grade of A- with a mean score of 4.37.
# Based on evaluations, Akosa, E. Wambalaba received a grade of B+ with a mean score of 4.28.
# Based on evaluations, Ndungu, Francis Gitonga received a grade of A with a mean score of 4.51.
# Based on evaluations, Amwayi, Oliver Shitanda received a grade of A- with a mean score of 4.33.
# Based on evaluations, Nyaribo, Cyprian Mose received a grade of B with a mean score of 4.07.
# Based on evaluations, Nyaribo, Cyprian Mose received a grade of B+ with a mean score of 4.27.
# Based on evaluations, Kakai, Pius Wanyonyi received a grade of A- with a mean score of 4.41.
# Based on evaluations, Kakai, Pius Wanyonyi received a grade of A- with a mean score of 4.35.
# Based on evaluations, Mutisya Mutungi, Mary Mumbua received a grade of A- with a mean score of 4.44.
# Based on evaluations, Mutisya Mutungi, Mary Mumbua received a grade of A with a mean score of 4.54.
# Based on evaluations, Mutisya Mutungi, Mary Mumbua received a grade of B+ with a mean score of 4.27.
# Based on evaluations, Terefe, Ermias Mergia received a grade of B- with a mean score of 3.89.
# Based on evaluations, Terefe, Ermias Mergia received a grade of B+ with a mean score of 4.31.
# Based on evaluations, Terefe, Ermias Mergia received a grade of A- with a mean score of 4.39.
# Based on evaluations, Terefe, Ermias Mergia received a grade of A- with a mean score of 4.36.
# Based on evaluations, Terefe, Ermias Mergia received a grade of A- with a mean score of 4.34.
# Based on evaluations, Terefe, Ermias Mergia received a grade of B+ with a mean score of 4.25.
# Based on evaluations, Njuguna, Joseph Kimani received a grade of A- with a mean score of 4.38.
# Based on evaluations, Njoroge, Simon Githaiga received a grade of B+ with a mean score of 4.27.
# Based on evaluations, Njoroge, Simon Githaiga received a grade of A- with a mean score of 4.37.
# Based on evaluations, Njoroge, Simon Githaiga received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Behr, Agnes Wanjiru received a grade of B+ with a mean score of 4.20.
# Based on evaluations, Behr, Agnes Wanjiru received a grade of A- with a mean score of 4.40.
# Based on evaluations, Behr, Agnes Wanjiru received a grade of A- with a mean score of 4.39.
# Based on evaluations, Ylonen, Aleksi Erik received a grade of A- with a mean score of 4.35.
# Based on evaluations, Ylonen, Aleksi Erik received a grade of A with a mean score of 4.58.
# Based on evaluations, Ylonen, Aleksi Erik received a grade of A- with a mean score of 4.34.
# Based on evaluations, Ylonen, Aleksi Erik received a grade of A- with a mean score of 4.43.
# Based on evaluations, Maganda, Willis Otieno received a grade of B with a mean score of 4.04.
# Based on evaluations, Maganda, Willis Otieno received a grade of B with a mean score of 4.07.
# Based on evaluations, Muliro, Wilfred Nasong'o received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Muliro, Wilfred Nasong'o received a grade of B+ with a mean score of 4.26.
# Based on evaluations, F   Veney, Cassandra Rachel received a grade of A- with a mean score of 4.36.
# Based on evaluations, F   Veney, Cassandra Rachel received a grade of B- with a mean score of 3.96.
# Based on evaluations, F   Veney, Cassandra Rachel received a grade of B with a mean score of 4.03.
# Based on evaluations, F   Veney, Cassandra Rachel received a grade of A- with a mean score of 4.45.
# Based on evaluations, Gisore, Billiah N. received a grade of B+ with a mean score of 4.20.
# Based on evaluations, Gisore, Billiah N. received a grade of B- with a mean score of 3.94.
# Based on evaluations, Mashiwa, Maurice received a grade of A- with a mean score of 4.34.
# Based on evaluations, Mbae, Justus received a grade of C+ with a mean score of 3.72.
# Based on evaluations, S   Maina, Ann Wambui received a grade of C+ with a mean score of 3.70.
# Based on evaluations, S   Maina, Ann Wambui received a grade of B with a mean score of 4.00.
# Based on evaluations, S   Maina, Ann Wambui received a grade of B+ with a mean score of 4.29.
# Based on evaluations, S   Mutune, Loraine received a grade of A- with a mean score of 4.40.
# Based on evaluations, S   Mutune, Loraine received a grade of A- with a mean score of 4.38.
# Based on evaluations, Sifuna, Austin Makokha received a grade of A with a mean score of 4.64.
# Based on evaluations, Sifuna, Austin Makokha received a grade of A- with a mean score of 4.43.
# Based on evaluations, Sifuna, Austin Makokha received a grade of A- with a mean score of 4.41.
# Based on evaluations, Karoki, Samuel Githinji received a grade of A- with a mean score of 4.38.
# Based on evaluations, Karoki, Samuel Githinji received a grade of B+ with a mean score of 4.18.
# Based on evaluations, Baraza, Cyrus M received a grade of B with a mean score of 4.15.
# Based on evaluations, Nakamura, Katsuji received a grade of A- with a mean score of 4.46.
# Based on evaluations, Nakamura, Katsuji received a grade of A with a mean score of 4.56.
# Based on evaluations, Githinji, Keziah Wangui,, Ms. received a grade of B+ with a mean score of 4.29.
# Based on evaluations, Githinji, Keziah Wangui,, Ms. received a grade of B+ with a mean score of 4.31.
# Based on evaluations, Telewa, Christabel received a grade of B+ with a mean score of 4.25.
# Based on evaluations, Telewa, Christabel received a grade of B+ with a mean score of 4.31.
# Based on evaluations, Karanja, Moses Mwangi,, Mr received a grade of B with a mean score of 3.99.
# Based on evaluations, Karanja, Moses Mwangi,, Mr received a grade of B- with a mean score of 3.93.
# Based on evaluations, Kidaha, Alfred Usagi received a grade of B+ with a mean score of 4.21.
# Based on evaluations, Kidaha, Alfred Usagi received a grade of A- with a mean score of 4.42.
# Based on evaluations, Mwangi, Isaac received a grade of B- with a mean score of 3.93.
# Based on evaluations, Mwangi, Isaac received a grade of A- with a mean score of 4.37.
# Based on evaluations, Mwilu, Asha Ahmed received a grade of A with a mean score of 4.59.
# Based on evaluations, Bosire, Julius Ombui,, Dr. received a grade of A- with a mean score of 4.36.
# Based on evaluations, Bosire, Julius Ombui,, Dr. received a grade of B with a mean score of 4.07.
# Based on evaluations, Bosire, Julius Ombui,, Dr. received a grade of B+ with a mean score of 4.30.
# Based on evaluations, Kamau, Sheila Wanjiku received a grade of B+ with a mean score of 4.29.
# Based on evaluations, Oranga, James Odhiambo received a grade of A with a mean score of 4.56.
# Based on evaluations, Oranga, James Odhiambo received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Owilla, Hesbon Hansen received a grade of A- with a mean score of 4.35.
# Based on evaluations, Owilla, Hesbon Hansen received a grade of B+ with a mean score of 4.31.
# Based on evaluations, Kimotho, Stephen Gichuhi received a grade of A with a mean score of 4.75.
# Based on evaluations, Kimotho, Stephen Gichuhi received a grade of A- with a mean score of 4.40.
# Based on evaluations, Kimotho, Stephen Gichuhi received a grade of B+ with a mean score of 4.30.
# Based on evaluations, Kimotho, Stephen Gichuhi received a grade of A with a mean score of 4.65.
# Based on evaluations, Githua, Oscar Wanyutu received a grade of C with a mean score of 3.65.
# Based on evaluations, Githua, Oscar Wanyutu received a grade of B+ with a mean score of 4.27.
# Based on evaluations, Githua, Oscar Wanyutu received a grade of B with a mean score of 4.04.
# Based on evaluations, Nyambegera, Stephen Morangi received a grade of B- with a mean score of 3.96.
# Based on evaluations, Nyambegera, Stephen Morangi received a grade of B with a mean score of 4.13.
# Based on evaluations, Mairura, Christopher Joseph received a grade of B- with a mean score of 3.94.
# Based on evaluations, Matula, Phylisters Daizy received a grade of B+ with a mean score of 4.32.
# Based on evaluations, Linge, Teresia K.K. received a grade of A- with a mean score of 4.35.
# Based on evaluations, Obila, Onyango James,, Mr. received a grade of B with a mean score of 4.03.
# Based on evaluations, Obila, Onyango James,, Mr. received a grade of B with a mean score of 4.06.
# Based on evaluations, Maore, Stephen K. received a grade of A- with a mean score of 4.41.
# Based on evaluations, Maore, Stephen K. received a grade of A- with a mean score of 4.43.
# Based on evaluations, Maore, Stephen K. received a grade of A- with a mean score of 4.45.
# Based on evaluations, S   Kiptum, Purity Jebotibin received a grade of B with a mean score of 4.16.
# Based on evaluations, S   Kiptum, Purity Jebotibin received a grade of A- with a mean score of 4.38.
# Based on evaluations, S   Kiptum, Purity Jebotibin received a grade of A- with a mean score of 4.36.
# Based on evaluations, Oyigo, Josephat DR received a grade of B with a mean score of 4.07.
# Based on evaluations, Oyigo, Josephat DR received a grade of B+ with a mean score of 4.19.
# Based on evaluations, Gitau, Samuel received a grade of D+ with a mean score of 3.32.
# Based on evaluations, Gitau, Samuel received a grade of C with a mean score of 3.57.
# Based on evaluations, Defersha, Amsalu Degu received a grade of B with a mean score of 4.16.
# Based on evaluations, Defersha, Amsalu Degu received a grade of B with a mean score of 4.17.
# Based on evaluations, Defersha, Amsalu Degu received a grade of B+ with a mean score of 4.19.
# Based on evaluations, Mwaniki, Moses received a grade of B with a mean score of 4.00.
# Based on evaluations, Mwaniki, Moses received a grade of B with a mean score of 4.05.
# Based on evaluations, Simiyu, Lucy received a grade of A- with a mean score of 4.47.
# Based on evaluations, Simiyu, Lucy received a grade of A- with a mean score of 4.37.
# Based on evaluations, Musau, Josephine Ndanu received a grade of B with a mean score of 4.11.
# Based on evaluations, Musau, Josephine Ndanu received a grade of A- with a mean score of 4.39.
# Based on evaluations, Musau, Josephine Ndanu received a grade of A- with a mean score of 4.46.
# Based on evaluations, Bironga, Sophia Moraa received a grade of A- with a mean score of 4.34.
# Based on evaluations, Bironga, Sophia Moraa received a grade of B+ with a mean score of 4.28.
# Based on evaluations, F   Munywoki, Samson received a grade of A- with a mean score of 4.35.
# Based on evaluations, Njoroge, Joseph received a grade of A- with a mean score of 4.38.
# Based on evaluations, Njoroge, Joseph received a grade of A- with a mean score of 4.35.
# Based on evaluations, Njoroge, Joseph received a grade of A- with a mean score of 4.35.
# Based on evaluations, Njoroge, Joseph received a grade of A with a mean score of 4.50.
# Based on evaluations, Omollo, Joseph Owade received a grade of B with a mean score of 4.08.
# Based on evaluations, Omollo, Joseph Owade received a grade of B with a mean score of 4.07.
# Based on evaluations, Omollo, Joseph Owade received a grade of B+ with a mean score of 4.19.
# Based on evaluations, Webbo, Roselynne Kyambi received a grade of B+ with a mean score of 4.32.
# Based on evaluations, Webbo, Roselynne Kyambi received a grade of A- with a mean score of 4.39.
# Based on evaluations, Ongecha, Francisca Atieno received a grade of A with a mean score of 4.48.
# Based on evaluations, Ongecha, Francisca Atieno received a grade of B+ with a mean score of 4.19.
# Based on evaluations, Brown, Dana Basnight received a grade of A with a mean score of 4.53.
#
# Query: How did Gitahi perform?
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of B with a mean score of 4.04.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of A- with a mean score of 4.43.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of A with a mean score of 4.49.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of B with a mean score of 4.17.
#
# Query: Results for Odoyo
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Evaluation of Gatumo, Francis Mambo
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Who scored above 4.8?
# No instructors scored above 4.8.
#
# Query: List instructors with scores below 3.5
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Which instructors scored exactly 4.0?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Which instructors got an A?
# Instructors with grade C:
# - Githua, Oscar Wanyutu: 3.65
# - Kamuri, Simon: 3.64
# - Namuye, Silvester: 3.62
# - Machoka, Philip Gichaba: 3.62
# - Arasa, Josephine: 3.62
# - Nyarigoti, Naom Moraa: 3.60
# - Gitau, Samuel: 3.57
# - Njenga, Edward Gachangi: 3.55
#
# Query: Show me all with grade B
# Instructors with grade A:
# - Sikolia, Geoffrey Serede,, Dr.: 4.75
# - Macharia, Jimmy: 4.71
# - Kamau, Joseph: 4.71
# - Ali, Fatuma Ahmed: 4.71
# - Nguru, Faith Wariara: 4.70
# - Kimotho, Stephen Gichuhi: 4.70
# - Sifuna, Austin Makokha: 4.64
# - Gachukia, Jennifer Wangari: 4.63
# - Mwangi, Jonathan Maina: 4.60
# - Adan, Ali: 4.60
# - Wachana, Paul: 4.59
# - Mwilu, Asha Ahmed: 4.59
# - Mulindi, Patrick M.: 4.59
# - Ylonen, Aleksi Erik: 4.58
# - Wetiba, Johnson Kwanusu: 4.58
# - Mburu, Esther Njambi: 4.58
# - Nyete, Abraham Mutunga: 4.58
# - Munyi, Elijah N: 4.57
# - Achoki, George: 4.56
# - Oranga, James Odhiambo: 4.56
# - Nginye, Michael Gichangi: 4.56
# - Nakamura, Katsuji: 4.56
# - Karimi, James Mark,, Ngari: 4.55
# - Ondiek, Collins Oduor: 4.55
# - Kimani, Nathan Muya: 4.55
# - Karume, Michelle Wariara: 4.55
# - Kakumu, Muema Pius: 4.55
# - Mbugua, Paul Mungai: 4.54
# - Njeru, Godwin Kinyua: 4.54
# - Njenga, Kefah Muiruri: 4.54
# - Mutisya Mutungi, Mary Mumbua: 4.54
# - Mbotu, Michael Mulandi: 4.54
# - Koshal, Jeremiah Ntaloi_Ole: 4.54
# - Kabongah, George Odhiambo: 4.54
# - Sule, Odhiambo F.E.: 4.53
# - Ndirangu, Dalton: 4.53
# - Kabacho, Mwangi: 4.53
# - Gatumo, Francis Mambo: 4.53
# - Brown, Dana Basnight: 4.53
# - Were, Jamen H.: 4.53
# - Scott, Bellows J: 4.53
# - S   Kiruthu, Lucy Nyaguthii: 4.52
# - Ogada, Agnes Owuor: 4.52
# - Noah, Naumih M.: 4.52
# - Njuguna, Amos Gitau: 4.52
# - Namuye, Maria: 4.52
# - F   Buyu, Matthew: 4.52
# - Ndungu, Francis Gitonga: 4.51
# - Musebe, Edward Achieng: 4.51
# - Mbatia, Betty Nyambura: 4.51
# - Kariuki, Lucy Nyawira: 4.51
# - F   Iraki, Fredrick Kang'ethe: 4.51
# - Okech, Timothy C.: 4.50
# - Ogore, Fredrick Michae: 4.50
# - Ogola, Mary Ganga: 4.50
# - Njoroge, Joseph: 4.50
# - Mohamed, Abdullahi Mohamed: 4.50
# - Mbugua, Wanjiku: 4.50
# - Magut, Zuhra C.: 4.50
# - Kiai, Gachanja: 4.50
# - Getecha, Ciru W.: 4.50
# - Ahenda, John Ang'udi: 4.50
# - Rubio Gijon, Pablo: 4.49
# - Oteri, Malack Omae: 4.49
# - Oriedi, David Opondo: 4.49
# - Onditi, Tom: 4.49
# - Oduol, Charles: 4.49
# - Gitahi, Jesse Elikanah_Machirah: 4.49
# - Akuma, Samson Mainye: 4.49
# - Ongecha, Francisca Atieno: 4.48
# - Njihia, David Thiru: 4.48
# - Ndegwa, Joyce Watetu: 4.48
# - Mosoti, Zachary: 4.48
# - Githinji, Stanley Muturi,, Dr.: 4.48
# - F   Wambalaba, Francis: 4.48
#
# Query: Who received a C?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Top 10 performers
# Top 10 performers:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
# - Achoki, George: 4.54 (A-)
# - Koshal, Jeremiah Ntaloi_Ole: 4.54 (A)
# - Kabongah, George Odhiambo: 4.54 (A)
# - Brown, Dana Basnight: 4.53 (A)
# - Were, Jamen H.: 4.53 (A)
#
# Query: Top 3 instructors this semester
# Top 3 performers:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
#
# Query: Top 20 performers
# Top 20 performers:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
# - Achoki, George: 4.54 (A-)
# - Koshal, Jeremiah Ntaloi_Ole: 4.54 (A)
# - Kabongah, George Odhiambo: 4.54 (A)
# - Brown, Dana Basnight: 4.53 (A)
# - Were, Jamen H.: 4.53 (A)
# - Ali, Fatuma Ahmed: 4.53 (A-)
# - Kimotho, Stephen Gichuhi: 4.53 (A)
# - Namuye, Maria: 4.52 (A)
# - Ndungu, Francis Gitonga: 4.51 (A)
# - Nakamura, Katsuji: 4.51 (A-)
# - F   Iraki, Fredrick Kang'ethe: 4.51 (A)
# - Mulindi, Patrick M.: 4.50 (A)
# - Kiai, Gachanja: 4.50 (A)
# - Wetiba, Johnson Kwanusu: 4.50 (A-)
# - Sifuna, Austin Makokha: 4.49 (A)
#
# Query: What feedback did students give Afundi?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Summarize feedback for Mohamed
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Show sample feedback for Odoyo
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: How did Alo perform?
# Based on evaluations, Aloo, Linus Alwal received a grade of A- with a mean score of 4.45.
# Based on evaluations, Aloo, Linus Alwal received a grade of A- with a mean score of 4.34.
# Based on evaluations, Aloo, Linus Alwal received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Gitoho, Salome Wanjiru received a grade of B with a mean score of 4.16.
# Based on evaluations, Gitoho, Salome Wanjiru received a grade of B+ with a mean score of 4.31.
# Based on evaluations, Koshal, Jeremiah Ntaloi_Ole received a grade of A with a mean score of 4.54.
#
# Query: Tell me about Basweti
# Based on evaluations, Basweti, Kevin Ogachi received a grade of C+ with a mean score of 3.77.
# Based on evaluations, Basweti, Kevin Ogachi received a grade of C+ with a mean score of 3.82.
# Based on evaluations, Basweti, Kevin Ogachi received a grade of B with a mean score of 4.03.
#
# Query: Evaluation for a nonexistent instructor
# No evaluation data found for Evaluation.

# %% [markdown]
# Where It Failed
# - “Results for Odoyo” / “Evaluation of Gatumo, Francis Mambo”
# - Issue: The intent parser didn’t recognize “Results for” or “Evaluation of” as lookup triggers.
# - Fix: Expand parser keywords to catch synonyms like results, evaluation of, performance of, review of.
# - “List instructors with scores below 3.5” / “Which instructors scored exactly 4.0”
# - Issue: Current parser only handles “above” thresholds. Equality and “below” weren’t implemented.
# - Fix: Add regex for “below”, “less than”, “equal to”, “exactly”.
# - “Which instructors got an A?” / “Show me all with grade B”
# - Issue: Parser mis‑mapped grade intent. It returned grade C for “A” and grade A for “B”.
# - Fix: Regex extraction needs to be more precise — right now it’s grabbing the wrong letter from the query string.

# %%
# oK so lets revamp that intent parser a bit
def parse_intent(user_input):
    text = user_input.lower()

    # Top performers
    m_top = re.search(r"top\s+(\d+)", text)
    if m_top:
        return {"intent": "top_ranked", "count": int(m_top.group(1))}

    # Score filters
    m_above = re.search(r"(above|greater than|over)\s*(\d+(\.\d+)?)", text)
    if m_above:
        return {"intent": "score_filter", "op": ">", "threshold": float(m_above.group(2))}

    m_below = re.search(r"(below|less than|under)\s*(\d+(\.\d+)?)", text)
    if m_below:
        return {"intent": "score_filter", "op": "<", "threshold": float(m_below.group(2))}

    m_equal = re.search(r"(equal|exactly|=|is)\s*(\d+(\.\d+)?)", text)
    if m_equal:
        return {"intent": "score_filter", "op": "=", "threshold": float(m_equal.group(2))}

    # Grade filters
    m_grade = re.search(r"(grade|got an|received an)\s*([abc])", text)
    if m_grade:
        return {"intent": "grade_filter", "grade": m_grade.group(2).upper()}

    # Instructor lookup
    if any(kw in text for kw in ["how did", "tell me about", "results for", "evaluation of", "performance of", "review of"]):
        return {"intent": "lookup", "name": user_input}

    return {"intent": "unknown"}

# %%
# Stress test queries
test_queries = [
    "Tell me about Afundi",
    "What’s the evaluation for Mohamed, Mwanashehe S.?",
    "How did Gitahi perform?",
    "Results for Odoyo",
    "Evaluation of Gatumo, Francis Mambo",
    "Who scored above 4.8?",
    "List instructors with scores below 3.5",
    "Which instructors scored exactly 4.0?",
    "Which instructors got an A?",
    "Show me all with grade B",
    "Who received a C?",
    "Top 10 performers",
    "Top 3 instructors this semester",
    "Top 20 performers",
    "What feedback did students give Afundi?",
    "Summarize feedback for Mohamed",
    "Show sample feedback for Odoyo",
    "How did Alo perform?",   # typo test
    "Tell me about Basweti",  # partial match
    "Evaluation for a nonexistent instructor"
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: Tell me about Afundi
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.04.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.15.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of A- with a mean score of 4.35.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B with a mean score of 4.12.
# Based on evaluations, Afundi, Patrick Omuhinda received a grade of B+ with a mean score of 4.18.
#
# Query: What’s the evaluation for Mohamed, Mwanashehe S.?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: How did Gitahi perform?
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of B with a mean score of 4.04.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of A- with a mean score of 4.43.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of A with a mean score of 4.49.
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah received a grade of B with a mean score of 4.17.
#
# Query: Results for Odoyo
# Based on evaluations, Odoyo, Fredrick received a grade of B with a mean score of 4.10.
#
# Query: Evaluation of Gatumo, Francis Mambo
# Based on evaluations, Gatumo, Francis Mambo received a grade of A- with a mean score of 4.41.
# Based on evaluations, Gatumo, Francis Mambo received a grade of A- with a mean score of 4.36.
# Based on evaluations, Gatumo, Francis Mambo received a grade of A with a mean score of 4.53.
# Based on evaluations, Gatumo, Francis Mambo received a grade of A- with a mean score of 4.45.
# Based on evaluations, Wangai, Njoroge Mambo received a grade of B with a mean score of 4.17.
# Based on evaluations, Wangai, Njoroge Mambo received a grade of B+ with a mean score of 4.28.
#
# Query: Who scored above 4.8?
# No instructors scored above 4.8.
#
# Query: List instructors with scores below 3.5
# Instructors with scores above 3.5:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
# - Achoki, George: 4.54 (A-)
# - Koshal, Jeremiah Ntaloi_Ole: 4.54 (A)
# - Kabongah, George Odhiambo: 4.54 (A)
# - Brown, Dana Basnight: 4.53 (A)
# - Were, Jamen H.: 4.53 (A)
# - Ali, Fatuma Ahmed: 4.53 (A-)
# - Kimotho, Stephen Gichuhi: 4.53 (A)
# - Namuye, Maria: 4.52 (A)
# - Ndungu, Francis Gitonga: 4.51 (A)
# - Nakamura, Katsuji: 4.51 (A-)
# - F   Iraki, Fredrick Kang'ethe: 4.51 (A)
# - Mulindi, Patrick M.: 4.50 (A)
# - Kiai, Gachanja: 4.50 (A)
# - Wetiba, Johnson Kwanusu: 4.50 (A-)
# - Sifuna, Austin Makokha: 4.49 (A)
# - Oriedi, David Opondo: 4.49 (A)
# - Oduol, Charles: 4.49 (A)
# - Kakumu, Muema Pius: 4.48 (A-)
# - Wainaina, Gituro: 4.47 (A-)
# - Onono-Okelo, Perez A.: 4.47 (A-)
# - Noah, Naumih M.: 4.47 (A-)
# - Mbotu, Michael Mulandi: 4.46 (A)
# - Karume, Michelle Wariara: 4.46 (A-)
# - Munyi, Elijah N: 4.46 (A-)
# - Rubio Gijon, Pablo: 4.45 (A-)
# - Akuma, Samson Mainye: 4.45 (A-)
# - Nyete, Abraham Mutunga: 4.45 (B+)
# - Mosoti, Zachary: 4.45 (A-)
# - Mohamed, Abdullahi Mohamed: 4.45 (A-)
# - Getecha, Ciru W.: 4.44 (A)
# - Sikolia, Geoffrey Serede,, Dr.: 4.44 (A)
# - Gatumo, Francis Mambo: 4.44 (A-)
# - Ndegwa, Joyce Watetu: 4.43 (A)
# - Bwire, Albert C.: 4.43 (A-)
# - Oteri, Malack Omae: 4.43 (A-)
# - Mburu, Esther Njambi: 4.43 (A)
# - Maore, Stephen K.: 4.43 (A-)
# - Kibet, Eric M.: 4.43 (A-)
# - Ondieki, Benard Odhiambo: 4.43 (A-)
# - Ylonen, Aleksi Erik: 4.42 (A-)
# - S   Kiruthu, Lucy Nyaguthii: 4.42 (A)
# - Ogore, Fredrick Michae: 4.42 (A-)
# - Simiyu, Lucy: 4.42 (A-)
# - Mutisya Mutungi, Mary Mumbua: 4.42 (A-)
# - Kabacho, Mwangi: 4.42 (B+)
# - Gachukia, Jennifer Wangari: 4.41 (A)
# - Oranga, James Odhiambo: 4.41 (A)
# - Musebe, Edward Achieng: 4.41 (A-)
# - F   Munene, Macharia: 4.41 (A-)
# - Rintari, Ann Wanjiku: 4.40 (A-)
# - Mwangi, Jonathan Maina: 4.40 (A-)
# - Ndirangu, Dalton: 4.40 (B)
# - Mage, Grace Nduta: 4.40 (A-)
# - Kioni, Benson Muthoga: 4.40 (A-)
# - Gromov, Mikhail D.: 4.40 (A-)
# - Githigaro, John Mwangi: 4.40 (A-)
# - Opondo, Mary Awuor: 4.40 (A-)
# - F   Wambalaba, Francis: 4.40 (A)
# - Njoroge, Joseph: 4.39 (A-)
# - Ogola, Mary Ganga: 4.39 (B+)
# - Awuor, Quin Elizabeth: 4.39 (A-)
# - S   Mutune, Loraine: 4.39 (A-)
# - Mutwiri, Marion Kirumba: 4.39 (A-)
# - Mule, Daniel: 4.39 (A-)
# - Mbugua, Wanjiku: 4.39 (A-)
# - Kiaye, Mary A.: 4.38 (A-)
# - Kamau, Joseph: 4.38 (A-)
# - Githiri, John Gitonga: 4.38 (A-)
# - Nyarige, Pamela Kwamboka: 4.38 (A-)
# - Njuguna, Joseph Kimani: 4.38 (A-)
# - Njenga, Kefah Muiruri: 4.38 (B+)
# - Muniafu, Max Maina: 4.38 (A-)
# - Milton, Obote J.: 4.38 (B+)
# - Kakai, Pius Wanyonyi: 4.38 (A-)
# - Mbatia, Betty Nyambura: 4.38 (A)
# - Scott, Bellows J: 4.38 (B+)
# - Njuguna, Amos Gitau: 4.38 (B)
# - Muendo, Daniel: 4.38 (A-)
# - Kiai, Alice Wanjira: 4.38 (A-)
# - Ondiek, Collins Oduor: 4.37 (A-)
# - Wangui, Ruth Njeri: 4.37 (A-)
# - Sungi, Simeon P.: 4.37 (A-)
# - Wafula, Maurine Maraka: 4.37 (A-)
# - Ouma, Zackayo Omolo: 4.37 (A-)
# - Kuria,, John: 4.37 (A-)
# - Akach, Joyce Akinyi: 4.37 (A-)
# - Ouma,, Judy Aluoch: 4.37 (A-)
# - Nginye, Michael Gichangi: 4.37 (B)
# - Ndungu, Tabitha K.: 4.37 (B+)
# - Njihia, David Thiru: 4.36 (B+)
# - Magut, Zuhra C.: 4.36 (A)
# - Karimi, James Mark,, Ngari: 4.36 (B+)
# - Kangu, Maureen: 4.36 (A-)
# - Webbo, Roselynne Kyambi: 4.36 (B+)
# - Kobuthi, Edward N.: 4.36 (B+)
# - Githinji, Stanley Muturi,, Dr.: 4.35 (A-)
# - Gichaga, Lucy Wanjiku: 4.35 (B+)
# - Mburu, Martin: 4.35 (A-)
# - Aloo, Linus Alwal: 4.35 (A-)
# - Linge, Teresia K.K.: 4.35 (A-)
# - Katete, George Onyango: 4.35 (A-)
# - Ireri, Kioko: 4.35 (B+)
# - F   Munywoki, Samson: 4.35 (A-)
# - Andango, Elizabeth: 4.35 (A-)
# - F   Buyu, Matthew: 4.35 (A)
# - Amuhaya, Edith Khavwajira: 4.35 (A-)
# - Maima, Apollo Odhiambo: 4.35 (A-)
# - Kimani, Joan Wanjiru: 4.35 (B+)
# - Misawo, Florence Awuor: 4.34 (A-)
# - Ndungu, Pauline W.: 4.34 (B+)
# - Ogendi, Paul: 4.34 (A-)
# - Mashiwa, Maurice: 4.34 (A-)
# - Akosa, E. Wambalaba: 4.34 (A-)
# - Mutanu, Leah: 4.34 (A-)
# - Ongecha, Francisca Atieno: 4.34 (A)
# - Owilla, Hesbon Hansen: 4.33 (A-)
# - Kihara, Michael: 4.33 (A-)
# - Kayeyia, Ernest Madara: 4.33 (A-)
# - Gachie, Richard K.: 4.33 (A-)
# - Behr, Agnes Wanjiru: 4.33 (B+)
# - Awuor, Emmanuel: 4.33 (A-)
# - Amwayi, Oliver Shitanda: 4.33 (A-)
# - Owino, Edward Otieno: 4.32 (A-)
# - Mwangi, William K.: 4.32 (B+)
# - Musau, Josephine Ndanu: 4.32 (B)
# - Matula, Phylisters Daizy: 4.32 (B+)
# - Otieno, Pauline Adhiambo: 4.31 (A-)
# - Macharia, Jimmy: 4.31 (B)
# - Kidaha, Alfred Usagi: 4.31 (B+)
# - Bironga, Sophia Moraa: 4.31 (A-)
# - Njoroge, Martin Chege: 4.31 (B+)
# - Musuva, Gladys Mwende: 4.31 (B+)
# - Munyae, Margaret M.: 4.31 (B+)
# - Muindi, Benjamin: 4.31 (B+)
# - Owuor, Benard O: 4.30 (A-)
# - Ndero, Peter K.: 4.30 (B+)
# - Odaba, Dan Noel: 4.30 (B+)
# - Mbole, Elizabeth M.: 4.30 (B+)
# - S   Kiptum, Purity Jebotibin: 4.30 (B)
# - Ochola, Phares B: 4.30 (B+)
# - Njoroge, Simon Githaiga: 4.30 (B+)
# - Muindi, Peter M.: 4.30 (B+)
# - Githinji, Keziah Wangui,, Ms.: 4.30 (B+)
# - Odhiambo, Terry J.: 4.30 (B)
# - Ochieng', Robi Koki: 4.29 (B)
# - Kamau, Sheila Wanjiku: 4.29 (B+)
# - Kamanu, Timothy_Kevin Kuria: 4.29 (B+)
# - Kavoo, Mark Kavoo: 4.29 (B+)
# - Asembo, Kenedy Onyango: 4.29 (B+)
# - Gitahi, Jesse Elikanah_Machirah: 4.28 (B)
# - Nyakundi, Jane: 4.28 (B+)
# - Kariuki, Lucy Nyawira: 4.28 (B+)
# - Telewa, Christabel: 4.28 (B+)
# - Karoki, Samuel Githinji: 4.28 (A-)
# - Ahenda, John Ang'udi: 4.28 (B+)
# - Muturi, Lucy N.: 4.28 (A-)
# - Waga, Fred: 4.27 (A-)
# - Okanda, Paul M: 4.27 (A-)
# - Nyaanga, Gideon Nyamweya: 4.27 (B+)
# - Joseph, Bertha B: 4.27 (B+)
# - Njeru, Godwin Kinyua: 4.27 (B)
# - Muriu, Marylyn Doreen: 4.26 (B+)
# - Okech, Timothy C.: 4.26 (A)
# - Nginda, Ronald Robert_Abwova: 4.26 (B+)
# - Muliro, Wilfred Nasong'o: 4.26 (B+)
# - Mbithi, Jonathan Ndolo: 4.26 (B+)
# - Terefe, Ermias Mergia: 4.26 (B-)
# - Kimathi, George Eliphas: 4.26 (B+)
# - Wachana, Paul: 4.25 (B)
# - Sule, Odhiambo F.E.: 4.25 (B)
# - Macharia, Hannah Muthoni: 4.25 (B)
# - Jefwa, Judith Jai_Jaleha: 4.25 (B)
# - Mulwa, Harrison Munyao: 4.25 (B+)
# - Newa, Fred Omondi: 4.25 (A-)
# - Kalunda, Elizabeth Nthambi: 4.25 (B+)
# - Gatauwa,, James M.: 4.25 (B+)
# - Maumo, Leonard Oluoch: 4.25 (B+)
# - Bosire, Julius Ombui,, Dr.: 4.24 (A-)
# - Nyaga, Nancy Ng'endo: 4.24 (B+)
# - Maina, Muchara Dr: 4.24 (B+)
# - Ireri, Niceta Wanja: 4.24 (B+)
# - Mohamed, Hussein Abdi: 4.24 (A-)
# - Onditi, Tom: 4.24 (B)
# - Owili, Florence Akinyi: 4.23 (B)
# - Otieno, Symon_Peter Victor: 4.23 (B)
# - Mbere, Sarah Wanjiru: 4.23 (B+)
# - Gitoho, Salome Wanjiru: 4.23 (B)
# - Cheluget, Elizabeth Jepchumba: 4.23 (B)
# - Okanya, Patrick Wafula_Simiyu: 4.23 (B+)
# - Nyambati, Grace K: 4.23 (B+)
# - Wamuyu, Patrick Kanyi: 4.23 (B)
# - Wangai, Njoroge Mambo: 4.22 (B)
# - Muriithi, Jane Gathigia: 4.22 (B+)
# - Mohamed, Mwanashehe S.: 4.22 (B+)
# - Mbugua, Levi Ng'ang'a: 4.22 (B+)
# - Khadioli, Nancy: 4.22 (B)
# - K'aol, George O.: 4.22 (A-)
# - Awuor, Anita Margaret: 4.22 (B+)
# - Odek, Anthony W.: 4.21 (B+)
# - Ogola, Jacob Owuor: 4.21 (B+)
# - Kahiri, Caroline Njeri,, Dr.: 4.21 (B)
# - Ambiyo, Sarah: 4.21 (B)
# - Newa, Elsie Opiyo: 4.21 (B)
# - Kirui, Gideon Kipng'eno: 4.21 (B)
# - Mwakina, Rozina Munna: 4.20 (B+)
# - Lio, Sammy A.N.: 4.20 (A-)
# - Gachanga, Esther Wanjiru: 4.20 (B+)
# - Gachago, Philip Muriithi: 4.20 (B+)
# - F   Veney, Cassandra Rachel: 4.20 (A-)
# - Waithima, Charity Wangui: 4.19 (B+)
# - Ouma,, Duncan Ochieng: 4.19 (B)
# - Ndiege, Joshua Rumo: 4.18 (B+)
# - Mbugua, John Chege: 4.18 (B+)
# - Gathua, Michael M.: 4.18 (B)
# - Panchani, Roopam Lalji: 4.18 (B+)
# - Defersha, Amsalu Degu: 4.17 (B)
# - Nyaribo, Cyprian Mose: 4.17 (B)
# - Mwangi, Peterson Kimiru: 4.17 (B+)
# - Muchiri, Catherine Wanjiru: 4.17 (B+)
# - Kinuthia, Annie Njoki: 4.17 (B)
# - Afundi, Patrick Omuhinda: 4.17 (B)
# - Ng'eno, Weldon Kibet: 4.17 (B)
# - Omondi, Daniel Onyango: 4.16 (B)
# - Ngugi, Wilson Mbugua: 4.16 (B)
# - Mirichii, John Mwaniki: 4.16 (B)
# - Karugu, Mureithi: 4.16 (B)
# - Nduati, Gidraph J.: 4.15 (B)
# - Kigwilu, Peter Changilwa: 4.15 (B+)
# - Muriithi, Petronilla Muthoni: 4.15 (B+)
# - Mwangi, Isaac: 4.15 (B-)
# - Baraza, Cyrus M: 4.15 (B)
# - Oyaro, Kepha N._Makori: 4.15 (B)
# - Nderu, Lawrence: 4.14 (B)
# - Obbanda, Luka Epainito: 4.13 (B+)
# - Mbugua, Peter Getyngo: 4.13 (B)
# - Oyigo, Josephat DR: 4.13 (B)
# - Njui, Francis: 4.12 (B)
# - Njeri, Teresia: 4.12 (B)
# - Wainaina, Samuel: 4.12 (B)
# - Mwalili, Tobias Mbithi: 4.12 (B)
# - Kogo, Vincent Kibet: 4.12 (B)
# - Njogu, Peter Mbugua: 4.12 (B)
# - Omollo, Joseph Owade: 4.11 (B)
# - Okallo, Dick Daniel: 4.11 (B+)
# - Kimani, Larry M: 4.11 (B)
# - Kaluyu, Veronicah: 4.11 (B)
# - Odoyo, Fredrick: 4.10 (B)
# - Oketch, Omondi: 4.10 (B+)
# - Nyabere, Emily: 4.10 (B)
# - Makhaso, Byron Chesoli: 4.09 (B+)
# - Owuor, John David_Ouma: 4.09 (B+)
# - Onyango, Resila: 4.09 (B)
# - Mwangi, Henry Njogo: 4.09 (C+)
# - Maranga,, Vincent Nyamari: 4.08 (B)
# - Were, Jane N.: 4.08 (B)
# - Gisore, Billiah N.: 4.07 (B+)
# - Nyamasyo, Eunice A.: 4.07 (B)
# - Odongo, Elizabeth Amwayi: 4.06 (B)
# - Onsomu, Clive Mochiemo: 4.06 (B+)
# - Maganda, Willis Otieno: 4.05 (B)
# - Odendo, Moses: 4.05 (B)
# - Obila, Onyango James,, Mr.: 4.04 (B)
# - Nyambegera, Stephen Morangi: 4.04 (B-)
# - Otiende, Noah Ochieng: 4.04 (B)
# - Njoroge, Margaret: 4.04 (B-)
# - Magero, Patrick L.K: 4.04 (B)
# - Arasa, Josephine: 4.04 (A-)
# - Nyong'o, Kwame o: 4.04 (B)
# - Ogada, Agnes Owuor: 4.03 (A-)
# - Mwaniki, Moses: 4.03 (B)
# - Wangechi, Chege: 4.02 (B-)
# - Oiye, Fredrick Ogutu,, Mr.: 4.02 (B)
# - Ogunde, Jane  Awuor: 4.00 (B)
# - S   Maina, Ann Wambui: 4.00 (C+)
# - Omolo, Calvin Andeve: 3.99 (B+)
# - Githua, Oscar Wanyutu: 3.99 (C)
# - Ogutu, Emily Atieno: 3.97 (B-)
# - Karanja, Moses Mwangi,, Mr: 3.96 (B)
# - Mairura, Christopher Joseph: 3.94 (B-)
# - Miriti, Gilbert Mugambi: 3.90 (B-)
# - Irari, Annette Wangui: 3.89 (B-)
# - Osiro, Moses Adama: 3.89 (C+)
# - Kamuri, Simon: 3.88 (B)
# - Basweti, Kevin Ogachi: 3.87 (C+)
# - Munyendo, Lincoln Were: 3.87 (C+)
# - Ndangili, Peter Munyao: 3.86 (B-)
# - Namuye, Silvester: 3.85 (C)
# - Njuguna, Lydia Nyambura: 3.84 (B-)
# - Nyarigoti, Naom Moraa: 3.78 (B-)
# - Bii, Cosmas K: 3.75 (C+)
# - Joseph, Muchina: 3.73 (C+)
# - Mbae, Justus: 3.72 (C+)
# - Koigi, Rachel Wanjiru: 3.66 (D-)
# - Machoka, Philip Gichaba: 3.64 (B-)
# - Njenga, Edward Gachangi: 3.55 (C)
#
# Query: Which instructors scored exactly 4.0?
# Instructors with scores above 4.0:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
# - Achoki, George: 4.54 (A-)
# - Koshal, Jeremiah Ntaloi_Ole: 4.54 (A)
# - Kabongah, George Odhiambo: 4.54 (A)
# - Brown, Dana Basnight: 4.53 (A)
# - Were, Jamen H.: 4.53 (A)
# - Ali, Fatuma Ahmed: 4.53 (A-)
# - Kimotho, Stephen Gichuhi: 4.53 (A)
# - Namuye, Maria: 4.52 (A)
# - Ndungu, Francis Gitonga: 4.51 (A)
# - Nakamura, Katsuji: 4.51 (A-)
# - F   Iraki, Fredrick Kang'ethe: 4.51 (A)
# - Mulindi, Patrick M.: 4.50 (A)
# - Kiai, Gachanja: 4.50 (A)
# - Wetiba, Johnson Kwanusu: 4.50 (A-)
# - Sifuna, Austin Makokha: 4.49 (A)
# - Oriedi, David Opondo: 4.49 (A)
# - Oduol, Charles: 4.49 (A)
# - Kakumu, Muema Pius: 4.48 (A-)
# - Wainaina, Gituro: 4.47 (A-)
# - Onono-Okelo, Perez A.: 4.47 (A-)
# - Noah, Naumih M.: 4.47 (A-)
# - Mbotu, Michael Mulandi: 4.46 (A)
# - Karume, Michelle Wariara: 4.46 (A-)
# - Munyi, Elijah N: 4.46 (A-)
# - Rubio Gijon, Pablo: 4.45 (A-)
# - Akuma, Samson Mainye: 4.45 (A-)
# - Nyete, Abraham Mutunga: 4.45 (B+)
# - Mosoti, Zachary: 4.45 (A-)
# - Mohamed, Abdullahi Mohamed: 4.45 (A-)
# - Getecha, Ciru W.: 4.44 (A)
# - Sikolia, Geoffrey Serede,, Dr.: 4.44 (A)
# - Gatumo, Francis Mambo: 4.44 (A-)
# - Ndegwa, Joyce Watetu: 4.43 (A)
# - Bwire, Albert C.: 4.43 (A-)
# - Oteri, Malack Omae: 4.43 (A-)
# - Mburu, Esther Njambi: 4.43 (A)
# - Maore, Stephen K.: 4.43 (A-)
# - Kibet, Eric M.: 4.43 (A-)
# - Ondieki, Benard Odhiambo: 4.43 (A-)
# - Ylonen, Aleksi Erik: 4.42 (A-)
# - S   Kiruthu, Lucy Nyaguthii: 4.42 (A)
# - Ogore, Fredrick Michae: 4.42 (A-)
# - Simiyu, Lucy: 4.42 (A-)
# - Mutisya Mutungi, Mary Mumbua: 4.42 (A-)
# - Kabacho, Mwangi: 4.42 (B+)
# - Gachukia, Jennifer Wangari: 4.41 (A)
# - Oranga, James Odhiambo: 4.41 (A)
# - Musebe, Edward Achieng: 4.41 (A-)
# - F   Munene, Macharia: 4.41 (A-)
# - Rintari, Ann Wanjiku: 4.40 (A-)
# - Mwangi, Jonathan Maina: 4.40 (A-)
# - Ndirangu, Dalton: 4.40 (B)
# - Mage, Grace Nduta: 4.40 (A-)
# - Kioni, Benson Muthoga: 4.40 (A-)
# - Gromov, Mikhail D.: 4.40 (A-)
# - Githigaro, John Mwangi: 4.40 (A-)
# - Opondo, Mary Awuor: 4.40 (A-)
# - F   Wambalaba, Francis: 4.40 (A)
# - Njoroge, Joseph: 4.39 (A-)
# - Ogola, Mary Ganga: 4.39 (B+)
# - Awuor, Quin Elizabeth: 4.39 (A-)
# - S   Mutune, Loraine: 4.39 (A-)
# - Mutwiri, Marion Kirumba: 4.39 (A-)
# - Mule, Daniel: 4.39 (A-)
# - Mbugua, Wanjiku: 4.39 (A-)
# - Kiaye, Mary A.: 4.38 (A-)
# - Kamau, Joseph: 4.38 (A-)
# - Githiri, John Gitonga: 4.38 (A-)
# - Nyarige, Pamela Kwamboka: 4.38 (A-)
# - Njuguna, Joseph Kimani: 4.38 (A-)
# - Njenga, Kefah Muiruri: 4.38 (B+)
# - Muniafu, Max Maina: 4.38 (A-)
# - Milton, Obote J.: 4.38 (B+)
# - Kakai, Pius Wanyonyi: 4.38 (A-)
# - Mbatia, Betty Nyambura: 4.38 (A)
# - Scott, Bellows J: 4.38 (B+)
# - Njuguna, Amos Gitau: 4.38 (B)
# - Muendo, Daniel: 4.38 (A-)
# - Kiai, Alice Wanjira: 4.38 (A-)
# - Ondiek, Collins Oduor: 4.37 (A-)
# - Wangui, Ruth Njeri: 4.37 (A-)
# - Sungi, Simeon P.: 4.37 (A-)
# - Wafula, Maurine Maraka: 4.37 (A-)
# - Ouma, Zackayo Omolo: 4.37 (A-)
# - Kuria,, John: 4.37 (A-)
# - Akach, Joyce Akinyi: 4.37 (A-)
# - Ouma,, Judy Aluoch: 4.37 (A-)
# - Nginye, Michael Gichangi: 4.37 (B)
# - Ndungu, Tabitha K.: 4.37 (B+)
# - Njihia, David Thiru: 4.36 (B+)
# - Magut, Zuhra C.: 4.36 (A)
# - Karimi, James Mark,, Ngari: 4.36 (B+)
# - Kangu, Maureen: 4.36 (A-)
# - Webbo, Roselynne Kyambi: 4.36 (B+)
# - Kobuthi, Edward N.: 4.36 (B+)
# - Githinji, Stanley Muturi,, Dr.: 4.35 (A-)
# - Gichaga, Lucy Wanjiku: 4.35 (B+)
# - Mburu, Martin: 4.35 (A-)
# - Aloo, Linus Alwal: 4.35 (A-)
# - Linge, Teresia K.K.: 4.35 (A-)
# - Katete, George Onyango: 4.35 (A-)
# - Ireri, Kioko: 4.35 (B+)
# - F   Munywoki, Samson: 4.35 (A-)
# - Andango, Elizabeth: 4.35 (A-)
# - F   Buyu, Matthew: 4.35 (A)
# - Amuhaya, Edith Khavwajira: 4.35 (A-)
# - Maima, Apollo Odhiambo: 4.35 (A-)
# - Kimani, Joan Wanjiru: 4.35 (B+)
# - Misawo, Florence Awuor: 4.34 (A-)
# - Ndungu, Pauline W.: 4.34 (B+)
# - Ogendi, Paul: 4.34 (A-)
# - Mashiwa, Maurice: 4.34 (A-)
# - Akosa, E. Wambalaba: 4.34 (A-)
# - Mutanu, Leah: 4.34 (A-)
# - Ongecha, Francisca Atieno: 4.34 (A)
# - Owilla, Hesbon Hansen: 4.33 (A-)
# - Kihara, Michael: 4.33 (A-)
# - Kayeyia, Ernest Madara: 4.33 (A-)
# - Gachie, Richard K.: 4.33 (A-)
# - Behr, Agnes Wanjiru: 4.33 (B+)
# - Awuor, Emmanuel: 4.33 (A-)
# - Amwayi, Oliver Shitanda: 4.33 (A-)
# - Owino, Edward Otieno: 4.32 (A-)
# - Mwangi, William K.: 4.32 (B+)
# - Musau, Josephine Ndanu: 4.32 (B)
# - Matula, Phylisters Daizy: 4.32 (B+)
# - Otieno, Pauline Adhiambo: 4.31 (A-)
# - Macharia, Jimmy: 4.31 (B)
# - Kidaha, Alfred Usagi: 4.31 (B+)
# - Bironga, Sophia Moraa: 4.31 (A-)
# - Njoroge, Martin Chege: 4.31 (B+)
# - Musuva, Gladys Mwende: 4.31 (B+)
# - Munyae, Margaret M.: 4.31 (B+)
# - Muindi, Benjamin: 4.31 (B+)
# - Owuor, Benard O: 4.30 (A-)
# - Ndero, Peter K.: 4.30 (B+)
# - Odaba, Dan Noel: 4.30 (B+)
# - Mbole, Elizabeth M.: 4.30 (B+)
# - S   Kiptum, Purity Jebotibin: 4.30 (B)
# - Ochola, Phares B: 4.30 (B+)
# - Njoroge, Simon Githaiga: 4.30 (B+)
# - Muindi, Peter M.: 4.30 (B+)
# - Githinji, Keziah Wangui,, Ms.: 4.30 (B+)
# - Odhiambo, Terry J.: 4.30 (B)
# - Ochieng', Robi Koki: 4.29 (B)
# - Kamau, Sheila Wanjiku: 4.29 (B+)
# - Kamanu, Timothy_Kevin Kuria: 4.29 (B+)
# - Kavoo, Mark Kavoo: 4.29 (B+)
# - Asembo, Kenedy Onyango: 4.29 (B+)
# - Gitahi, Jesse Elikanah_Machirah: 4.28 (B)
# - Nyakundi, Jane: 4.28 (B+)
# - Kariuki, Lucy Nyawira: 4.28 (B+)
# - Telewa, Christabel: 4.28 (B+)
# - Karoki, Samuel Githinji: 4.28 (A-)
# - Ahenda, John Ang'udi: 4.28 (B+)
# - Muturi, Lucy N.: 4.28 (A-)
# - Waga, Fred: 4.27 (A-)
# - Okanda, Paul M: 4.27 (A-)
# - Nyaanga, Gideon Nyamweya: 4.27 (B+)
# - Joseph, Bertha B: 4.27 (B+)
# - Njeru, Godwin Kinyua: 4.27 (B)
# - Muriu, Marylyn Doreen: 4.26 (B+)
# - Okech, Timothy C.: 4.26 (A)
# - Nginda, Ronald Robert_Abwova: 4.26 (B+)
# - Muliro, Wilfred Nasong'o: 4.26 (B+)
# - Mbithi, Jonathan Ndolo: 4.26 (B+)
# - Terefe, Ermias Mergia: 4.26 (B-)
# - Kimathi, George Eliphas: 4.26 (B+)
# - Wachana, Paul: 4.25 (B)
# - Sule, Odhiambo F.E.: 4.25 (B)
# - Macharia, Hannah Muthoni: 4.25 (B)
# - Jefwa, Judith Jai_Jaleha: 4.25 (B)
# - Mulwa, Harrison Munyao: 4.25 (B+)
# - Newa, Fred Omondi: 4.25 (A-)
# - Kalunda, Elizabeth Nthambi: 4.25 (B+)
# - Gatauwa,, James M.: 4.25 (B+)
# - Maumo, Leonard Oluoch: 4.25 (B+)
# - Bosire, Julius Ombui,, Dr.: 4.24 (A-)
# - Nyaga, Nancy Ng'endo: 4.24 (B+)
# - Maina, Muchara Dr: 4.24 (B+)
# - Ireri, Niceta Wanja: 4.24 (B+)
# - Mohamed, Hussein Abdi: 4.24 (A-)
# - Onditi, Tom: 4.24 (B)
# - Owili, Florence Akinyi: 4.23 (B)
# - Otieno, Symon_Peter Victor: 4.23 (B)
# - Mbere, Sarah Wanjiru: 4.23 (B+)
# - Gitoho, Salome Wanjiru: 4.23 (B)
# - Cheluget, Elizabeth Jepchumba: 4.23 (B)
# - Okanya, Patrick Wafula_Simiyu: 4.23 (B+)
# - Nyambati, Grace K: 4.23 (B+)
# - Wamuyu, Patrick Kanyi: 4.23 (B)
# - Wangai, Njoroge Mambo: 4.22 (B)
# - Muriithi, Jane Gathigia: 4.22 (B+)
# - Mohamed, Mwanashehe S.: 4.22 (B+)
# - Mbugua, Levi Ng'ang'a: 4.22 (B+)
# - Khadioli, Nancy: 4.22 (B)
# - K'aol, George O.: 4.22 (A-)
# - Awuor, Anita Margaret: 4.22 (B+)
# - Odek, Anthony W.: 4.21 (B+)
# - Ogola, Jacob Owuor: 4.21 (B+)
# - Kahiri, Caroline Njeri,, Dr.: 4.21 (B)
# - Ambiyo, Sarah: 4.21 (B)
# - Newa, Elsie Opiyo: 4.21 (B)
# - Kirui, Gideon Kipng'eno: 4.21 (B)
# - Mwakina, Rozina Munna: 4.20 (B+)
# - Lio, Sammy A.N.: 4.20 (A-)
# - Gachanga, Esther Wanjiru: 4.20 (B+)
# - Gachago, Philip Muriithi: 4.20 (B+)
# - F   Veney, Cassandra Rachel: 4.20 (A-)
# - Waithima, Charity Wangui: 4.19 (B+)
# - Ouma,, Duncan Ochieng: 4.19 (B)
# - Ndiege, Joshua Rumo: 4.18 (B+)
# - Mbugua, John Chege: 4.18 (B+)
# - Gathua, Michael M.: 4.18 (B)
# - Panchani, Roopam Lalji: 4.18 (B+)
# - Defersha, Amsalu Degu: 4.17 (B)
# - Nyaribo, Cyprian Mose: 4.17 (B)
# - Mwangi, Peterson Kimiru: 4.17 (B+)
# - Muchiri, Catherine Wanjiru: 4.17 (B+)
# - Kinuthia, Annie Njoki: 4.17 (B)
# - Afundi, Patrick Omuhinda: 4.17 (B)
# - Ng'eno, Weldon Kibet: 4.17 (B)
# - Omondi, Daniel Onyango: 4.16 (B)
# - Ngugi, Wilson Mbugua: 4.16 (B)
# - Mirichii, John Mwaniki: 4.16 (B)
# - Karugu, Mureithi: 4.16 (B)
# - Nduati, Gidraph J.: 4.15 (B)
# - Kigwilu, Peter Changilwa: 4.15 (B+)
# - Muriithi, Petronilla Muthoni: 4.15 (B+)
# - Mwangi, Isaac: 4.15 (B-)
# - Baraza, Cyrus M: 4.15 (B)
# - Oyaro, Kepha N._Makori: 4.15 (B)
# - Nderu, Lawrence: 4.14 (B)
# - Obbanda, Luka Epainito: 4.13 (B+)
# - Mbugua, Peter Getyngo: 4.13 (B)
# - Oyigo, Josephat DR: 4.13 (B)
# - Njui, Francis: 4.12 (B)
# - Njeri, Teresia: 4.12 (B)
# - Wainaina, Samuel: 4.12 (B)
# - Mwalili, Tobias Mbithi: 4.12 (B)
# - Kogo, Vincent Kibet: 4.12 (B)
# - Njogu, Peter Mbugua: 4.12 (B)
# - Omollo, Joseph Owade: 4.11 (B)
# - Okallo, Dick Daniel: 4.11 (B+)
# - Kimani, Larry M: 4.11 (B)
# - Kaluyu, Veronicah: 4.11 (B)
# - Odoyo, Fredrick: 4.10 (B)
# - Oketch, Omondi: 4.10 (B+)
# - Nyabere, Emily: 4.10 (B)
# - Makhaso, Byron Chesoli: 4.09 (B+)
# - Owuor, John David_Ouma: 4.09 (B+)
# - Onyango, Resila: 4.09 (B)
# - Mwangi, Henry Njogo: 4.09 (C+)
# - Maranga,, Vincent Nyamari: 4.08 (B)
# - Were, Jane N.: 4.08 (B)
# - Gisore, Billiah N.: 4.07 (B+)
# - Nyamasyo, Eunice A.: 4.07 (B)
# - Odongo, Elizabeth Amwayi: 4.06 (B)
# - Onsomu, Clive Mochiemo: 4.06 (B+)
# - Maganda, Willis Otieno: 4.05 (B)
# - Odendo, Moses: 4.05 (B)
# - Obila, Onyango James,, Mr.: 4.04 (B)
# - Nyambegera, Stephen Morangi: 4.04 (B-)
# - Otiende, Noah Ochieng: 4.04 (B)
# - Njoroge, Margaret: 4.04 (B-)
# - Magero, Patrick L.K: 4.04 (B)
# - Arasa, Josephine: 4.04 (A-)
# - Nyong'o, Kwame o: 4.04 (B)
# - Ogada, Agnes Owuor: 4.03 (A-)
# - Mwaniki, Moses: 4.03 (B)
# - Wangechi, Chege: 4.02 (B-)
# - Oiye, Fredrick Ogutu,, Mr.: 4.02 (B)
#
# Query: Which instructors got an A?
# Instructors with grade A:
# - Sikolia, Geoffrey Serede,, Dr.: 4.75
# - Macharia, Jimmy: 4.71
# - Kamau, Joseph: 4.71
# - Ali, Fatuma Ahmed: 4.71
# - Nguru, Faith Wariara: 4.70
# - Kimotho, Stephen Gichuhi: 4.70
# - Sifuna, Austin Makokha: 4.64
# - Gachukia, Jennifer Wangari: 4.63
# - Mwangi, Jonathan Maina: 4.60
# - Adan, Ali: 4.60
# - Wachana, Paul: 4.59
# - Mwilu, Asha Ahmed: 4.59
# - Mulindi, Patrick M.: 4.59
# - Ylonen, Aleksi Erik: 4.58
# - Wetiba, Johnson Kwanusu: 4.58
# - Mburu, Esther Njambi: 4.58
# - Nyete, Abraham Mutunga: 4.58
# - Munyi, Elijah N: 4.57
# - Achoki, George: 4.56
# - Oranga, James Odhiambo: 4.56
# - Nginye, Michael Gichangi: 4.56
# - Nakamura, Katsuji: 4.56
# - Karimi, James Mark,, Ngari: 4.55
# - Ondiek, Collins Oduor: 4.55
# - Kimani, Nathan Muya: 4.55
# - Karume, Michelle Wariara: 4.55
# - Kakumu, Muema Pius: 4.55
# - Mbugua, Paul Mungai: 4.54
# - Njeru, Godwin Kinyua: 4.54
# - Njenga, Kefah Muiruri: 4.54
# - Mutisya Mutungi, Mary Mumbua: 4.54
# - Mbotu, Michael Mulandi: 4.54
# - Koshal, Jeremiah Ntaloi_Ole: 4.54
# - Kabongah, George Odhiambo: 4.54
# - Sule, Odhiambo F.E.: 4.53
# - Ndirangu, Dalton: 4.53
# - Kabacho, Mwangi: 4.53
# - Gatumo, Francis Mambo: 4.53
# - Brown, Dana Basnight: 4.53
# - Were, Jamen H.: 4.53
# - Scott, Bellows J: 4.53
# - S   Kiruthu, Lucy Nyaguthii: 4.52
# - Ogada, Agnes Owuor: 4.52
# - Noah, Naumih M.: 4.52
# - Njuguna, Amos Gitau: 4.52
# - Namuye, Maria: 4.52
# - F   Buyu, Matthew: 4.52
# - Ndungu, Francis Gitonga: 4.51
# - Musebe, Edward Achieng: 4.51
# - Mbatia, Betty Nyambura: 4.51
# - Kariuki, Lucy Nyawira: 4.51
# - F   Iraki, Fredrick Kang'ethe: 4.51
# - Okech, Timothy C.: 4.50
# - Ogore, Fredrick Michae: 4.50
# - Ogola, Mary Ganga: 4.50
# - Njoroge, Joseph: 4.50
# - Mohamed, Abdullahi Mohamed: 4.50
# - Mbugua, Wanjiku: 4.50
# - Magut, Zuhra C.: 4.50
# - Kiai, Gachanja: 4.50
# - Getecha, Ciru W.: 4.50
# - Ahenda, John Ang'udi: 4.50
# - Rubio Gijon, Pablo: 4.49
# - Oteri, Malack Omae: 4.49
# - Oriedi, David Opondo: 4.49
# - Onditi, Tom: 4.49
# - Oduol, Charles: 4.49
# - Gitahi, Jesse Elikanah_Machirah: 4.49
# - Akuma, Samson Mainye: 4.49
# - Ongecha, Francisca Atieno: 4.48
# - Njihia, David Thiru: 4.48
# - Ndegwa, Joyce Watetu: 4.48
# - Mosoti, Zachary: 4.48
# - Githinji, Stanley Muturi,, Dr.: 4.48
# - F   Wambalaba, Francis: 4.48
#
# Query: Show me all with grade B
# Instructors with grade B:
# - Wangai, Njoroge Mambo: 4.17
# - Ondiek, Collins Oduor: 4.17
# - Njoroge, Margaret: 4.17
# - Nginye, Michael Gichangi: 4.17
# - Mulwa, Harrison Munyao: 4.17
# - Mohamed, Mwanashehe S.: 4.17
# - Machoka, Philip Gichaba: 4.17
# - Macharia, Hannah Muthoni: 4.17
# - Kinuthia, Annie Njoki: 4.17
# - Gathua, Michael M.: 4.17
# - Ambiyo, Sarah: 4.17
# - Defersha, Amsalu Degu: 4.17
# - Scott, Bellows J: 4.16
# - S   Kiptum, Purity Jebotibin: 4.16
# - Panchani, Roopam Lalji: 4.16
# - Omondi, Daniel Onyango: 4.16
# - Odhiambo, Terry J.: 4.16
# - Ngugi, Wilson Mbugua: 4.16
# - Mirichii, John Mwaniki: 4.16
# - Gitoho, Salome Wanjiru: 4.16
# - Oiye, Fredrick Ogutu,, Mr.: 4.15
# - Njuguna, Amos Gitau: 4.15
# - Ndirangu, Dalton: 4.15
# - Baraza, Cyrus M: 4.15
# - Mbugua, Wanjiku: 4.14
# - Kirui, Gideon Kipng'eno: 4.14
# - Kavoo, Mark Kavoo: 4.14
# - Ahenda, John Ang'udi: 4.14
# - Khadioli, Nancy: 4.13
# - Sikolia, Geoffrey Serede,, Dr.: 4.13
# - Oyaro, Kepha N._Makori: 4.13
# - Otiende, Noah Ochieng: 4.13
# - Nyambegera, Stephen Morangi: 4.13
# - Mwangi, Peterson Kimiru: 4.13
# - Muriithi, Jane Gathigia: 4.13
# - Njui, Francis: 4.12
# - Njeri, Teresia: 4.12
# - Odaba, Dan Noel: 4.12
# - Mwalili, Tobias Mbithi: 4.12
# - Kariuki, Lucy Nyawira: 4.12
# - Kamuri, Simon: 4.12
# - F   Buyu, Matthew: 4.12
# - Njogu, Peter Mbugua: 4.12
# - Ouma,, Duncan Ochieng: 4.11
# - Ogola, Jacob Owuor: 4.11
# - Ochieng', Robi Koki: 4.11
# - Musau, Josephine Ndanu: 4.11
# - Kimani, Larry M: 4.11
# - Gitahi, Jesse Elikanah_Machirah: 4.11
# - Afundi, Patrick Omuhinda: 4.10
# - Owuor, John David_Ouma: 4.10
# - Odoyo, Fredrick: 4.10
# - Mbugua, Peter Getyngo: 4.10
# - Kigwilu, Peter Changilwa: 4.10
# - Wamuyu, Patrick Kanyi: 4.10
# - Nyabere, Emily: 4.10
# - Odendo, Moses: 4.09
# - Lio, Sammy A.N.: 4.09
# - Nduati, Gidraph J.: 4.09
# - Were, Jane N.: 4.09
# - Wangechi, Chege: 4.09
# - Wachana, Paul: 4.09
# - Onyango, Resila: 4.09
# - Okech, Timothy C.: 4.09
# - Obbanda, Luka Epainito: 4.09
# - Newa, Fred Omondi: 4.09
# - Muturi, Lucy N.: 4.09
# - Muriithi, Petronilla Muthoni: 4.09
# - Owili, Florence Akinyi: 4.08
# - Onditi, Tom: 4.08
# - Ndiege, Joshua Rumo: 4.08
# - Nderu, Lawrence: 4.08
# - Maranga,, Vincent Nyamari: 4.08
# - Karugu, Mureithi: 4.08
# - Kahiri, Caroline Njeri,, Dr.: 4.08
# - Omollo, Joseph Owade: 4.08
# - Newa, Elsie Opiyo: 4.07
# - Oyigo, Josephat DR: 4.07
# - Nyaribo, Cyprian Mose: 4.07
# - Njeru, Godwin Kinyua: 4.07
# - Ng'eno, Weldon Kibet: 4.07
# - Koigi, Rachel Wanjiru: 4.07
# - Bosire, Julius Ombui,, Dr.: 4.07
# - Nyamasyo, Eunice A.: 4.07
# - Odongo, Elizabeth Amwayi: 4.06
# - Maganda, Willis Otieno: 4.05
# - Osiro, Moses Adama: 4.05
# - Muchiri, Catherine Wanjiru: 4.05
# - Cheluget, Elizabeth Jepchumba: 4.05
# - Obila, Onyango James,, Mr.: 4.04
# - Magero, Patrick L.K: 4.04
# - Jefwa, Judith Jai_Jaleha: 4.04
# - Githua, Oscar Wanyutu: 4.04
# - Nyong'o, Kwame o: 4.04
# - Wainaina, Samuel: 4.03
# - Mohamed, Hussein Abdi: 4.03
# - Kaluyu, Veronicah: 4.03
# - Gachanga, Esther Wanjiru: 4.03
# - F   Veney, Cassandra Rachel: 4.03
# - Basweti, Kevin Ogachi: 4.03
# - Mwaniki, Moses: 4.03
# - Kogo, Vincent Kibet: 4.03
# - Otieno, Symon_Peter Victor: 4.02
# - Okallo, Dick Daniel: 4.02
# - Kamau, Joseph: 4.02
# - Macharia, Jimmy: 4.01
# - S   Maina, Ann Wambui: 4.00
# - Ogunde, Jane  Awuor: 4.00
# - Munyendo, Lincoln Were: 3.99
# - Karanja, Moses Mwangi,, Mr: 3.99
# - Sule, Odhiambo F.E.: 3.98
# - Makhaso, Byron Chesoli: 3.98
#
# Query: Who received a C?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Top 10 performers
# Top 10 performers:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
# - Achoki, George: 4.54 (A-)
# - Koshal, Jeremiah Ntaloi_Ole: 4.54 (A)
# - Kabongah, George Odhiambo: 4.54 (A)
# - Brown, Dana Basnight: 4.53 (A)
# - Were, Jamen H.: 4.53 (A)
#
# Query: Top 3 instructors this semester
# Top 3 performers:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
#
# Query: Top 20 performers
# Top 20 performers:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
# - Achoki, George: 4.54 (A-)
# - Koshal, Jeremiah Ntaloi_Ole: 4.54 (A)
# - Kabongah, George Odhiambo: 4.54 (A)
# - Brown, Dana Basnight: 4.53 (A)
# - Were, Jamen H.: 4.53 (A)
# - Ali, Fatuma Ahmed: 4.53 (A-)
# - Kimotho, Stephen Gichuhi: 4.53 (A)
# - Namuye, Maria: 4.52 (A)
# - Ndungu, Francis Gitonga: 4.51 (A)
# - Nakamura, Katsuji: 4.51 (A-)
# - F   Iraki, Fredrick Kang'ethe: 4.51 (A)
# - Mulindi, Patrick M.: 4.50 (A)
# - Kiai, Gachanja: 4.50 (A)
# - Wetiba, Johnson Kwanusu: 4.50 (A-)
# - Sifuna, Austin Makokha: 4.49 (A)
#
# Query: What feedback did students give Afundi?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Summarize feedback for Mohamed
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: Show sample feedback for Odoyo
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.
#
# Query: How did Alo perform?
# Based on evaluations, Aloo, Linus Alwal received a grade of A- with a mean score of 4.45.
# Based on evaluations, Aloo, Linus Alwal received a grade of A- with a mean score of 4.34.
# Based on evaluations, Aloo, Linus Alwal received a grade of B+ with a mean score of 4.26.
# Based on evaluations, Gitoho, Salome Wanjiru received a grade of B with a mean score of 4.16.
# Based on evaluations, Gitoho, Salome Wanjiru received a grade of B+ with a mean score of 4.31.
# Based on evaluations, Koshal, Jeremiah Ntaloi_Ole received a grade of A with a mean score of 4.54.
#
# Query: Tell me about Basweti
# Based on evaluations, Basweti, Kevin Ogachi received a grade of C+ with a mean score of 3.77.
# Based on evaluations, Basweti, Kevin Ogachi received a grade of C+ with a mean score of 3.82.
# Based on evaluations, Basweti, Kevin Ogachi received a grade of B with a mean score of 4.03.
#
# Query: Evaluation for a nonexistent instructor
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, or top performers.

# %% [markdown]
# ok so it worked. It just broke down on knowing who got a C and on the feedback questions on students and what feedback they gave. So its not yet capable of going over the comment and giving a summary on it based on positive, neutral and negative. So that means we have to move to sentiment analysis, topic analysis and indetification possibly with bertopic and other NLTK NLP libraries and work with hugging face so that the response is in a consultant manner(as a side one, once we have something basic, I would like to do research on how a consultant would speak and give out feedback in sth that is closely related to this field). But atleast it knows when theres no instructor present, we just have to adjust the output it gives when its presented with such a question. This is the new output.

# %%
# So lets patch that letter intent section
import re

def parse_intent(user_input):
    text = user_input.lower()

    # Top performers
    m_top = re.search(r"top\s+(\d+)", text)
    if m_top:
        return {"intent": "top_ranked", "count": int(m_top.group(1))}

    # Score filters
    m_above = re.search(r"(above|greater than|over)\s*(\d+(\.\d+)?)", text)
    if m_above:
        return {"intent": "score_filter", "op": ">", "threshold": float(m_above.group(2))}

    m_below = re.search(r"(below|less than|under)\s*(\d+(\.\d+)?)", text)
    if m_below:
        return {"intent": "score_filter", "op": "<", "threshold": float(m_below.group(2))}

    m_equal = re.search(r"(equal|exactly|=|is)\s*(\d+(\.\d+)?)", text)
    if m_equal:
        return {"intent": "score_filter", "op": "=", "threshold": float(m_equal.group(2))}

    # Grade filters (A/B/C/D/F with optional + or -)
    m_grade = re.search(r"(grade|got\s+an|received\s+an|with\s+grade|who\s+received)\s*([abcdf])([+-]?)\b", text)
    if m_grade:
        grade = (m_grade.group(2) + m_grade.group(3)).upper()
        return {"intent": "grade_filter", "grade": grade}

    # Feedback intents
    feedback_kws = [
        "what feedback did", "summarize feedback", "sample feedback", "student comments",
        "qualitative feedback", "how did students feel", "what did students say"
    ]
    if any(kw in text for kw in feedback_kws):
        return {"intent": "feedback", "name": user_input}

    # Instructor lookup
    lookup_kws = ["how did", "tell me about", "results for", "evaluation of", "performance of", "review of", "what’s the evaluation for"]
    if any(kw in text for kw in lookup_kws):
        return {"intent": "lookup", "name": user_input}

    return {"intent": "unknown"}

# %%
# Then we adjust the grade filtering
def get_instructors_by_grade(grade):
    query = """
    SELECT f.full_name, ROUND(AVG(e.mean_score), 2) AS avg_score
    FROM Faculty f
    JOIN TeachingAssignments ta ON f.faculty_id = ta.faculty_id
    JOIN Sections s ON ta.section_id = s.section_id
    JOIN Evaluations e ON s.section_id = e.section_id
    WHERE e.letter_grade = ?
    GROUP BY f.full_name
    ORDER BY avg_score DESC
    """
    cursor.execute(query, (grade,))
    rows = cursor.fetchall()
    if not rows:
        return f"No instructors found with grade {grade}."
    lines = [f"- {name}: {score:.2f}" for name, score in rows]
    return "Instructors with grade " + grade + ":\n" + "\n".join(lines)

# %%
# Lets adjust the fuzzy matchgin with a feedback loop
from rapidfuzz import fuzz

def find_best_faculty(user_input, threshold=70):
    q = user_input.lower()
    cursor.execute("SELECT faculty_id, full_name FROM Faculty")
    rows = cursor.fetchall()
    best, best_score = None, -1
    for fid, name in rows:
        sim = max(fuzz.partial_ratio(q, name.lower()), fuzz.token_set_ratio(q, name.lower()))
        if sim > best_score:
            best_score = sim
            best = (fid, name)
    return best if best_score >= threshold else None

def get_feedback_rows(fid, limit=1000):
    cursor.execute("""
        SELECT comment_text
        FROM FeedbackCorpus
        WHERE faculty_id = ?
    """, (fid,))
    return [r[0] for r in cursor.fetchall()]

# %% [markdown]
# # Sentiment Analysis

# %%
# Lets start off with some basic sentiment analysis
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

def sentiment_summary(comments):
    scores = [sia.polarity_scores(c)["compound"] for c in comments if c and c.strip()]
    if not scores:
        return {"avg": 0, "pos_pct": 0, "neg_pct": 0, "neu_pct": 0}
    pos = sum(1 for s in scores if s > 0.05)
    neg = sum(1 for s in scores if s < -0.05)
    neu = len(scores) - pos - neg
    total = len(scores)
    return {
        "avg": sum(scores) / total,
        "pos_pct": pos / total,
        "neg_pct": neg / total,
        "neu_pct": neu / total
    }
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Some topic hints
import re
from collections import Counter

def keyword_hints(comments, top_k=5):
    # naive keyword extraction: split, lowercase, filter short/common words
    stop = set(["the","and","to","of","in","for","on","is","was","are","with","that","this","it","as","at","by","from","or","an","be","but","not"])
    tokens = []
    for c in comments:
        words = re.findall(r"[a-zA-Z][a-zA-Z'-]+", c.lower())
        tokens.extend(w for w in words if len(w) > 3 and w not in stop)
    common = Counter(tokens).most_common(top_k)
    return [w for w, _ in common]

# %%
# Then lets work on the feedback response in a consultant style manner
def feedback_response(user_input, sample_n=3):
    match = find_best_faculty(user_input)
    if not match:
        return "I couldn’t find that instructor. Try a full or closer name."
    fid, full_name = match
    comments = get_feedback_rows(fid)
    if not comments:
        return f"No qualitative feedback available for {full_name}."

    sent = sentiment_summary(comments)
    keys = keyword_hints(comments)

    # pick sample quotes: one positive, one neutral, one negative if available
    pos_q = next((c for c in comments if sia.polarity_scores(c)["compound"] > 0.3), None)
    neg_q = next((c for c in comments if sia.polarity_scores(c)["compound"] < -0.3), None)
    neu_q = next((c for c in comments if -0.05 <= sia.polarity_scores(c)["compound"] <= 0.05), None)

    lines = [
        f"{full_name}: feedback is mostly "
        + ("positive" if sent["avg"] > 0.1 else "mixed" if abs(sent['avg']) <= 0.1 else "negative")
        + f" (pos {sent['pos_pct']:.0%}, neu {sent['neu_pct']:.0%}, neg {sent['neg_pct']:.0%}).",
        f"Common themes: {', '.join(keys) or 'none detected'}."
    ]

    samples = []
    if pos_q: samples.append(f"- Strength: “{pos_q}”")
    if neu_q: samples.append(f"- Neutral: “{neu_q}”")
    if neg_q: samples.append(f"- Improvement: “{neg_q}”")

    if samples:
        lines.append("Sample comments:")
        lines.extend(samples)

    return "\n".join(lines)

# %%
# Then we integrate the function in
def get_consultant_response(user_input):
    intent = parse_intent(user_input)

    if intent["intent"] == "lookup":
        return lookup_instructor_evaluation(intent["name"])
    if intent["intent"] == "top_ranked":
        return get_top_performers(intent["count"])
    if intent["intent"] == "score_filter":
        return get_instructors_by_score(intent["op"], intent["threshold"])
    if intent["intent"] == "grade_filter":
        return get_instructors_by_grade(intent["grade"])
    if intent["intent"] == "feedback":
        return feedback_response(intent["name"])

    return "I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback."

# %%
def get_instructors_by_score(op, threshold):
    """
    Return instructors filtered by score threshold with operator >, <, or =.
    """
    # Base query with aggregation
    base_query = """
    SELECT f.full_name, ROUND(AVG(e.mean_score), 2) AS avg_score, e.letter_grade
    FROM Faculty f
    JOIN TeachingAssignments ta ON f.faculty_id = ta.faculty_id
    JOIN Sections s ON ta.section_id = s.section_id
    JOIN Evaluations e ON s.section_id = e.section_id
    GROUP BY f.full_name
    HAVING avg_score {op} ?
    ORDER BY avg_score DESC
    """.format(op=op)

    cursor.execute(base_query, (threshold,))
    rows = cursor.fetchall()

    if not rows:
        return f"No instructors scored {op} {threshold}."

    header = f"Instructors with scores {op} {threshold}:"
    lines = [f"- {name}: {score:.2f} ({grade})" for name, score, grade in rows]
    return header + "\n" + "\n".join(lines)

# %% [markdown]
# ayt so weve made new changes and now i wanna stress test the system with the following questions
#
# Instructor Lookup
# - “Tell me about Afundi” → direct surname lookup.
# - “Evaluation of Mohamed, Mwanashehe S.” → full name with comma.
# - “Results for Odoyo” → surname only.
# - “How did Gitahi perform this semester?” → natural phrasing.
# - “Review of Gatumo, Francis Mambo” → synonym trigger.
#
# 🔹 Score Filters
# - “Who scored above 4.5?” → should list top scorers.
# - “List instructors with scores below 3.5” → test the new < operator.
# - “Which instructors scored exactly 4.0?” → equality case.
# - “Show me instructors with scores greater than 4.2” → alternate phrasing.
#
# 🔹 Grade Filters
# - “Which instructors got an A?” → should return grade A.
# - “Who received a C?” → test grade C.
# - “Show me all with grade B+” → plus/minus handling.
# - “List instructors with grade D” → lower performers.
#
# 🔹 Feedback Queries
# - “What feedback did students give Afundi?” → fuzzy match + sentiment summary.
# - “Summarize feedback for Mohamed” → sentiment + themes.
# - “Show sample feedback for Odoyo” → sample quotes.
# - “How did students feel about Gitahi?” → synonym trigger.
# - “Qualitative feedback for Gatumo” → alternate phrasing.
#
# 🔹 Ranking
# - “Top 5 performers” → small list.
# - “Top 10 performers” → larger list.
# - “Top 20 instructors this semester” → stress test with big limit.
#
# 🔹 Edge Cases
# - “Tell me about Alo” → fuzzy match to Aloo.
# - “Evaluation for Basweti” → partial surname.
# - “Who received a Z?” → invalid grade, should gracefully handle.
# - “Feedback for a nonexistent instructor” → should return “No instructor found.”

# %%
# Now just gotta stress test the system
# Stress test queries
test_queries = [
    "Tell me about Afundi",
    "What’s the evaluation for Mohamed, Mwanashehe S.?",
    "How did Gitahi perform?",
    "Results for Odoyo",
    "Evaluation of Gatumo, Francis Mambo",
    "Who scored above 4.8?",
    "List instructors with scores below 3.5",
    "Which instructors scored exactly 4.0?",
    "Which instructors got an A?",
    "Show me all with grade B",
    "Who received a C?",
    "Top 10 performers",
    "Top 3 instructors this semester",
    "Top 20 performers",
    "What feedback did students give Afundi?",
    "Summarize feedback for Mohamed",
    "Show sample feedback for Odoyo",
    "How did Alo perform?",   # typo test
    "Tell me about Basweti",  # partial match
    "Evaluation for a nonexistent instructor"
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: Tell me about Afundi
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Mwanashehe S. -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Owuor, John David_Ouma -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Gitahi, Jesse Elikanah_Machirah -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Odoyo, Fredrick -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Gatumo, Francis Mambo -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Oyaro, Kepha N._Makori -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ogada, Agnes Owuor -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kuria,, John -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Achoki, George -> similarity: 35.294117647058826
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Amos Gitau -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Cheluget, Elizabeth Jepchumba -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Nyabere, Emily -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Nyong'o, Kwame o -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Gachukia, Jennifer Wangari -> similarity: 34.285714285714285
# [DEBUG] Comparing: tell me about afundi vs Oriedi, David Opondo -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ndirangu, Dalton -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs Ondieki, Benard Odhiambo -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Muriithi, Petronilla Muthoni -> similarity: 51.61290322580645
# [DEBUG] Comparing: tell me about afundi vs Namuye, Silvester -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Afundi, Patrick Omuhinda -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Ahenda, John Ang'udi -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Wamuyu, Patrick Kanyi -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Ndiege, Joshua Rumo -> similarity: 41.02564102564103
# [DEBUG] Comparing: tell me about afundi vs Basweti, Kevin Ogachi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Aloo, Linus Alwal -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Oteri, Malack Omae -> similarity: 48.0
# [DEBUG] Comparing: tell me about afundi vs Nyete, Abraham Mutunga -> similarity: 47.61904761904762
# [DEBUG] Comparing: tell me about afundi vs Makhaso, Byron Chesoli -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about afundi vs Kogo, Vincent Kibet -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Gachanga, Esther Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mwalili, Tobias Mbithi -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Mutanu, Leah -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Nderu, Lawrence -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Henry Njogo -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Ondiek, Collins Oduor -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about afundi vs Githinji, Stanley Muturi,, Dr. -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Kayeyia, Ernest Madara -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Abdullahi Mohamed -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Jonathan Maina -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Mbatia, Betty Nyambura -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Okanya, Patrick Wafula_Simiyu -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Muendo, Daniel -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Muniafu, Max Maina -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Kamanu, Timothy_Kevin Kuria -> similarity: 38.297872340425535
# [DEBUG] Comparing: tell me about afundi vs Kamuri, Simon -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Kabacho, Mwangi -> similarity: 51.85185185185186
# [DEBUG] Comparing: tell me about afundi vs Gitoho, Salome Wanjiru -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Gachago, Philip Muriithi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Kimathi, George Eliphas -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Misawo, Florence Awuor -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Odendo, Moses -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mbithi, Jonathan Ndolo -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Muchiri, Catherine Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Ogola, Mary Ganga -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Namuye, Maria -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karimi, James Mark,, Ngari -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Kibet, Eric M. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Akuma, Samson Mainye -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Awuor, Emmanuel -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Ouma,, Duncan Ochieng -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kobuthi, Edward N. -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Wetiba, Johnson Kwanusu -> similarity: 32.55813953488372
# [DEBUG] Comparing: tell me about afundi vs Njui, Francis -> similarity: 45.45454545454546
# [DEBUG] Comparing: tell me about afundi vs Miriti, Gilbert Mugambi -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Maina, Muchara Dr -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Opondo, Mary Awuor -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ochola, Phares B -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Ogola, Jacob Owuor -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Musuva, Gladys Mwende -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mbere, Sarah Wanjiru -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Mosoti, Zachary -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Were, Jane N. -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Muriu, Marylyn Doreen -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Mbotu, Michael Mulandi -> similarity: 60.0
# [DEBUG] Comparing: tell me about afundi vs Nduati, Gidraph J. -> similarity: 29.629629629629626
# [DEBUG] Comparing: tell me about afundi vs Musebe, Edward Achieng -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Sule, Odhiambo F.E. -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Ogendi, Paul -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Joseph, Muchina -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Okanda, Paul M -> similarity: 35.294117647058826
# [DEBUG] Comparing: tell me about afundi vs Newa, Fred Omondi -> similarity: 45.16129032258065
# [DEBUG] Comparing: tell me about afundi vs K'aol, George O. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Getecha, Ciru W. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Ndegwa, Joyce Watetu -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kamau, Joseph -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs S   Kiruthu, Lucy Nyaguthii -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Mburu, Esther Njambi -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs F   Wambalaba, Francis -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Wainaina, Gituro -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Njenga, Edward Gachangi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Nguru, Faith Wariara -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Noah, Naumih M. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Amuhaya, Edith Khavwajira -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs Wangui, Ruth Njeri -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Wanjiku -> similarity: 46.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Kimani, Nathan Muya -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Otieno, Symon_Peter Victor -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Odhiambo, Terry J. -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Osiro, Moses Adama -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Asembo, Kenedy Onyango -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Onyango, Resila -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Kirui, Gideon Kipng'eno -> similarity: 27.77777777777778
# [DEBUG] Comparing: tell me about afundi vs Sungi, Simeon P. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Arasa, Josephine -> similarity: 27.77777777777777
# [DEBUG] Comparing: tell me about afundi vs Newa, Elsie Opiyo -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Hussein Abdi -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Peterson Kimiru -> similarity: 41.86046511627907
# [DEBUG] Comparing: tell me about afundi vs Lio, Sammy A.N. -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Kakumu, Muema Pius -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Ochieng', Robi Koki -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Magut, Zuhra C. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Gromov, Mikhail D. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Nginda, Ronald Robert_Abwova -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Mbole, Elizabeth M. -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Koshal, Jeremiah Ntaloi_Ole -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Sikolia, Geoffrey Serede,, Dr. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Gichaga, Lucy Wanjiku -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Wachana, Paul -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Ouma,, Judy Aluoch -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Ouma, Zackayo Omolo -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Okech, Timothy C. -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Onono-Okelo, Perez A. -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Owili, Florence Akinyi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Martin Chege -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Oduol, Charles -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Nyarigoti, Naom Moraa -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs F   Buyu, Matthew -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Peter Getyngo -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Ambiyo, Sarah -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Nyamasyo, Eunice A. -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Onditi, Tom -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Jefwa, Judith Jai_Jaleha -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Milton, Obote J. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kiai, Alice Wanjira -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Awuor, Quin Elizabeth -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Ogutu, Emily Atieno -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Mburu, Martin -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Oketch, Omondi -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Nyarige, Pamela Kwamboka -> similarity: 47.36842105263158
# [DEBUG] Comparing: tell me about afundi vs Njihia, David Thiru -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about afundi vs Scott, Bellows J -> similarity: 47.61904761904761
# [DEBUG] Comparing: tell me about afundi vs Rintari, Ann Wanjiku -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Kiaye, Mary A. -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Omolo, Calvin Andeve -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Irari, Annette Wangui -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Nyambati, Grace K -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Njeri, Teresia -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about afundi vs Okallo, Dick Daniel -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Andango, Elizabeth -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Akach, Joyce Akinyi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Onsomu, Clive Mochiemo -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kioni, Benson Muthoga -> similarity: 39.02439024390244
# [DEBUG] Comparing: tell me about afundi vs Kariuki, Lucy Nyawira -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Wainaina, Samuel -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Ngugi, Wilson Mbugua -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Gatauwa,, James M. -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Joseph, Bertha B -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Mirichii, John Mwaniki -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Muriithi, Jane Gathigia -> similarity: 37.2093023255814
# [DEBUG] Comparing: tell me about afundi vs Bwire, Albert C. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Bii, Cosmas K -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Owuor, Benard O -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karugu, Mureithi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Nginye, Michael Gichangi -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Mulwa, Harrison Munyao -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Akosa, E. Wambalaba -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Francis Gitonga -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about afundi vs F   Iraki, Fredrick Kang'ethe -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Adan, Ali -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Otieno, Pauline Adhiambo -> similarity: 44.99999999999999
# [DEBUG] Comparing: tell me about afundi vs Kalunda, Elizabeth Nthambi -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Kigwilu, Peter Changilwa -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Amwayi, Oliver Shitanda -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Ireri, Kioko -> similarity: 26.086956521739136
# [DEBUG] Comparing: tell me about afundi vs Nyaribo, Cyprian Mose -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kakai, Pius Wanyonyi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mutisya Mutungi, Mary Mumbua -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Njeru, Godwin Kinyua -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Mbugua, John Chege -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Mage, Grace Nduta -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Muindi, Peter M. -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Mulindi, Patrick M. -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Maranga,, Vincent Nyamari -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Terefe, Ermias Mergia -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Obbanda, Luka Epainito -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Kimani, Joan Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Macharia, Hannah Muthoni -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Maumo, Leonard Oluoch -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Joseph Kimani -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Simon Githaiga -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Mwakina, Rozina Munna -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Behr, Agnes Wanjiru -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Ylonen, Aleksi Erik -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Maganda, Willis Otieno -> similarity: 42.857142857142854
# [DEBUG] Comparing: tell me about afundi vs Ali, Fatuma Ahmed -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Gathua, Michael M. -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Muliro, Wilfred Nasong'o -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Odaba, Dan Noel -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Nyaanga, Gideon Nyamweya -> similarity: 31.818181818181813
# [DEBUG] Comparing: tell me about afundi vs Katete, George Onyango -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Pauline W. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Wangechi, Chege -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Munyi, Elijah N -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Githigaro, John Mwangi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs F   Veney, Cassandra Rachel -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Magero, Patrick L.K -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Gisore, Billiah N. -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about afundi vs Kabongah, George Odhiambo -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ng'eno, Weldon Kibet -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mashiwa, Maurice -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs F   Munene, Macharia -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Mbae, Justus -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Kavoo, Mark Kavoo -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs S   Maina, Ann Wambui -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Machoka, Philip Gichaba -> similarity: 32.55813953488372
# [DEBUG] Comparing: tell me about afundi vs Macharia, Jimmy -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Wangai, Njoroge Mambo -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs S   Mutune, Loraine -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Sifuna, Austin Makokha -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Karoki, Samuel Githinji -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Baraza, Cyrus M -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Gachie, Richard K. -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Nakamura, Katsuji -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Githinji, Keziah Wangui,, Ms. -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Omondi, Daniel Onyango -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Telewa, Christabel -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Oiye, Fredrick Ogutu,, Mr. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karanja, Moses Mwangi,, Mr -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Kidaha, Alfred Usagi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Waga, Fred -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Isaac -> similarity: 31.57894736842105
# [DEBUG] Comparing: tell me about afundi vs Mwilu, Asha Ahmed -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Bosire, Julius Ombui,, Dr. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kamau, Sheila Wanjiku -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Oranga, James Odhiambo -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Muindi, Benjamin -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Owilla, Hesbon Hansen -> similarity: 47.36842105263158
# [DEBUG] Comparing: tell me about afundi vs Mule, Daniel -> similarity: 47.61904761904761
# [DEBUG] Comparing: tell me about afundi vs Kimotho, Stephen Gichuhi -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Karume, Michelle Wariara -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Githua, Oscar Wanyutu -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Nyambegera, Stephen Morangi -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Mairura, Christopher Joseph -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Kaluyu, Veronicah -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Matula, Phylisters Daizy -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Linge, Teresia K.K. -> similarity: 30.769230769230774
# [DEBUG] Comparing: tell me about afundi vs Obila, Onyango James,, Mr. -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs Njenga, Kefah Muiruri -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Owino, Edward Otieno -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kangu, Maureen -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Maore, Stephen K. -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs S   Kiptum, Purity Jebotibin -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Were, Jamen H. -> similarity: 45.45454545454546
# [DEBUG] Comparing: tell me about afundi vs Wafula, Maurine Maraka -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Khadioli, Nancy -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Levi Ng'ang'a -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Lydia Nyambura -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kahiri, Caroline Njeri,, Dr. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Githiri, John Gitonga -> similarity: 27.77777777777778
# [DEBUG] Comparing: tell me about afundi vs Nyakundi, Jane -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Oyigo, Josephat DR -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ndangili, Peter Munyao -> similarity: 47.61904761904762
# [DEBUG] Comparing: tell me about afundi vs Maima, Apollo Odhiambo -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Gitau, Samuel -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Kimani, Larry M -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Njogu, Peter Mbugua -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Munyendo, Lincoln Were -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Odongo, Elizabeth Amwayi -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Defersha, Amsalu Degu -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Tabitha K. -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about afundi vs Mwaniki, Moses -> similarity: 30.000000000000004
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Paul Mungai -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Simiyu, Lucy -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Musau, Josephine Ndanu -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Ireri, Niceta Wanja -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Ndero, Peter K. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Awuor, Anita Margaret -> similarity: 43.90243902439025
# [DEBUG] Comparing: tell me about afundi vs Ogunde, Jane  Awuor -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Waithima, Charity Wangui -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Munyae, Margaret M. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Bironga, Sophia Moraa -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Kihara, Michael -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Margaret -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Mutwiri, Marion Kirumba -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Mwangi, William K. -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs F   Munywoki, Samson -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Joseph -> similarity: 27.27272727272727
# [DEBUG] Comparing: tell me about afundi vs Panchani, Roopam Lalji -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Omollo, Joseph Owade -> similarity: 43.24324324324324
# [DEBUG] Comparing: tell me about afundi vs Webbo, Roselynne Kyambi -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Ongecha, Francisca Atieno -> similarity: 35.55555555555556
# [DEBUG] Comparing: tell me about afundi vs Muturi, Lucy N. -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Nyaga, Nancy Ng'endo -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Brown, Dana Basnight -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Kinuthia, Annie Njoki -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kiai, Gachanja -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Ogore, Fredrick Michae -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Otiende, Noah Ochieng -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Odek, Anthony W. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Rubio Gijon, Pablo -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Koigi, Rachel Wanjiru -> similarity: 40.0
# No evaluation data found for Tell me about Afundi.
#
# Query: What’s the evaluation for Mohamed, Mwanashehe S.?
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mohamed, Mwanashehe S. -> similarity: 100.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Owuor, John David_Ouma -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gitahi, Jesse Elikanah_Machirah -> similarity: 36.065573770491795
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Odoyo, Fredrick -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gatumo, Francis Mambo -> similarity: 47.61904761904761
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oyaro, Kepha N._Makori -> similarity: 36.36363636363637
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogada, Agnes Owuor -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kuria,, John -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Achoki, George -> similarity: 35.71428571428571
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njuguna, Amos Gitau -> similarity: 34.285714285714285
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Cheluget, Elizabeth Jepchumba -> similarity: 39.13043478260869
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyabere, Emily -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyong'o, Kwame o -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gachukia, Jennifer Wangari -> similarity: 38.46153846153846
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oriedi, David Opondo -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ndirangu, Dalton -> similarity: 37.5
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ondieki, Benard Odhiambo -> similarity: 41.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muriithi, Petronilla Muthoni -> similarity: 36.73469387755102
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Namuye, Silvester -> similarity: 47.05882352941176
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Afundi, Patrick Omuhinda -> similarity: 41.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ahenda, John Ang'udi -> similarity: 41.02564102564102
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wamuyu, Patrick Kanyi -> similarity: 35.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ndiege, Joshua Rumo -> similarity: 42.10526315789473
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Basweti, Kevin Ogachi -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Aloo, Linus Alwal -> similarity: 35.29411764705882
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oteri, Malack Omae -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyete, Abraham Mutunga -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Makhaso, Byron Chesoli -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kogo, Vincent Kibet -> similarity: 31.57894736842105
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gachanga, Esther Wanjiru -> similarity: 44.99999999999999
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mwalili, Tobias Mbithi -> similarity: 45.16129032258065
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mutanu, Leah -> similarity: 41.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nderu, Lawrence -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mwangi, Henry Njogo -> similarity: 42.42424242424242
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ondiek, Collins Oduor -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Githinji, Stanley Muturi,, Dr. -> similarity: 36.36363636363637
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kayeyia, Ernest Madara -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mohamed, Abdullahi Mohamed -> similarity: 57.692307692307686
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mwangi, Jonathan Maina -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbatia, Betty Nyambura -> similarity: 41.02564102564102
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Okanya, Patrick Wafula_Simiyu -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muendo, Daniel -> similarity: 57.14285714285714
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muniafu, Max Maina -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kamanu, Timothy_Kevin Kuria -> similarity: 38.46153846153846
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kamuri, Simon -> similarity: 46.15384615384615
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kabacho, Mwangi -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gitoho, Salome Wanjiru -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gachago, Philip Muriithi -> similarity: 37.2093023255814
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kimathi, George Eliphas -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Misawo, Florence Awuor -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Odendo, Moses -> similarity: 53.84615384615385
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbithi, Jonathan Ndolo -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muchiri, Catherine Wanjiru -> similarity: 38.46153846153846
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogola, Mary Ganga -> similarity: 52.94117647058824
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Namuye, Maria -> similarity: 61.53846153846154
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Karimi, James Mark,, Ngari -> similarity: 42.307692307692314
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kibet, Eric M. -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Akuma, Samson Mainye -> similarity: 44.99999999999999
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Awuor, Emmanuel -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ouma,, Duncan Ochieng -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kobuthi, Edward N. -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wetiba, Johnson Kwanusu -> similarity: 39.13043478260869
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njui, Francis -> similarity: 38.46153846153846
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Miriti, Gilbert Mugambi -> similarity: 34.78260869565217
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Maina, Muchara Dr -> similarity: 47.05882352941176
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Opondo, Mary Awuor -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ochola, Phares B -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogola, Jacob Owuor -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Musuva, Gladys Mwende -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbere, Sarah Wanjiru -> similarity: 41.02564102564102
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mosoti, Zachary -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Were, Jane N. -> similarity: 46.15384615384615
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muriu, Marylyn Doreen -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbotu, Michael Mulandi -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nduati, Gidraph J. -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Musebe, Edward Achieng -> similarity: 43.90243902439024
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Sule, Odhiambo F.E. -> similarity: 36.8421052631579
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogendi, Paul -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Joseph, Muchina -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Okanda, Paul M -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Newa, Fred Omondi -> similarity: 47.05882352941176
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs K'aol, George O. -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Getecha, Ciru W. -> similarity: 34.78260869565217
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ndegwa, Joyce Watetu -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kamau, Joseph -> similarity: 46.15384615384615
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs S   Kiruthu, Lucy Nyaguthii -> similarity: 43.47826086956522
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mburu, Esther Njambi -> similarity: 35.89743589743589
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs F   Wambalaba, Francis -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wainaina, Gituro -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njenga, Edward Gachangi -> similarity: 34.78260869565217
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nguru, Faith Wariara -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Noah, Naumih M. -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Amuhaya, Edith Khavwajira -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wangui, Ruth Njeri -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbugua, Wanjiku -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kimani, Nathan Muya -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Otieno, Symon_Peter Victor -> similarity: 37.5
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Odhiambo, Terry J. -> similarity: 41.379310344827594
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Osiro, Moses Adama -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Asembo, Kenedy Onyango -> similarity: 36.36363636363637
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Onyango, Resila -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kirui, Gideon Kipng'eno -> similarity: 26.086956521739136
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Sungi, Simeon P. -> similarity: 37.5
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Arasa, Josephine -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Newa, Elsie Opiyo -> similarity: 41.17647058823529
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mohamed, Hussein Abdi -> similarity: 57.14285714285714
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mwangi, Peterson Kimiru -> similarity: 37.83783783783784
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Lio, Sammy A.N. -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kakumu, Muema Pius -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ochieng', Robi Koki -> similarity: 31.57894736842105
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Magut, Zuhra C. -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gromov, Mikhail D. -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nginda, Ronald Robert_Abwova -> similarity: 35.71428571428571
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbole, Elizabeth M. -> similarity: 47.36842105263158
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Koshal, Jeremiah Ntaloi_Ole -> similarity: 40.816326530612244
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Sikolia, Geoffrey Serede,, Dr. -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gichaga, Lucy Wanjiku -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wachana, Paul -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ouma,, Judy Aluoch -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ouma, Zackayo Omolo -> similarity: 42.10526315789473
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Okech, Timothy C. -> similarity: 41.17647058823529
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Onono-Okelo, Perez A. -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Owili, Florence Akinyi -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njoroge, Martin Chege -> similarity: 52.38095238095239
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oduol, Charles -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyarigoti, Naom Moraa -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs F   Buyu, Matthew -> similarity: 37.03703703703704
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbugua, Peter Getyngo -> similarity: 39.02439024390244
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ambiyo, Sarah -> similarity: 53.84615384615385
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyamasyo, Eunice A. -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Onditi, Tom -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Jefwa, Judith Jai_Jaleha -> similarity: 43.90243902439024
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Milton, Obote J. -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kiai, Alice Wanjira -> similarity: 42.10526315789473
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Awuor, Quin Elizabeth -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogutu, Emily Atieno -> similarity: 47.36842105263158
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mburu, Martin -> similarity: 46.15384615384615
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oketch, Omondi -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyarige, Pamela Kwamboka -> similarity: 41.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njihia, David Thiru -> similarity: 35.71428571428571
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Scott, Bellows J -> similarity: 37.5
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Rintari, Ann Wanjiku -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kiaye, Mary A. -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Omolo, Calvin Andeve -> similarity: 44.99999999999999
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Irari, Annette Wangui -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyambati, Grace K -> similarity: 41.17647058823529
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njeri, Teresia -> similarity: 35.71428571428571
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Okallo, Dick Daniel -> similarity: 36.8421052631579
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Andango, Elizabeth -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Akach, Joyce Akinyi -> similarity: 36.8421052631579
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Onsomu, Clive Mochiemo -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kioni, Benson Muthoga -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kariuki, Lucy Nyawira -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wainaina, Samuel -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ngugi, Wilson Mbugua -> similarity: 35.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gatauwa,, James M. -> similarity: 38.70967741935484
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Joseph, Bertha B -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mirichii, John Mwaniki -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muriithi, Jane Gathigia -> similarity: 34.78260869565217
# ...
# [DEBUG] Comparing: tell me about basweti vs Mburu, Martin -> similarity: 48.0
# [DEBUG] Comparing: tell me about basweti vs Oketch, Omondi -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Nyarige, Pamela Kwamboka -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about basweti vs Njihia, David Thiru -> similarity: 31.25
# [DEBUG] Comparing: tell me about basweti vs Scott, Bellows J -> similarity: 47.61904761904761
# [DEBUG] Comparing: tell me about basweti vs Rintari, Ann Wanjiku -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Kiaye, Mary A. -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about basweti vs Omolo, Calvin Andeve -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about basweti vs Irari, Annette Wangui -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Nyambati, Grace K -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Njeri, Teresia -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Okallo, Dick Daniel -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs Andango, Elizabeth -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Akach, Joyce Akinyi -> similarity: 31.25
# [DEBUG] Comparing: tell me about basweti vs Onsomu, Clive Mochiemo -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about basweti vs Kioni, Benson Muthoga -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Kariuki, Lucy Nyawira -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Wainaina, Samuel -> similarity: 27.586206896551722
# [DEBUG] Comparing: tell me about basweti vs Ngugi, Wilson Mbugua -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Gatauwa,, James M. -> similarity: 41.02564102564103
# [DEBUG] Comparing: tell me about basweti vs Joseph, Bertha B -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Mirichii, John Mwaniki -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about basweti vs Muriithi, Jane Gathigia -> similarity: 39.02439024390244
# [DEBUG] Comparing: tell me about basweti vs Bwire, Albert C. -> similarity: 48.648648648648646
# [DEBUG] Comparing: tell me about basweti vs Bii, Cosmas K -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about basweti vs Owuor, Benard O -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about basweti vs Karugu, Mureithi -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about basweti vs Nginye, Michael Gichangi -> similarity: 35.0
# [DEBUG] Comparing: tell me about basweti vs Mulwa, Harrison Munyao -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about basweti vs Akosa, E. Wambalaba -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Ndungu, Francis Gitonga -> similarity: 25.64102564102564
# [DEBUG] Comparing: tell me about basweti vs F   Iraki, Fredrick Kang'ethe -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Adan, Ali -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Otieno, Pauline Adhiambo -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Kalunda, Elizabeth Nthambi -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about basweti vs Kigwilu, Peter Changilwa -> similarity: 35.55555555555556
# [DEBUG] Comparing: tell me about basweti vs Amwayi, Oliver Shitanda -> similarity: 31.818181818181813
# [DEBUG] Comparing: tell me about basweti vs Ireri, Kioko -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about basweti vs Nyaribo, Cyprian Mose -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about basweti vs Kakai, Pius Wanyonyi -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about basweti vs Mutisya Mutungi, Mary Mumbua -> similarity: 36.734693877551024
# [DEBUG] Comparing: tell me about basweti vs Njeru, Godwin Kinyua -> similarity: 29.268292682926827
# [DEBUG] Comparing: tell me about basweti vs Mbugua, John Chege -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about basweti vs Mage, Grace Nduta -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about basweti vs Muindi, Peter M. -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Mulindi, Patrick M. -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Maranga,, Vincent Nyamari -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Terefe, Ermias Mergia -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Obbanda, Luka Epainito -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about basweti vs Kimani, Joan Wanjiru -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Macharia, Hannah Muthoni -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Maumo, Leonard Oluoch -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Njuguna, Joseph Kimani -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about basweti vs Njoroge, Simon Githaiga -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about basweti vs Mwakina, Rozina Munna -> similarity: 29.629629629629626
# [DEBUG] Comparing: tell me about basweti vs Behr, Agnes Wanjiru -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Ylonen, Aleksi Erik -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Maganda, Willis Otieno -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Ali, Fatuma Ahmed -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about basweti vs Gathua, Michael M. -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about basweti vs Muliro, Wilfred Nasong'o -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about basweti vs Odaba, Dan Noel -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs Nyaanga, Gideon Nyamweya -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about basweti vs Katete, George Onyango -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about basweti vs Ndungu, Pauline W. -> similarity: 31.25
# [DEBUG] Comparing: tell me about basweti vs Wangechi, Chege -> similarity: 31.57894736842105
# [DEBUG] Comparing: tell me about basweti vs Munyi, Elijah N -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about basweti vs Githigaro, John Mwangi -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about basweti vs F   Veney, Cassandra Rachel -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Magero, Patrick L.K -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Gisore, Billiah N. -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about basweti vs Kabongah, George Odhiambo -> similarity: 34.285714285714285
# [DEBUG] Comparing: tell me about basweti vs Ng'eno, Weldon Kibet -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Mashiwa, Maurice -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs F   Munene, Macharia -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about basweti vs Mbae, Justus -> similarity: 50.0
# [DEBUG] Comparing: tell me about basweti vs Kavoo, Mark Kavoo -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs S   Maina, Ann Wambui -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Machoka, Philip Gichaba -> similarity: 31.818181818181813
# [DEBUG] Comparing: tell me about basweti vs Macharia, Jimmy -> similarity: 21.42857142857143
# [DEBUG] Comparing: tell me about basweti vs Wangai, Njoroge Mambo -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about basweti vs S   Mutune, Loraine -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about basweti vs Sifuna, Austin Makokha -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Karoki, Samuel Githinji -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Baraza, Cyrus M -> similarity: 27.77777777777777
# [DEBUG] Comparing: tell me about basweti vs Gachie, Richard K. -> similarity: 25.0
# [DEBUG] Comparing: tell me about basweti vs Nakamura, Katsuji -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Githinji, Keziah Wangui,, Ms. -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about basweti vs Omondi, Daniel Onyango -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about basweti vs Telewa, Christabel -> similarity: 50.0
# [DEBUG] Comparing: tell me about basweti vs Oiye, Fredrick Ogutu,, Mr. -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about basweti vs Karanja, Moses Mwangi,, Mr -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about basweti vs Kidaha, Alfred Usagi -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about basweti vs Waga, Fred -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about basweti vs Mwangi, Isaac -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about basweti vs Mwilu, Asha Ahmed -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about basweti vs Bosire, Julius Ombui,, Dr. -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about basweti vs Kamau, Sheila Wanjiku -> similarity: 43.75
# [DEBUG] Comparing: tell me about basweti vs Oranga, James Odhiambo -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about basweti vs Muindi, Benjamin -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about basweti vs Owilla, Hesbon Hansen -> similarity: 51.28205128205128
# [DEBUG] Comparing: tell me about basweti vs Mule, Daniel -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about basweti vs Kimotho, Stephen Gichuhi -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Karume, Michelle Wariara -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about basweti vs Githua, Oscar Wanyutu -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Nyambegera, Stephen Morangi -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Mairura, Christopher Joseph -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Kaluyu, Veronicah -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Matula, Phylisters Daizy -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Linge, Teresia K.K. -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about basweti vs Obila, Onyango James,, Mr. -> similarity: 35.0
# [DEBUG] Comparing: tell me about basweti vs Njenga, Kefah Muiruri -> similarity: 31.57894736842105
# [DEBUG] Comparing: tell me about basweti vs Owino, Edward Otieno -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Kangu, Maureen -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about basweti vs Maore, Stephen K. -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about basweti vs S   Kiptum, Purity Jebotibin -> similarity: 48.484848484848484
# [DEBUG] Comparing: tell me about basweti vs Were, Jamen H. -> similarity: 45.45454545454546
# [DEBUG] Comparing: tell me about basweti vs Wafula, Maurine Maraka -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about basweti vs Khadioli, Nancy -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about basweti vs Mbugua, Levi Ng'ang'a -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Njuguna, Lydia Nyambura -> similarity: 34.285714285714285
# [DEBUG] Comparing: tell me about basweti vs Kahiri, Caroline Njeri,, Dr. -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about basweti vs Githiri, John Gitonga -> similarity: 27.027027027027028
# [DEBUG] Comparing: tell me about basweti vs Nyakundi, Jane -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about basweti vs Oyigo, Josephat DR -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Ndangili, Peter Munyao -> similarity: 41.86046511627907
# [DEBUG] Comparing: tell me about basweti vs Maima, Apollo Odhiambo -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Gitau, Samuel -> similarity: 41.1764705882353
# [DEBUG] Comparing: tell me about basweti vs Kimani, Larry M -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about basweti vs Njogu, Peter Mbugua -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Munyendo, Lincoln Were -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about basweti vs Odongo, Elizabeth Amwayi -> similarity: 48.64864864864865
# [DEBUG] Comparing: tell me about basweti vs Defersha, Amsalu Degu -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Ndungu, Tabitha K. -> similarity: 31.25
# [DEBUG] Comparing: tell me about basweti vs Mwaniki, Moses -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs Mbugua, Paul Mungai -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Simiyu, Lucy -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about basweti vs Musau, Josephine Ndanu -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Ireri, Niceta Wanja -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs Ndero, Peter K. -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about basweti vs Awuor, Anita Margaret -> similarity: 43.75
# [DEBUG] Comparing: tell me about basweti vs Ogunde, Jane  Awuor -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Waithima, Charity Wangui -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about basweti vs Munyae, Margaret M. -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Bironga, Sophia Moraa -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about basweti vs Kihara, Michael -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about basweti vs Njoroge, Margaret -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Mutwiri, Marion Kirumba -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about basweti vs Mwangi, William K. -> similarity: 30.769230769230774
# [DEBUG] Comparing: tell me about basweti vs F   Munywoki, Samson -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about basweti vs Njoroge, Joseph -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Panchani, Roopam Lalji -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about basweti vs Omollo, Joseph Owade -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about basweti vs Webbo, Roselynne Kyambi -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about basweti vs Ongecha, Francisca Atieno -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Muturi, Lucy N. -> similarity: 30.000000000000004
# [DEBUG] Comparing: tell me about basweti vs Nyaga, Nancy Ng'endo -> similarity: 24.242424242424242
# [DEBUG] Comparing: tell me about basweti vs Brown, Dana Basnight -> similarity: 43.75
# [DEBUG] Comparing: tell me about basweti vs Kinuthia, Annie Njoki -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Kiai, Gachanja -> similarity: 22.85714285714286
# [DEBUG] Comparing: tell me about basweti vs Ogore, Fredrick Michae -> similarity: 32.55813953488372
# [DEBUG] Comparing: tell me about basweti vs Otiende, Noah Ochieng -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Odek, Anthony W. -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Rubio Gijon, Pablo -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Koigi, Rachel Wanjiru -> similarity: 32.25806451612904
# No evaluation data found for Tell me about Basweti.
#
# Query: Evaluation for a nonexistent instructor
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.

# %%
# Ok that operational error is not good so lets look at the db again
cursor.execute("PRAGMA table_info(FeedbackCorpus)")
print(cursor.fetchall())
# Out:
# [(0, 'feedback_id', 'INTEGER', 0, None, 1), (1, 'faculty_id', 'INTEGER', 0, None, 0), (2, 'instructor', 'TEXT', 0, None, 0), (3, 'course_code', 'TEXT', 0, None, 0), (4, 'section_code', 'TEXT', 0, None, 0), (5, 'semester', 'TEXT', 0, None, 0), (6, 'comment_type', 'TEXT', 0, None, 0), (7, 'comment_text', 'TEXT', 0, None, 0)]

# %%
def get_feedback_summary(fid, limit=3):
    query = """
    SELECT comment_text
    FROM FeedbackCorpus
    WHERE faculty_id = ?
    LIMIT ?
    """
    cursor.execute(query, (fid, limit))
    rows = cursor.fetchall()

    if rows:
        comments = [r[0] for r in rows]
        return "Sample feedback:\n" + "\n".join(f"- {c}" for c in comments)
    return "No qualitative feedback available."

# %%
# Now just gotta stress test the system
# Stress test queries
test_queries = [
    "Tell me about Afundi",
    "What’s the evaluation for Mohamed, Mwanashehe S.?",
    "How did Gitahi perform?",
    "Results for Odoyo",
    "Evaluation of Gatumo, Francis Mambo",
    "Who scored above 4.8?",
    "List instructors with scores below 3.5",
    "Which instructors scored exactly 4.0?",
    "Which instructors got an A?",
    "Show me all with grade B",
    "Who received a C?",
    "Top 10 performers",
    "Top 3 instructors this semester",
    "Top 20 performers",
    "What feedback did students give Afundi?",
    "Summarize feedback for Mohamed",
    "Show sample feedback for Odoyo",
    "How did Alo perform?",   # typo test
    "Tell me about Basweti",  # partial match
    "Evaluation for a nonexistent instructor"
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: Tell me about Afundi
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Mwanashehe S. -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Owuor, John David_Ouma -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Gitahi, Jesse Elikanah_Machirah -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Odoyo, Fredrick -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Gatumo, Francis Mambo -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Oyaro, Kepha N._Makori -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ogada, Agnes Owuor -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kuria,, John -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Achoki, George -> similarity: 35.294117647058826
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Amos Gitau -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Cheluget, Elizabeth Jepchumba -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Nyabere, Emily -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Nyong'o, Kwame o -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Gachukia, Jennifer Wangari -> similarity: 34.285714285714285
# [DEBUG] Comparing: tell me about afundi vs Oriedi, David Opondo -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ndirangu, Dalton -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs Ondieki, Benard Odhiambo -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Muriithi, Petronilla Muthoni -> similarity: 51.61290322580645
# [DEBUG] Comparing: tell me about afundi vs Namuye, Silvester -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Afundi, Patrick Omuhinda -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Ahenda, John Ang'udi -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Wamuyu, Patrick Kanyi -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Ndiege, Joshua Rumo -> similarity: 41.02564102564103
# [DEBUG] Comparing: tell me about afundi vs Basweti, Kevin Ogachi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Aloo, Linus Alwal -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Oteri, Malack Omae -> similarity: 48.0
# [DEBUG] Comparing: tell me about afundi vs Nyete, Abraham Mutunga -> similarity: 47.61904761904762
# [DEBUG] Comparing: tell me about afundi vs Makhaso, Byron Chesoli -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about afundi vs Kogo, Vincent Kibet -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Gachanga, Esther Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mwalili, Tobias Mbithi -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Mutanu, Leah -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Nderu, Lawrence -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Henry Njogo -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Ondiek, Collins Oduor -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about afundi vs Githinji, Stanley Muturi,, Dr. -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Kayeyia, Ernest Madara -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Abdullahi Mohamed -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Jonathan Maina -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Mbatia, Betty Nyambura -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Okanya, Patrick Wafula_Simiyu -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Muendo, Daniel -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Muniafu, Max Maina -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Kamanu, Timothy_Kevin Kuria -> similarity: 38.297872340425535
# [DEBUG] Comparing: tell me about afundi vs Kamuri, Simon -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Kabacho, Mwangi -> similarity: 51.85185185185186
# [DEBUG] Comparing: tell me about afundi vs Gitoho, Salome Wanjiru -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Gachago, Philip Muriithi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Kimathi, George Eliphas -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Misawo, Florence Awuor -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Odendo, Moses -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mbithi, Jonathan Ndolo -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Muchiri, Catherine Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Ogola, Mary Ganga -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Namuye, Maria -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karimi, James Mark,, Ngari -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Kibet, Eric M. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Akuma, Samson Mainye -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Awuor, Emmanuel -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Ouma,, Duncan Ochieng -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kobuthi, Edward N. -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Wetiba, Johnson Kwanusu -> similarity: 32.55813953488372
# [DEBUG] Comparing: tell me about afundi vs Njui, Francis -> similarity: 45.45454545454546
# [DEBUG] Comparing: tell me about afundi vs Miriti, Gilbert Mugambi -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Maina, Muchara Dr -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Opondo, Mary Awuor -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ochola, Phares B -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Ogola, Jacob Owuor -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Musuva, Gladys Mwende -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mbere, Sarah Wanjiru -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Mosoti, Zachary -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Were, Jane N. -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Muriu, Marylyn Doreen -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Mbotu, Michael Mulandi -> similarity: 60.0
# [DEBUG] Comparing: tell me about afundi vs Nduati, Gidraph J. -> similarity: 29.629629629629626
# [DEBUG] Comparing: tell me about afundi vs Musebe, Edward Achieng -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Sule, Odhiambo F.E. -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Ogendi, Paul -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Joseph, Muchina -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Okanda, Paul M -> similarity: 35.294117647058826
# [DEBUG] Comparing: tell me about afundi vs Newa, Fred Omondi -> similarity: 45.16129032258065
# [DEBUG] Comparing: tell me about afundi vs K'aol, George O. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Getecha, Ciru W. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Ndegwa, Joyce Watetu -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kamau, Joseph -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs S   Kiruthu, Lucy Nyaguthii -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Mburu, Esther Njambi -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs F   Wambalaba, Francis -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Wainaina, Gituro -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Njenga, Edward Gachangi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Nguru, Faith Wariara -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Noah, Naumih M. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Amuhaya, Edith Khavwajira -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs Wangui, Ruth Njeri -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Wanjiku -> similarity: 46.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Kimani, Nathan Muya -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Otieno, Symon_Peter Victor -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Odhiambo, Terry J. -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Osiro, Moses Adama -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Asembo, Kenedy Onyango -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Onyango, Resila -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Kirui, Gideon Kipng'eno -> similarity: 27.77777777777778
# [DEBUG] Comparing: tell me about afundi vs Sungi, Simeon P. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Arasa, Josephine -> similarity: 27.77777777777777
# [DEBUG] Comparing: tell me about afundi vs Newa, Elsie Opiyo -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Hussein Abdi -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Peterson Kimiru -> similarity: 41.86046511627907
# [DEBUG] Comparing: tell me about afundi vs Lio, Sammy A.N. -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Kakumu, Muema Pius -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Ochieng', Robi Koki -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Magut, Zuhra C. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Gromov, Mikhail D. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Nginda, Ronald Robert_Abwova -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Mbole, Elizabeth M. -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Koshal, Jeremiah Ntaloi_Ole -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Sikolia, Geoffrey Serede,, Dr. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Gichaga, Lucy Wanjiku -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Wachana, Paul -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Ouma,, Judy Aluoch -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Ouma, Zackayo Omolo -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Okech, Timothy C. -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Onono-Okelo, Perez A. -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Owili, Florence Akinyi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Martin Chege -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Oduol, Charles -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Nyarigoti, Naom Moraa -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs F   Buyu, Matthew -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Peter Getyngo -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Ambiyo, Sarah -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Nyamasyo, Eunice A. -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Onditi, Tom -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Jefwa, Judith Jai_Jaleha -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Milton, Obote J. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kiai, Alice Wanjira -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Awuor, Quin Elizabeth -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Ogutu, Emily Atieno -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Mburu, Martin -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Oketch, Omondi -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Nyarige, Pamela Kwamboka -> similarity: 47.36842105263158
# [DEBUG] Comparing: tell me about afundi vs Njihia, David Thiru -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about afundi vs Scott, Bellows J -> similarity: 47.61904761904761
# [DEBUG] Comparing: tell me about afundi vs Rintari, Ann Wanjiku -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Kiaye, Mary A. -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Omolo, Calvin Andeve -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Irari, Annette Wangui -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Nyambati, Grace K -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Njeri, Teresia -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about afundi vs Okallo, Dick Daniel -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Andango, Elizabeth -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Akach, Joyce Akinyi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Onsomu, Clive Mochiemo -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kioni, Benson Muthoga -> similarity: 39.02439024390244
# [DEBUG] Comparing: tell me about afundi vs Kariuki, Lucy Nyawira -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Wainaina, Samuel -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Ngugi, Wilson Mbugua -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Gatauwa,, James M. -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Joseph, Bertha B -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Mirichii, John Mwaniki -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Muriithi, Jane Gathigia -> similarity: 37.2093023255814
# [DEBUG] Comparing: tell me about afundi vs Bwire, Albert C. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Bii, Cosmas K -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Owuor, Benard O -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karugu, Mureithi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Nginye, Michael Gichangi -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Mulwa, Harrison Munyao -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Akosa, E. Wambalaba -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Francis Gitonga -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about afundi vs F   Iraki, Fredrick Kang'ethe -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Adan, Ali -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Otieno, Pauline Adhiambo -> similarity: 44.99999999999999
# [DEBUG] Comparing: tell me about afundi vs Kalunda, Elizabeth Nthambi -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Kigwilu, Peter Changilwa -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Amwayi, Oliver Shitanda -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Ireri, Kioko -> similarity: 26.086956521739136
# [DEBUG] Comparing: tell me about afundi vs Nyaribo, Cyprian Mose -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kakai, Pius Wanyonyi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mutisya Mutungi, Mary Mumbua -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Njeru, Godwin Kinyua -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Mbugua, John Chege -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Mage, Grace Nduta -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Muindi, Peter M. -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Mulindi, Patrick M. -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Maranga,, Vincent Nyamari -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Terefe, Ermias Mergia -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Obbanda, Luka Epainito -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Kimani, Joan Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Macharia, Hannah Muthoni -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Maumo, Leonard Oluoch -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Joseph Kimani -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Simon Githaiga -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Mwakina, Rozina Munna -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Behr, Agnes Wanjiru -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Ylonen, Aleksi Erik -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Maganda, Willis Otieno -> similarity: 42.857142857142854
# [DEBUG] Comparing: tell me about afundi vs Ali, Fatuma Ahmed -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Gathua, Michael M. -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Muliro, Wilfred Nasong'o -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Odaba, Dan Noel -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Nyaanga, Gideon Nyamweya -> similarity: 31.818181818181813
# [DEBUG] Comparing: tell me about afundi vs Katete, George Onyango -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Pauline W. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Wangechi, Chege -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Munyi, Elijah N -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Githigaro, John Mwangi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs F   Veney, Cassandra Rachel -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Magero, Patrick L.K -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Gisore, Billiah N. -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about afundi vs Kabongah, George Odhiambo -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ng'eno, Weldon Kibet -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mashiwa, Maurice -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs F   Munene, Macharia -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Mbae, Justus -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Kavoo, Mark Kavoo -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs S   Maina, Ann Wambui -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Machoka, Philip Gichaba -> similarity: 32.55813953488372
# [DEBUG] Comparing: tell me about afundi vs Macharia, Jimmy -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Wangai, Njoroge Mambo -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs S   Mutune, Loraine -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Sifuna, Austin Makokha -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Karoki, Samuel Githinji -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Baraza, Cyrus M -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Gachie, Richard K. -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Nakamura, Katsuji -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Githinji, Keziah Wangui,, Ms. -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Omondi, Daniel Onyango -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Telewa, Christabel -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Oiye, Fredrick Ogutu,, Mr. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karanja, Moses Mwangi,, Mr -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Kidaha, Alfred Usagi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Waga, Fred -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Isaac -> similarity: 31.57894736842105
# [DEBUG] Comparing: tell me about afundi vs Mwilu, Asha Ahmed -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Bosire, Julius Ombui,, Dr. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kamau, Sheila Wanjiku -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Oranga, James Odhiambo -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Muindi, Benjamin -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Owilla, Hesbon Hansen -> similarity: 47.36842105263158
# [DEBUG] Comparing: tell me about afundi vs Mule, Daniel -> similarity: 47.61904761904761
# [DEBUG] Comparing: tell me about afundi vs Kimotho, Stephen Gichuhi -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Karume, Michelle Wariara -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Githua, Oscar Wanyutu -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Nyambegera, Stephen Morangi -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Mairura, Christopher Joseph -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Kaluyu, Veronicah -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Matula, Phylisters Daizy -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Linge, Teresia K.K. -> similarity: 30.769230769230774
# [DEBUG] Comparing: tell me about afundi vs Obila, Onyango James,, Mr. -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs Njenga, Kefah Muiruri -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Owino, Edward Otieno -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kangu, Maureen -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Maore, Stephen K. -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs S   Kiptum, Purity Jebotibin -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Were, Jamen H. -> similarity: 45.45454545454546
# [DEBUG] Comparing: tell me about afundi vs Wafula, Maurine Maraka -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Khadioli, Nancy -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Levi Ng'ang'a -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Lydia Nyambura -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kahiri, Caroline Njeri,, Dr. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Githiri, John Gitonga -> similarity: 27.77777777777778
# [DEBUG] Comparing: tell me about afundi vs Nyakundi, Jane -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Oyigo, Josephat DR -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ndangili, Peter Munyao -> similarity: 47.61904761904762
# [DEBUG] Comparing: tell me about afundi vs Maima, Apollo Odhiambo -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Gitau, Samuel -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Kimani, Larry M -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Njogu, Peter Mbugua -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Munyendo, Lincoln Were -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Odongo, Elizabeth Amwayi -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Defersha, Amsalu Degu -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Tabitha K. -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about afundi vs Mwaniki, Moses -> similarity: 30.000000000000004
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Paul Mungai -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Simiyu, Lucy -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Musau, Josephine Ndanu -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Ireri, Niceta Wanja -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Ndero, Peter K. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Awuor, Anita Margaret -> similarity: 43.90243902439025
# [DEBUG] Comparing: tell me about afundi vs Ogunde, Jane  Awuor -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Waithima, Charity Wangui -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Munyae, Margaret M. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Bironga, Sophia Moraa -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Kihara, Michael -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Margaret -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Mutwiri, Marion Kirumba -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Mwangi, William K. -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs F   Munywoki, Samson -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Joseph -> similarity: 27.27272727272727
# [DEBUG] Comparing: tell me about afundi vs Panchani, Roopam Lalji -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Omollo, Joseph Owade -> similarity: 43.24324324324324
# [DEBUG] Comparing: tell me about afundi vs Webbo, Roselynne Kyambi -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Ongecha, Francisca Atieno -> similarity: 35.55555555555556
# [DEBUG] Comparing: tell me about afundi vs Muturi, Lucy N. -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Nyaga, Nancy Ng'endo -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Brown, Dana Basnight -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Kinuthia, Annie Njoki -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kiai, Gachanja -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Ogore, Fredrick Michae -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Otiende, Noah Ochieng -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Odek, Anthony W. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Rubio Gijon, Pablo -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Koigi, Rachel Wanjiru -> similarity: 40.0
# No evaluation data found for Tell me about Afundi.
#
# Query: What’s the evaluation for Mohamed, Mwanashehe S.?
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mohamed, Mwanashehe S. -> similarity: 100.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Owuor, John David_Ouma -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gitahi, Jesse Elikanah_Machirah -> similarity: 36.065573770491795
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Odoyo, Fredrick -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gatumo, Francis Mambo -> similarity: 47.61904761904761
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oyaro, Kepha N._Makori -> similarity: 36.36363636363637
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogada, Agnes Owuor -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kuria,, John -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Achoki, George -> similarity: 35.71428571428571
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njuguna, Amos Gitau -> similarity: 34.285714285714285
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Cheluget, Elizabeth Jepchumba -> similarity: 39.13043478260869
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyabere, Emily -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyong'o, Kwame o -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gachukia, Jennifer Wangari -> similarity: 38.46153846153846
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oriedi, David Opondo -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ndirangu, Dalton -> similarity: 37.5
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ondieki, Benard Odhiambo -> similarity: 41.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muriithi, Petronilla Muthoni -> similarity: 36.73469387755102
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Namuye, Silvester -> similarity: 47.05882352941176
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Afundi, Patrick Omuhinda -> similarity: 41.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ahenda, John Ang'udi -> similarity: 41.02564102564102
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wamuyu, Patrick Kanyi -> similarity: 35.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ndiege, Joshua Rumo -> similarity: 42.10526315789473
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Basweti, Kevin Ogachi -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Aloo, Linus Alwal -> similarity: 35.29411764705882
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oteri, Malack Omae -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyete, Abraham Mutunga -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Makhaso, Byron Chesoli -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kogo, Vincent Kibet -> similarity: 31.57894736842105
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gachanga, Esther Wanjiru -> similarity: 44.99999999999999
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mwalili, Tobias Mbithi -> similarity: 45.16129032258065
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mutanu, Leah -> similarity: 41.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nderu, Lawrence -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mwangi, Henry Njogo -> similarity: 42.42424242424242
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ondiek, Collins Oduor -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Githinji, Stanley Muturi,, Dr. -> similarity: 36.36363636363637
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kayeyia, Ernest Madara -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mohamed, Abdullahi Mohamed -> similarity: 57.692307692307686
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mwangi, Jonathan Maina -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbatia, Betty Nyambura -> similarity: 41.02564102564102
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Okanya, Patrick Wafula_Simiyu -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muendo, Daniel -> similarity: 57.14285714285714
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muniafu, Max Maina -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kamanu, Timothy_Kevin Kuria -> similarity: 38.46153846153846
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kamuri, Simon -> similarity: 46.15384615384615
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kabacho, Mwangi -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gitoho, Salome Wanjiru -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gachago, Philip Muriithi -> similarity: 37.2093023255814
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kimathi, George Eliphas -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Misawo, Florence Awuor -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Odendo, Moses -> similarity: 53.84615384615385
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbithi, Jonathan Ndolo -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muchiri, Catherine Wanjiru -> similarity: 38.46153846153846
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogola, Mary Ganga -> similarity: 52.94117647058824
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Namuye, Maria -> similarity: 61.53846153846154
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Karimi, James Mark,, Ngari -> similarity: 42.307692307692314
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kibet, Eric M. -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Akuma, Samson Mainye -> similarity: 44.99999999999999
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Awuor, Emmanuel -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ouma,, Duncan Ochieng -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kobuthi, Edward N. -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wetiba, Johnson Kwanusu -> similarity: 39.13043478260869
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njui, Francis -> similarity: 38.46153846153846
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Miriti, Gilbert Mugambi -> similarity: 34.78260869565217
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Maina, Muchara Dr -> similarity: 47.05882352941176
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Opondo, Mary Awuor -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ochola, Phares B -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogola, Jacob Owuor -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Musuva, Gladys Mwende -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbere, Sarah Wanjiru -> similarity: 41.02564102564102
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mosoti, Zachary -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Were, Jane N. -> similarity: 46.15384615384615
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muriu, Marylyn Doreen -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbotu, Michael Mulandi -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nduati, Gidraph J. -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Musebe, Edward Achieng -> similarity: 43.90243902439024
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Sule, Odhiambo F.E. -> similarity: 36.8421052631579
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogendi, Paul -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Joseph, Muchina -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Okanda, Paul M -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Newa, Fred Omondi -> similarity: 47.05882352941176
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs K'aol, George O. -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Getecha, Ciru W. -> similarity: 34.78260869565217
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ndegwa, Joyce Watetu -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kamau, Joseph -> similarity: 46.15384615384615
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs S   Kiruthu, Lucy Nyaguthii -> similarity: 43.47826086956522
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mburu, Esther Njambi -> similarity: 35.89743589743589
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs F   Wambalaba, Francis -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wainaina, Gituro -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njenga, Edward Gachangi -> similarity: 34.78260869565217
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nguru, Faith Wariara -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Noah, Naumih M. -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Amuhaya, Edith Khavwajira -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wangui, Ruth Njeri -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbugua, Wanjiku -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kimani, Nathan Muya -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Otieno, Symon_Peter Victor -> similarity: 37.5
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Odhiambo, Terry J. -> similarity: 41.379310344827594
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Osiro, Moses Adama -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Asembo, Kenedy Onyango -> similarity: 36.36363636363637
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Onyango, Resila -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kirui, Gideon Kipng'eno -> similarity: 26.086956521739136
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Sungi, Simeon P. -> similarity: 37.5
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Arasa, Josephine -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Newa, Elsie Opiyo -> similarity: 41.17647058823529
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mohamed, Hussein Abdi -> similarity: 57.14285714285714
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mwangi, Peterson Kimiru -> similarity: 37.83783783783784
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Lio, Sammy A.N. -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kakumu, Muema Pius -> similarity: 44.44444444444444
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ochieng', Robi Koki -> similarity: 31.57894736842105
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Magut, Zuhra C. -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gromov, Mikhail D. -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nginda, Ronald Robert_Abwova -> similarity: 35.71428571428571
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbole, Elizabeth M. -> similarity: 47.36842105263158
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Koshal, Jeremiah Ntaloi_Ole -> similarity: 40.816326530612244
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Sikolia, Geoffrey Serede,, Dr. -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gichaga, Lucy Wanjiku -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wachana, Paul -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ouma,, Judy Aluoch -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ouma, Zackayo Omolo -> similarity: 42.10526315789473
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Okech, Timothy C. -> similarity: 41.17647058823529
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Onono-Okelo, Perez A. -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Owili, Florence Akinyi -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njoroge, Martin Chege -> similarity: 52.38095238095239
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oduol, Charles -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyarigoti, Naom Moraa -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs F   Buyu, Matthew -> similarity: 37.03703703703704
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mbugua, Peter Getyngo -> similarity: 39.02439024390244
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ambiyo, Sarah -> similarity: 53.84615384615385
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyamasyo, Eunice A. -> similarity: 46.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Onditi, Tom -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Jefwa, Judith Jai_Jaleha -> similarity: 43.90243902439024
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Milton, Obote J. -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kiai, Alice Wanjira -> similarity: 42.10526315789473
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Awuor, Quin Elizabeth -> similarity: 38.095238095238095
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ogutu, Emily Atieno -> similarity: 47.36842105263158
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mburu, Martin -> similarity: 46.15384615384615
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Oketch, Omondi -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyarige, Pamela Kwamboka -> similarity: 41.666666666666664
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njihia, David Thiru -> similarity: 35.71428571428571
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Scott, Bellows J -> similarity: 37.5
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Rintari, Ann Wanjiku -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kiaye, Mary A. -> similarity: 50.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Omolo, Calvin Andeve -> similarity: 44.99999999999999
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Irari, Annette Wangui -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Nyambati, Grace K -> similarity: 41.17647058823529
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Njeri, Teresia -> similarity: 35.71428571428571
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Okallo, Dick Daniel -> similarity: 36.8421052631579
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Andango, Elizabeth -> similarity: 38.888888888888886
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Akach, Joyce Akinyi -> similarity: 36.8421052631579
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Onsomu, Clive Mochiemo -> similarity: 40.90909090909091
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kioni, Benson Muthoga -> similarity: 42.85714285714286
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Kariuki, Lucy Nyawira -> similarity: 33.333333333333336
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Wainaina, Samuel -> similarity: 43.75
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Ngugi, Wilson Mbugua -> similarity: 35.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Gatauwa,, James M. -> similarity: 38.70967741935484
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Joseph, Bertha B -> similarity: 40.0
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Mirichii, John Mwaniki -> similarity: 45.45454545454546
# [DEBUG] Comparing: what’s the evaluation for mohamed, mwanashehe s.? vs Muriithi, Jane Gathigia -> similarity: 34.78260869565217
# ...
# [DEBUG] Comparing: tell me about basweti vs Mburu, Martin -> similarity: 48.0
# [DEBUG] Comparing: tell me about basweti vs Oketch, Omondi -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Nyarige, Pamela Kwamboka -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about basweti vs Njihia, David Thiru -> similarity: 31.25
# [DEBUG] Comparing: tell me about basweti vs Scott, Bellows J -> similarity: 47.61904761904761
# [DEBUG] Comparing: tell me about basweti vs Rintari, Ann Wanjiku -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Kiaye, Mary A. -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about basweti vs Omolo, Calvin Andeve -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about basweti vs Irari, Annette Wangui -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Nyambati, Grace K -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Njeri, Teresia -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Okallo, Dick Daniel -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs Andango, Elizabeth -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Akach, Joyce Akinyi -> similarity: 31.25
# [DEBUG] Comparing: tell me about basweti vs Onsomu, Clive Mochiemo -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about basweti vs Kioni, Benson Muthoga -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Kariuki, Lucy Nyawira -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Wainaina, Samuel -> similarity: 27.586206896551722
# [DEBUG] Comparing: tell me about basweti vs Ngugi, Wilson Mbugua -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Gatauwa,, James M. -> similarity: 41.02564102564103
# [DEBUG] Comparing: tell me about basweti vs Joseph, Bertha B -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Mirichii, John Mwaniki -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about basweti vs Muriithi, Jane Gathigia -> similarity: 39.02439024390244
# [DEBUG] Comparing: tell me about basweti vs Bwire, Albert C. -> similarity: 48.648648648648646
# [DEBUG] Comparing: tell me about basweti vs Bii, Cosmas K -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about basweti vs Owuor, Benard O -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about basweti vs Karugu, Mureithi -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about basweti vs Nginye, Michael Gichangi -> similarity: 35.0
# [DEBUG] Comparing: tell me about basweti vs Mulwa, Harrison Munyao -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about basweti vs Akosa, E. Wambalaba -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Ndungu, Francis Gitonga -> similarity: 25.64102564102564
# [DEBUG] Comparing: tell me about basweti vs F   Iraki, Fredrick Kang'ethe -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Adan, Ali -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Otieno, Pauline Adhiambo -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Kalunda, Elizabeth Nthambi -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about basweti vs Kigwilu, Peter Changilwa -> similarity: 35.55555555555556
# [DEBUG] Comparing: tell me about basweti vs Amwayi, Oliver Shitanda -> similarity: 31.818181818181813
# [DEBUG] Comparing: tell me about basweti vs Ireri, Kioko -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about basweti vs Nyaribo, Cyprian Mose -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about basweti vs Kakai, Pius Wanyonyi -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about basweti vs Mutisya Mutungi, Mary Mumbua -> similarity: 36.734693877551024
# [DEBUG] Comparing: tell me about basweti vs Njeru, Godwin Kinyua -> similarity: 29.268292682926827
# [DEBUG] Comparing: tell me about basweti vs Mbugua, John Chege -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about basweti vs Mage, Grace Nduta -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about basweti vs Muindi, Peter M. -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Mulindi, Patrick M. -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Maranga,, Vincent Nyamari -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Terefe, Ermias Mergia -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Obbanda, Luka Epainito -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about basweti vs Kimani, Joan Wanjiru -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Macharia, Hannah Muthoni -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Maumo, Leonard Oluoch -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Njuguna, Joseph Kimani -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about basweti vs Njoroge, Simon Githaiga -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about basweti vs Mwakina, Rozina Munna -> similarity: 29.629629629629626
# [DEBUG] Comparing: tell me about basweti vs Behr, Agnes Wanjiru -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Ylonen, Aleksi Erik -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Maganda, Willis Otieno -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Ali, Fatuma Ahmed -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about basweti vs Gathua, Michael M. -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about basweti vs Muliro, Wilfred Nasong'o -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about basweti vs Odaba, Dan Noel -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs Nyaanga, Gideon Nyamweya -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about basweti vs Katete, George Onyango -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about basweti vs Ndungu, Pauline W. -> similarity: 31.25
# [DEBUG] Comparing: tell me about basweti vs Wangechi, Chege -> similarity: 31.57894736842105
# [DEBUG] Comparing: tell me about basweti vs Munyi, Elijah N -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about basweti vs Githigaro, John Mwangi -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about basweti vs F   Veney, Cassandra Rachel -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Magero, Patrick L.K -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Gisore, Billiah N. -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about basweti vs Kabongah, George Odhiambo -> similarity: 34.285714285714285
# [DEBUG] Comparing: tell me about basweti vs Ng'eno, Weldon Kibet -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Mashiwa, Maurice -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs F   Munene, Macharia -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about basweti vs Mbae, Justus -> similarity: 50.0
# [DEBUG] Comparing: tell me about basweti vs Kavoo, Mark Kavoo -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs S   Maina, Ann Wambui -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Machoka, Philip Gichaba -> similarity: 31.818181818181813
# [DEBUG] Comparing: tell me about basweti vs Macharia, Jimmy -> similarity: 21.42857142857143
# [DEBUG] Comparing: tell me about basweti vs Wangai, Njoroge Mambo -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about basweti vs S   Mutune, Loraine -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about basweti vs Sifuna, Austin Makokha -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Karoki, Samuel Githinji -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Baraza, Cyrus M -> similarity: 27.77777777777777
# [DEBUG] Comparing: tell me about basweti vs Gachie, Richard K. -> similarity: 25.0
# [DEBUG] Comparing: tell me about basweti vs Nakamura, Katsuji -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Githinji, Keziah Wangui,, Ms. -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about basweti vs Omondi, Daniel Onyango -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about basweti vs Telewa, Christabel -> similarity: 50.0
# [DEBUG] Comparing: tell me about basweti vs Oiye, Fredrick Ogutu,, Mr. -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about basweti vs Karanja, Moses Mwangi,, Mr -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about basweti vs Kidaha, Alfred Usagi -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about basweti vs Waga, Fred -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about basweti vs Mwangi, Isaac -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about basweti vs Mwilu, Asha Ahmed -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about basweti vs Bosire, Julius Ombui,, Dr. -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about basweti vs Kamau, Sheila Wanjiku -> similarity: 43.75
# [DEBUG] Comparing: tell me about basweti vs Oranga, James Odhiambo -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about basweti vs Muindi, Benjamin -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about basweti vs Owilla, Hesbon Hansen -> similarity: 51.28205128205128
# [DEBUG] Comparing: tell me about basweti vs Mule, Daniel -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about basweti vs Kimotho, Stephen Gichuhi -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Karume, Michelle Wariara -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about basweti vs Githua, Oscar Wanyutu -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Nyambegera, Stephen Morangi -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Mairura, Christopher Joseph -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about basweti vs Kaluyu, Veronicah -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Matula, Phylisters Daizy -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Linge, Teresia K.K. -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about basweti vs Obila, Onyango James,, Mr. -> similarity: 35.0
# [DEBUG] Comparing: tell me about basweti vs Njenga, Kefah Muiruri -> similarity: 31.57894736842105
# [DEBUG] Comparing: tell me about basweti vs Owino, Edward Otieno -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Kangu, Maureen -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about basweti vs Maore, Stephen K. -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about basweti vs S   Kiptum, Purity Jebotibin -> similarity: 48.484848484848484
# [DEBUG] Comparing: tell me about basweti vs Were, Jamen H. -> similarity: 45.45454545454546
# [DEBUG] Comparing: tell me about basweti vs Wafula, Maurine Maraka -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about basweti vs Khadioli, Nancy -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about basweti vs Mbugua, Levi Ng'ang'a -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Njuguna, Lydia Nyambura -> similarity: 34.285714285714285
# [DEBUG] Comparing: tell me about basweti vs Kahiri, Caroline Njeri,, Dr. -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about basweti vs Githiri, John Gitonga -> similarity: 27.027027027027028
# [DEBUG] Comparing: tell me about basweti vs Nyakundi, Jane -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about basweti vs Oyigo, Josephat DR -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Ndangili, Peter Munyao -> similarity: 41.86046511627907
# [DEBUG] Comparing: tell me about basweti vs Maima, Apollo Odhiambo -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Gitau, Samuel -> similarity: 41.1764705882353
# [DEBUG] Comparing: tell me about basweti vs Kimani, Larry M -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about basweti vs Njogu, Peter Mbugua -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Munyendo, Lincoln Were -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about basweti vs Odongo, Elizabeth Amwayi -> similarity: 48.64864864864865
# [DEBUG] Comparing: tell me about basweti vs Defersha, Amsalu Degu -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about basweti vs Ndungu, Tabitha K. -> similarity: 31.25
# [DEBUG] Comparing: tell me about basweti vs Mwaniki, Moses -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs Mbugua, Paul Mungai -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Simiyu, Lucy -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about basweti vs Musau, Josephine Ndanu -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Ireri, Niceta Wanja -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about basweti vs Ndero, Peter K. -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about basweti vs Awuor, Anita Margaret -> similarity: 43.75
# [DEBUG] Comparing: tell me about basweti vs Ogunde, Jane  Awuor -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Waithima, Charity Wangui -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about basweti vs Munyae, Margaret M. -> similarity: 40.0
# [DEBUG] Comparing: tell me about basweti vs Bironga, Sophia Moraa -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about basweti vs Kihara, Michael -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about basweti vs Njoroge, Margaret -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Mutwiri, Marion Kirumba -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about basweti vs Mwangi, William K. -> similarity: 30.769230769230774
# [DEBUG] Comparing: tell me about basweti vs F   Munywoki, Samson -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about basweti vs Njoroge, Joseph -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about basweti vs Panchani, Roopam Lalji -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about basweti vs Omollo, Joseph Owade -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about basweti vs Webbo, Roselynne Kyambi -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about basweti vs Ongecha, Francisca Atieno -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Muturi, Lucy N. -> similarity: 30.000000000000004
# [DEBUG] Comparing: tell me about basweti vs Nyaga, Nancy Ng'endo -> similarity: 24.242424242424242
# [DEBUG] Comparing: tell me about basweti vs Brown, Dana Basnight -> similarity: 43.75
# [DEBUG] Comparing: tell me about basweti vs Kinuthia, Annie Njoki -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Kiai, Gachanja -> similarity: 22.85714285714286
# [DEBUG] Comparing: tell me about basweti vs Ogore, Fredrick Michae -> similarity: 32.55813953488372
# [DEBUG] Comparing: tell me about basweti vs Otiende, Noah Ochieng -> similarity: 37.5
# [DEBUG] Comparing: tell me about basweti vs Odek, Anthony W. -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about basweti vs Rubio Gijon, Pablo -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about basweti vs Koigi, Rachel Wanjiru -> similarity: 32.25806451612904
# No evaluation data found for Tell me about Basweti.
#
# Query: Evaluation for a nonexistent instructor
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.

# %% [markdown]
# alright so that worked, and I was reviewing the answers and there are some where it came out short.like here 'Query: What feedback did students give Afundi?
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Summarize feedback for Mohamed
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Show sample feedback for Odoyo
# I couldn’t find that instructor. Try a full or closer name.' the AI is got at listing, ranking and just straight pulling of information. But is now breaking down when it comes to forming sentences and answering qualitative questions. Its not forming sentences. 'est match: Mohamed, Mwanashehe S. with score: 100.0
# Based on evaluations, Mohamed, Mwanashehe S. received a grade of B+ with a mean score of 4.22.
# No qualitative feedback available.' that's an output from the AI itself. So that means we need to start to train it on forming sentences that are coherent,understand the context of the question and can draw the neccassary information and also form summaries down the line.
#
# ok so lets begin on sentintment analysis

# %% [markdown]
# # Starter Sentiment + Summary (NLTK VADER)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

def feedback_response(user_input, sample_n=3):
    # Step 1: Fuzzy match instructor
    match = find_best_faculty(user_input)
    if not match:
        return "I couldn’t find that instructor. Try a full or closer name."
    fid, full_name = match

    # Step 2: Fetch comments
    cursor.execute("""
        SELECT comment_text
        FROM FeedbackCorpus
        WHERE faculty_id = ?
    """, (fid,))
    comments = [r[0] for r in cursor.fetchall()]
    if not comments:
        return f"No qualitative feedback available for {full_name}."

    # Step 3: Sentiment analysis
    scores = [sia.polarity_scores(c)["compound"] for c in comments if c.strip()]
    pos = sum(1 for s in scores if s > 0.05)
    neg = sum(1 for s in scores if s < -0.05)
    neu = len(scores) - pos - neg
    total = len(scores)
    avg = sum(scores) / total if total else 0

    sentiment_label = "positive" if avg > 0.1 else "mixed" if abs(avg) <= 0.1 else "negative"

    # Step 4: Build consultant-style response
    response = [
        f"Feedback for {full_name} is mostly {sentiment_label}.",
        f"Breakdown: {pos/total:.0%} positive, {neu/total:.0%} neutral, {neg/total:.0%} negative."
    ]

    # Step 5: Sample comments
    sample_comments = comments[:sample_n]
    if sample_comments:
        response.append("Representative comments:")
        for c in sample_comments:
            response.append(f"- \"{c}\"")

    return "\n".join(response)

# %%
# Some basic stress testing
# Evaluation test queries
test_queries = [
    "Tell me about Afundi",                          # Instructor lookup
    "Summarize feedback for Mohamed",                # Feedback + sentiment summary
    "Results for Odoyo",                             # Lookup by surname
    "Which instructors got an A?",                   # Grade filter
    "Who received a C?",                             # Grade filter lower performers
    "List instructors with scores below 3.5",        # Score filter (below)
    "Which instructors scored exactly 4.0?",         # Score filter (equality)
    "Top 5 performers",                              # Ranking
    "What feedback did students give Gitahi?",       # Feedback query
    "Evaluation for a nonexistent instructor"        # Edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: Tell me about Afundi
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Mwanashehe S. -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Owuor, John David_Ouma -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Gitahi, Jesse Elikanah_Machirah -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Odoyo, Fredrick -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Gatumo, Francis Mambo -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Oyaro, Kepha N._Makori -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ogada, Agnes Owuor -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kuria,, John -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Achoki, George -> similarity: 35.294117647058826
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Amos Gitau -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Cheluget, Elizabeth Jepchumba -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Nyabere, Emily -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Nyong'o, Kwame o -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Gachukia, Jennifer Wangari -> similarity: 34.285714285714285
# [DEBUG] Comparing: tell me about afundi vs Oriedi, David Opondo -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ndirangu, Dalton -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs Ondieki, Benard Odhiambo -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Muriithi, Petronilla Muthoni -> similarity: 51.61290322580645
# [DEBUG] Comparing: tell me about afundi vs Namuye, Silvester -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Afundi, Patrick Omuhinda -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Ahenda, John Ang'udi -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Wamuyu, Patrick Kanyi -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Ndiege, Joshua Rumo -> similarity: 41.02564102564103
# [DEBUG] Comparing: tell me about afundi vs Basweti, Kevin Ogachi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Aloo, Linus Alwal -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Oteri, Malack Omae -> similarity: 48.0
# [DEBUG] Comparing: tell me about afundi vs Nyete, Abraham Mutunga -> similarity: 47.61904761904762
# [DEBUG] Comparing: tell me about afundi vs Makhaso, Byron Chesoli -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about afundi vs Kogo, Vincent Kibet -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Gachanga, Esther Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mwalili, Tobias Mbithi -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Mutanu, Leah -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Nderu, Lawrence -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Henry Njogo -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Ondiek, Collins Oduor -> similarity: 34.14634146341463
# [DEBUG] Comparing: tell me about afundi vs Githinji, Stanley Muturi,, Dr. -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Kayeyia, Ernest Madara -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Abdullahi Mohamed -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Jonathan Maina -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Mbatia, Betty Nyambura -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Okanya, Patrick Wafula_Simiyu -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Muendo, Daniel -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Muniafu, Max Maina -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Kamanu, Timothy_Kevin Kuria -> similarity: 38.297872340425535
# [DEBUG] Comparing: tell me about afundi vs Kamuri, Simon -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Kabacho, Mwangi -> similarity: 51.85185185185186
# [DEBUG] Comparing: tell me about afundi vs Gitoho, Salome Wanjiru -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Gachago, Philip Muriithi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Kimathi, George Eliphas -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Misawo, Florence Awuor -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Odendo, Moses -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mbithi, Jonathan Ndolo -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Muchiri, Catherine Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Ogola, Mary Ganga -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Namuye, Maria -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karimi, James Mark,, Ngari -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Kibet, Eric M. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Akuma, Samson Mainye -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Awuor, Emmanuel -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Ouma,, Duncan Ochieng -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kobuthi, Edward N. -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Wetiba, Johnson Kwanusu -> similarity: 32.55813953488372
# [DEBUG] Comparing: tell me about afundi vs Njui, Francis -> similarity: 45.45454545454546
# [DEBUG] Comparing: tell me about afundi vs Miriti, Gilbert Mugambi -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Maina, Muchara Dr -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Opondo, Mary Awuor -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ochola, Phares B -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Ogola, Jacob Owuor -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Musuva, Gladys Mwende -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mbere, Sarah Wanjiru -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Mosoti, Zachary -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Were, Jane N. -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Muriu, Marylyn Doreen -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Mbotu, Michael Mulandi -> similarity: 60.0
# [DEBUG] Comparing: tell me about afundi vs Nduati, Gidraph J. -> similarity: 29.629629629629626
# [DEBUG] Comparing: tell me about afundi vs Musebe, Edward Achieng -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Sule, Odhiambo F.E. -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Ogendi, Paul -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Joseph, Muchina -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Okanda, Paul M -> similarity: 35.294117647058826
# [DEBUG] Comparing: tell me about afundi vs Newa, Fred Omondi -> similarity: 45.16129032258065
# [DEBUG] Comparing: tell me about afundi vs K'aol, George O. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Getecha, Ciru W. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Ndegwa, Joyce Watetu -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kamau, Joseph -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs S   Kiruthu, Lucy Nyaguthii -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Mburu, Esther Njambi -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs F   Wambalaba, Francis -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Wainaina, Gituro -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Njenga, Edward Gachangi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Nguru, Faith Wariara -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Noah, Naumih M. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Amuhaya, Edith Khavwajira -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs Wangui, Ruth Njeri -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Wanjiku -> similarity: 46.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Kimani, Nathan Muya -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Otieno, Symon_Peter Victor -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Odhiambo, Terry J. -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Osiro, Moses Adama -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Asembo, Kenedy Onyango -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Onyango, Resila -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Kirui, Gideon Kipng'eno -> similarity: 27.77777777777778
# [DEBUG] Comparing: tell me about afundi vs Sungi, Simeon P. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Arasa, Josephine -> similarity: 27.77777777777777
# [DEBUG] Comparing: tell me about afundi vs Newa, Elsie Opiyo -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs Mohamed, Hussein Abdi -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Peterson Kimiru -> similarity: 41.86046511627907
# [DEBUG] Comparing: tell me about afundi vs Lio, Sammy A.N. -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Kakumu, Muema Pius -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Ochieng', Robi Koki -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Magut, Zuhra C. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Gromov, Mikhail D. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Nginda, Ronald Robert_Abwova -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Mbole, Elizabeth M. -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Koshal, Jeremiah Ntaloi_Ole -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Sikolia, Geoffrey Serede,, Dr. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Gichaga, Lucy Wanjiku -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Wachana, Paul -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Ouma,, Judy Aluoch -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Ouma, Zackayo Omolo -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Okech, Timothy C. -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Onono-Okelo, Perez A. -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Owili, Florence Akinyi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Martin Chege -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Oduol, Charles -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Nyarigoti, Naom Moraa -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs F   Buyu, Matthew -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Peter Getyngo -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Ambiyo, Sarah -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Nyamasyo, Eunice A. -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Onditi, Tom -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Jefwa, Judith Jai_Jaleha -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Milton, Obote J. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kiai, Alice Wanjira -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Awuor, Quin Elizabeth -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Ogutu, Emily Atieno -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Mburu, Martin -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Oketch, Omondi -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Nyarige, Pamela Kwamboka -> similarity: 47.36842105263158
# [DEBUG] Comparing: tell me about afundi vs Njihia, David Thiru -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about afundi vs Scott, Bellows J -> similarity: 47.61904761904761
# [DEBUG] Comparing: tell me about afundi vs Rintari, Ann Wanjiku -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Kiaye, Mary A. -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Omolo, Calvin Andeve -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Irari, Annette Wangui -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Nyambati, Grace K -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Njeri, Teresia -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about afundi vs Okallo, Dick Daniel -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Andango, Elizabeth -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Akach, Joyce Akinyi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Onsomu, Clive Mochiemo -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kioni, Benson Muthoga -> similarity: 39.02439024390244
# [DEBUG] Comparing: tell me about afundi vs Kariuki, Lucy Nyawira -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Wainaina, Samuel -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Ngugi, Wilson Mbugua -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Gatauwa,, James M. -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Joseph, Bertha B -> similarity: 38.46153846153846
# [DEBUG] Comparing: tell me about afundi vs Mirichii, John Mwaniki -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Muriithi, Jane Gathigia -> similarity: 37.2093023255814
# [DEBUG] Comparing: tell me about afundi vs Bwire, Albert C. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Bii, Cosmas K -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Owuor, Benard O -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karugu, Mureithi -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Nginye, Michael Gichangi -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Mulwa, Harrison Munyao -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Akosa, E. Wambalaba -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Francis Gitonga -> similarity: 29.411764705882348
# [DEBUG] Comparing: tell me about afundi vs F   Iraki, Fredrick Kang'ethe -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Adan, Ali -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Otieno, Pauline Adhiambo -> similarity: 44.99999999999999
# [DEBUG] Comparing: tell me about afundi vs Kalunda, Elizabeth Nthambi -> similarity: 43.47826086956522
# [DEBUG] Comparing: tell me about afundi vs Kigwilu, Peter Changilwa -> similarity: 41.02564102564102
# [DEBUG] Comparing: tell me about afundi vs Amwayi, Oliver Shitanda -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Ireri, Kioko -> similarity: 26.086956521739136
# [DEBUG] Comparing: tell me about afundi vs Nyaribo, Cyprian Mose -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Kakai, Pius Wanyonyi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mutisya Mutungi, Mary Mumbua -> similarity: 45.714285714285715
# [DEBUG] Comparing: tell me about afundi vs Njeru, Godwin Kinyua -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Mbugua, John Chege -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Mage, Grace Nduta -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Muindi, Peter M. -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Mulindi, Patrick M. -> similarity: 35.8974358974359
# [DEBUG] Comparing: tell me about afundi vs Maranga,, Vincent Nyamari -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Terefe, Ermias Mergia -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Obbanda, Luka Epainito -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Kimani, Joan Wanjiru -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Macharia, Hannah Muthoni -> similarity: 42.85714285714286
# [DEBUG] Comparing: tell me about afundi vs Maumo, Leonard Oluoch -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Joseph Kimani -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Simon Githaiga -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Mwakina, Rozina Munna -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Behr, Agnes Wanjiru -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Ylonen, Aleksi Erik -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Maganda, Willis Otieno -> similarity: 42.857142857142854
# [DEBUG] Comparing: tell me about afundi vs Ali, Fatuma Ahmed -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Gathua, Michael M. -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Muliro, Wilfred Nasong'o -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Odaba, Dan Noel -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Nyaanga, Gideon Nyamweya -> similarity: 31.818181818181813
# [DEBUG] Comparing: tell me about afundi vs Katete, George Onyango -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Pauline W. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Wangechi, Chege -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Munyi, Elijah N -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Githigaro, John Mwangi -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs F   Veney, Cassandra Rachel -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Magero, Patrick L.K -> similarity: 36.36363636363637
# [DEBUG] Comparing: tell me about afundi vs Gisore, Billiah N. -> similarity: 34.78260869565217
# [DEBUG] Comparing: tell me about afundi vs Kabongah, George Odhiambo -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ng'eno, Weldon Kibet -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Mashiwa, Maurice -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs F   Munene, Macharia -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Mbae, Justus -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Kavoo, Mark Kavoo -> similarity: 35.71428571428571
# [DEBUG] Comparing: tell me about afundi vs S   Maina, Ann Wambui -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Machoka, Philip Gichaba -> similarity: 32.55813953488372
# [DEBUG] Comparing: tell me about afundi vs Macharia, Jimmy -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Wangai, Njoroge Mambo -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs S   Mutune, Loraine -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Sifuna, Austin Makokha -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Karoki, Samuel Githinji -> similarity: 38.888888888888886
# [DEBUG] Comparing: tell me about afundi vs Baraza, Cyrus M -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Gachie, Richard K. -> similarity: 26.66666666666667
# [DEBUG] Comparing: tell me about afundi vs Nakamura, Katsuji -> similarity: 41.379310344827594
# [DEBUG] Comparing: tell me about afundi vs Githinji, Keziah Wangui,, Ms. -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Omondi, Daniel Onyango -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Telewa, Christabel -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Oiye, Fredrick Ogutu,, Mr. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Karanja, Moses Mwangi,, Mr -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Kidaha, Alfred Usagi -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Waga, Fred -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Mwangi, Isaac -> similarity: 31.57894736842105
# [DEBUG] Comparing: tell me about afundi vs Mwilu, Asha Ahmed -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Bosire, Julius Ombui,, Dr. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Kamau, Sheila Wanjiku -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Oranga, James Odhiambo -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Muindi, Benjamin -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Owilla, Hesbon Hansen -> similarity: 47.36842105263158
# [DEBUG] Comparing: tell me about afundi vs Mule, Daniel -> similarity: 47.61904761904761
# [DEBUG] Comparing: tell me about afundi vs Kimotho, Stephen Gichuhi -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Karume, Michelle Wariara -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Githua, Oscar Wanyutu -> similarity: 35.89743589743589
# [DEBUG] Comparing: tell me about afundi vs Nyambegera, Stephen Morangi -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Mairura, Christopher Joseph -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Kaluyu, Veronicah -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Matula, Phylisters Daizy -> similarity: 35.0
# [DEBUG] Comparing: tell me about afundi vs Linge, Teresia K.K. -> similarity: 30.769230769230774
# [DEBUG] Comparing: tell me about afundi vs Obila, Onyango James,, Mr. -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs Njenga, Kefah Muiruri -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Owino, Edward Otieno -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kangu, Maureen -> similarity: 46.15384615384615
# [DEBUG] Comparing: tell me about afundi vs Maore, Stephen K. -> similarity: 32.432432432432435
# [DEBUG] Comparing: tell me about afundi vs S   Kiptum, Purity Jebotibin -> similarity: 43.75
# [DEBUG] Comparing: tell me about afundi vs Were, Jamen H. -> similarity: 45.45454545454546
# [DEBUG] Comparing: tell me about afundi vs Wafula, Maurine Maraka -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Khadioli, Nancy -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Levi Ng'ang'a -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Njuguna, Lydia Nyambura -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kahiri, Caroline Njeri,, Dr. -> similarity: 30.303030303030297
# [DEBUG] Comparing: tell me about afundi vs Githiri, John Gitonga -> similarity: 27.77777777777778
# [DEBUG] Comparing: tell me about afundi vs Nyakundi, Jane -> similarity: 50.0
# [DEBUG] Comparing: tell me about afundi vs Oyigo, Josephat DR -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Ndangili, Peter Munyao -> similarity: 47.61904761904762
# [DEBUG] Comparing: tell me about afundi vs Maima, Apollo Odhiambo -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Gitau, Samuel -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Kimani, Larry M -> similarity: 28.57142857142857
# [DEBUG] Comparing: tell me about afundi vs Njogu, Peter Mbugua -> similarity: 41.17647058823529
# [DEBUG] Comparing: tell me about afundi vs Munyendo, Lincoln Were -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Odongo, Elizabeth Amwayi -> similarity: 44.44444444444444
# [DEBUG] Comparing: tell me about afundi vs Defersha, Amsalu Degu -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Ndungu, Tabitha K. -> similarity: 32.25806451612904
# [DEBUG] Comparing: tell me about afundi vs Mwaniki, Moses -> similarity: 30.000000000000004
# [DEBUG] Comparing: tell me about afundi vs Mbugua, Paul Mungai -> similarity: 47.05882352941176
# [DEBUG] Comparing: tell me about afundi vs Simiyu, Lucy -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Musau, Josephine Ndanu -> similarity: 31.999999999999996
# [DEBUG] Comparing: tell me about afundi vs Ireri, Niceta Wanja -> similarity: 37.83783783783784
# [DEBUG] Comparing: tell me about afundi vs Ndero, Peter K. -> similarity: 40.0
# [DEBUG] Comparing: tell me about afundi vs Awuor, Anita Margaret -> similarity: 43.90243902439025
# [DEBUG] Comparing: tell me about afundi vs Ogunde, Jane  Awuor -> similarity: 42.10526315789474
# [DEBUG] Comparing: tell me about afundi vs Waithima, Charity Wangui -> similarity: 42.10526315789473
# [DEBUG] Comparing: tell me about afundi vs Munyae, Margaret M. -> similarity: 37.03703703703704
# [DEBUG] Comparing: tell me about afundi vs Bironga, Sophia Moraa -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Kihara, Michael -> similarity: 34.28571428571429
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Margaret -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Mutwiri, Marion Kirumba -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs Mwangi, William K. -> similarity: 36.8421052631579
# [DEBUG] Comparing: tell me about afundi vs F   Munywoki, Samson -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Njoroge, Joseph -> similarity: 27.27272727272727
# [DEBUG] Comparing: tell me about afundi vs Panchani, Roopam Lalji -> similarity: 33.33333333333333
# [DEBUG] Comparing: tell me about afundi vs Omollo, Joseph Owade -> similarity: 43.24324324324324
# [DEBUG] Comparing: tell me about afundi vs Webbo, Roselynne Kyambi -> similarity: 42.42424242424242
# [DEBUG] Comparing: tell me about afundi vs Ongecha, Francisca Atieno -> similarity: 35.55555555555556
# [DEBUG] Comparing: tell me about afundi vs Muturi, Lucy N. -> similarity: 41.666666666666664
# [DEBUG] Comparing: tell me about afundi vs Nyaga, Nancy Ng'endo -> similarity: 31.25
# [DEBUG] Comparing: tell me about afundi vs Brown, Dana Basnight -> similarity: 38.70967741935484
# [DEBUG] Comparing: tell me about afundi vs Kinuthia, Annie Njoki -> similarity: 35.29411764705882
# [DEBUG] Comparing: tell me about afundi vs Kiai, Gachanja -> similarity: 30.76923076923077
# [DEBUG] Comparing: tell me about afundi vs Ogore, Fredrick Michae -> similarity: 38.095238095238095
# [DEBUG] Comparing: tell me about afundi vs Otiende, Noah Ochieng -> similarity: 37.5
# [DEBUG] Comparing: tell me about afundi vs Odek, Anthony W. -> similarity: 33.333333333333336
# [DEBUG] Comparing: tell me about afundi vs Rubio Gijon, Pablo -> similarity: 34.48275862068966
# [DEBUG] Comparing: tell me about afundi vs Koigi, Rachel Wanjiru -> similarity: 40.0
# No evaluation data found for Tell me about Afundi.
#
# Query: Summarize feedback for Mohamed
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Results for Odoyo
# [DEBUG] Comparing: results for odoyo vs Mohamed, Mwanashehe S. -> similarity: 25.641025641025635
# [DEBUG] Comparing: results for odoyo vs Owuor, John David_Ouma -> similarity: 41.17647058823529
# [DEBUG] Comparing: results for odoyo vs Gitahi, Jesse Elikanah_Machirah -> similarity: 25.806451612903224
# [DEBUG] Comparing: results for odoyo vs Odoyo, Fredrick -> similarity: 50.0
# [DEBUG] Comparing: results for odoyo vs Gatumo, Francis Mambo -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Oyaro, Kepha N._Makori -> similarity: 30.769230769230774
# [DEBUG] Comparing: results for odoyo vs Ogada, Agnes Owuor -> similarity: 40.0
# [DEBUG] Comparing: results for odoyo vs Kuria,, John -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Achoki, George -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Njuguna, Amos Gitau -> similarity: 25.806451612903224
# [DEBUG] Comparing: results for odoyo vs Cheluget, Elizabeth Jepchumba -> similarity: 29.629629629629626
# [DEBUG] Comparing: results for odoyo vs Nyabere, Emily -> similarity: 31.57894736842105
# [DEBUG] Comparing: results for odoyo vs Nyong'o, Kwame o -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Gachukia, Jennifer Wangari -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Oriedi, David Opondo -> similarity: 41.666666666666664
# [DEBUG] Comparing: results for odoyo vs Ndirangu, Dalton -> similarity: 38.46153846153846
# [DEBUG] Comparing: results for odoyo vs Ondieki, Benard Odhiambo -> similarity: 38.70967741935484
# [DEBUG] Comparing: results for odoyo vs Muriithi, Petronilla Muthoni -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Namuye, Silvester -> similarity: 36.36363636363637
# [DEBUG] Comparing: results for odoyo vs Afundi, Patrick Omuhinda -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Ahenda, John Ang'udi -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Wamuyu, Patrick Kanyi -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Ndiege, Joshua Rumo -> similarity: 38.70967741935484
# [DEBUG] Comparing: results for odoyo vs Basweti, Kevin Ogachi -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Aloo, Linus Alwal -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Oteri, Malack Omae -> similarity: 25.0
# [DEBUG] Comparing: results for odoyo vs Nyete, Abraham Mutunga -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Makhaso, Byron Chesoli -> similarity: 35.8974358974359
# [DEBUG] Comparing: results for odoyo vs Kogo, Vincent Kibet -> similarity: 33.33333333333333
# [DEBUG] Comparing: results for odoyo vs Gachanga, Esther Wanjiru -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Mwalili, Tobias Mbithi -> similarity: 24.242424242424242
# [DEBUG] Comparing: results for odoyo vs Mutanu, Leah -> similarity: 30.000000000000004
# [DEBUG] Comparing: results for odoyo vs Nderu, Lawrence -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Mwangi, Henry Njogo -> similarity: 37.03703703703704
# [DEBUG] Comparing: results for odoyo vs Ondiek, Collins Oduor -> similarity: 44.44444444444444
# [DEBUG] Comparing: results for odoyo vs Githinji, Stanley Muturi,, Dr. -> similarity: 37.5
# [DEBUG] Comparing: results for odoyo vs Kayeyia, Ernest Madara -> similarity: 41.379310344827594
# [DEBUG] Comparing: results for odoyo vs Mohamed, Abdullahi Mohamed -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Mwangi, Jonathan Maina -> similarity: 18.75
# [DEBUG] Comparing: results for odoyo vs Mbatia, Betty Nyambura -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs Okanya, Patrick Wafula_Simiyu -> similarity: 30.434782608695656
# [DEBUG] Comparing: results for odoyo vs Muendo, Daniel -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Muniafu, Max Maina -> similarity: 23.076923076923073
# [DEBUG] Comparing: results for odoyo vs Kamanu, Timothy_Kevin Kuria -> similarity: 25.0
# [DEBUG] Comparing: results for odoyo vs Kamuri, Simon -> similarity: 30.76923076923077
# [DEBUG] Comparing: results for odoyo vs Kabacho, Mwangi -> similarity: 17.391304347826086
# [DEBUG] Comparing: results for odoyo vs Gitoho, Salome Wanjiru -> similarity: 30.769230769230774
# [DEBUG] Comparing: results for odoyo vs Gachago, Philip Muriithi -> similarity: 20.68965517241379
# [DEBUG] Comparing: results for odoyo vs Kimathi, George Eliphas -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Misawo, Florence Awuor -> similarity: 37.5
# [DEBUG] Comparing: results for odoyo vs Odendo, Moses -> similarity: 44.44444444444444
# [DEBUG] Comparing: results for odoyo vs Mbithi, Jonathan Ndolo -> similarity: 37.5
# [DEBUG] Comparing: results for odoyo vs Muchiri, Catherine Wanjiru -> similarity: 27.586206896551722
# [DEBUG] Comparing: results for odoyo vs Ogola, Mary Ganga -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Namuye, Maria -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs Karimi, James Mark,, Ngari -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Kibet, Eric M. -> similarity: 38.46153846153846
# [DEBUG] Comparing: results for odoyo vs Akuma, Samson Mainye -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Awuor, Emmanuel -> similarity: 40.0
# [DEBUG] Comparing: results for odoyo vs Ouma,, Duncan Ochieng -> similarity: 25.0
# [DEBUG] Comparing: results for odoyo vs Kobuthi, Edward N. -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Wetiba, Johnson Kwanusu -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Njui, Francis -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Miriti, Gilbert Mugambi -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Maina, Muchara Dr -> similarity: 30.76923076923077
# [DEBUG] Comparing: results for odoyo vs Opondo, Mary Awuor -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Ochola, Phares B -> similarity: 42.42424242424242
# [DEBUG] Comparing: results for odoyo vs Ogola, Jacob Owuor -> similarity: 37.5
# [DEBUG] Comparing: results for odoyo vs Musuva, Gladys Mwende -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Mbere, Sarah Wanjiru -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Mosoti, Zachary -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Were, Jane N. -> similarity: 31.999999999999996
# [DEBUG] Comparing: results for odoyo vs Muriu, Marylyn Doreen -> similarity: 41.17647058823529
# [DEBUG] Comparing: results for odoyo vs Mbotu, Michael Mulandi -> similarity: 29.629629629629626
# [DEBUG] Comparing: results for odoyo vs Nduati, Gidraph J. -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Musebe, Edward Achieng -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Sule, Odhiambo F.E. -> similarity: 50.0
# [DEBUG] Comparing: results for odoyo vs Ogendi, Paul -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Joseph, Muchina -> similarity: 21.052631578947366
# [DEBUG] Comparing: results for odoyo vs Okanda, Paul M -> similarity: 38.70967741935484
# [DEBUG] Comparing: results for odoyo vs Newa, Fred Omondi -> similarity: 45.16129032258065
# [DEBUG] Comparing: results for odoyo vs K'aol, George O. -> similarity: 41.379310344827594
# [DEBUG] Comparing: results for odoyo vs Getecha, Ciru W. -> similarity: 35.71428571428571
# [DEBUG] Comparing: results for odoyo vs Ndegwa, Joyce Watetu -> similarity: 32.432432432432435
# [DEBUG] Comparing: results for odoyo vs Kamau, Joseph -> similarity: 26.086956521739136
# [DEBUG] Comparing: results for odoyo vs S   Kiruthu, Lucy Nyaguthii -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Mburu, Esther Njambi -> similarity: 38.70967741935484
# [DEBUG] Comparing: results for odoyo vs F   Wambalaba, Francis -> similarity: 27.02702702702703
# [DEBUG] Comparing: results for odoyo vs Wainaina, Gituro -> similarity: 23.076923076923073
# [DEBUG] Comparing: results for odoyo vs Njenga, Edward Gachangi -> similarity: 25.806451612903224
# [DEBUG] Comparing: results for odoyo vs Nguru, Faith Wariara -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Noah, Naumih M. -> similarity: 17.391304347826086
# [DEBUG] Comparing: results for odoyo vs Amuhaya, Edith Khavwajira -> similarity: 24.242424242424242
# [DEBUG] Comparing: results for odoyo vs Wangui, Ruth Njeri -> similarity: 37.03703703703704
# [DEBUG] Comparing: results for odoyo vs Mbugua, Wanjiku -> similarity: 17.391304347826086
# [DEBUG] Comparing: results for odoyo vs Kimani, Nathan Muya -> similarity: 23.076923076923073
# [DEBUG] Comparing: results for odoyo vs Otieno, Symon_Peter Victor -> similarity: 35.71428571428571
# [DEBUG] Comparing: results for odoyo vs Odhiambo, Terry J. -> similarity: 34.28571428571429
# [DEBUG] Comparing: results for odoyo vs Osiro, Moses Adama -> similarity: 31.999999999999996
# [DEBUG] Comparing: results for odoyo vs Asembo, Kenedy Onyango -> similarity: 36.36363636363637
# [DEBUG] Comparing: results for odoyo vs Onyango, Resila -> similarity: 50.0
# [DEBUG] Comparing: results for odoyo vs Kirui, Gideon Kipng'eno -> similarity: 34.48275862068966
# [DEBUG] Comparing: results for odoyo vs Sungi, Simeon P. -> similarity: 35.71428571428571
# [DEBUG] Comparing: results for odoyo vs Arasa, Josephine -> similarity: 30.76923076923077
# [DEBUG] Comparing: results for odoyo vs Newa, Elsie Opiyo -> similarity: 50.0
# [DEBUG] Comparing: results for odoyo vs Mohamed, Hussein Abdi -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Mwangi, Peterson Kimiru -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Lio, Sammy A.N. -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Kakumu, Muema Pius -> similarity: 24.0
# [DEBUG] Comparing: results for odoyo vs Ochieng', Robi Koki -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Magut, Zuhra C. -> similarity: 37.03703703703704
# [DEBUG] Comparing: results for odoyo vs Gromov, Mikhail D. -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Nginda, Ronald Robert_Abwova -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Mbole, Elizabeth M. -> similarity: 27.586206896551722
# [DEBUG] Comparing: results for odoyo vs Koshal, Jeremiah Ntaloi_Ole -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Sikolia, Geoffrey Serede,, Dr. -> similarity: 38.297872340425535
# [DEBUG] Comparing: results for odoyo vs Gichaga, Lucy Wanjiku -> similarity: 21.05263157894737
# [DEBUG] Comparing: results for odoyo vs Wachana, Paul -> similarity: 22.22222222222222
# [DEBUG] Comparing: results for odoyo vs Ouma,, Judy Aluoch -> similarity: 34.28571428571429
# [DEBUG] Comparing: results for odoyo vs Ouma, Zackayo Omolo -> similarity: 41.666666666666664
# [DEBUG] Comparing: results for odoyo vs Okech, Timothy C. -> similarity: 31.999999999999996
# [DEBUG] Comparing: results for odoyo vs Onono-Okelo, Perez A. -> similarity: 36.8421052631579
# [DEBUG] Comparing: results for odoyo vs Owili, Florence Akinyi -> similarity: 36.36363636363637
# [DEBUG] Comparing: results for odoyo vs Njoroge, Martin Chege -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Oduol, Charles -> similarity: 38.70967741935484
# [DEBUG] Comparing: results for odoyo vs Nyarigoti, Naom Moraa -> similarity: 36.8421052631579
# [DEBUG] Comparing: results for odoyo vs F   Buyu, Matthew -> similarity: 25.0
# [DEBUG] Comparing: results for odoyo vs Mbugua, Peter Getyngo -> similarity: 41.379310344827594
# [DEBUG] Comparing: results for odoyo vs Ambiyo, Sarah -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs Nyamasyo, Eunice A. -> similarity: 24.0
# [DEBUG] Comparing: results for odoyo vs Onditi, Tom -> similarity: 37.5
# [DEBUG] Comparing: results for odoyo vs Jefwa, Judith Jai_Jaleha -> similarity: 29.629629629629626
# [DEBUG] Comparing: results for odoyo vs Milton, Obote J. -> similarity: 41.379310344827594
# [DEBUG] Comparing: results for odoyo vs Kiai, Alice Wanjira -> similarity: 23.076923076923073
# [DEBUG] Comparing: results for odoyo vs Awuor, Quin Elizabeth -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Ogutu, Emily Atieno -> similarity: 33.33333333333333
# [DEBUG] Comparing: results for odoyo vs Mburu, Martin -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Oketch, Omondi -> similarity: 42.85714285714286
# [DEBUG] Comparing: results for odoyo vs Nyarige, Pamela Kwamboka -> similarity: 29.268292682926827
# [DEBUG] Comparing: results for odoyo vs Njihia, David Thiru -> similarity: 22.22222222222223
# [DEBUG] Comparing: results for odoyo vs Scott, Bellows J -> similarity: 35.71428571428571
# [DEBUG] Comparing: results for odoyo vs Rintari, Ann Wanjiku -> similarity: 30.76923076923077
# [DEBUG] Comparing: results for odoyo vs Kiaye, Mary A. -> similarity: 30.76923076923077
# [DEBUG] Comparing: results for odoyo vs Omolo, Calvin Andeve -> similarity: 27.27272727272727
# [DEBUG] Comparing: results for odoyo vs Irari, Annette Wangui -> similarity: 25.0
# [DEBUG] Comparing: results for odoyo vs Nyambati, Grace K -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Njeri, Teresia -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Okallo, Dick Daniel -> similarity: 30.76923076923077
# [DEBUG] Comparing: results for odoyo vs Andango, Elizabeth -> similarity: 34.28571428571429
# [DEBUG] Comparing: results for odoyo vs Akach, Joyce Akinyi -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs Onsomu, Clive Mochiemo -> similarity: 30.769230769230774
# [DEBUG] Comparing: results for odoyo vs Kioni, Benson Muthoga -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Kariuki, Lucy Nyawira -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Wainaina, Samuel -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Ngugi, Wilson Mbugua -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Gatauwa,, James M. -> similarity: 27.27272727272727
# [DEBUG] Comparing: results for odoyo vs Joseph, Bertha B -> similarity: 29.629629629629626
# [DEBUG] Comparing: results for odoyo vs Mirichii, John Mwaniki -> similarity: 25.0
# [DEBUG] Comparing: results for odoyo vs Muriithi, Jane Gathigia -> similarity: 25.0
# [DEBUG] Comparing: results for odoyo vs Bwire, Albert C. -> similarity: 41.666666666666664
# [DEBUG] Comparing: results for odoyo vs Bii, Cosmas K -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Owuor, Benard O -> similarity: 43.47826086956522
# [DEBUG] Comparing: results for odoyo vs Karugu, Mureithi -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Nginye, Michael Gichangi -> similarity: 21.42857142857143
# [DEBUG] Comparing: results for odoyo vs Mulwa, Harrison Munyao -> similarity: 41.379310344827594
# [DEBUG] Comparing: results for odoyo vs Akosa, E. Wambalaba -> similarity: 22.22222222222223
# [DEBUG] Comparing: results for odoyo vs Ndungu, Francis Gitonga -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs F   Iraki, Fredrick Kang'ethe -> similarity: 31.818181818181813
# [DEBUG] Comparing: results for odoyo vs Adan, Ali -> similarity: 23.07692307692308
# [DEBUG] Comparing: results for odoyo vs Otieno, Pauline Adhiambo -> similarity: 34.14634146341463
# [DEBUG] Comparing: results for odoyo vs Kalunda, Elizabeth Nthambi -> similarity: 23.529411764705888
# [DEBUG] Comparing: results for odoyo vs Kigwilu, Peter Changilwa -> similarity: 25.806451612903224
# [DEBUG] Comparing: results for odoyo vs Amwayi, Oliver Shitanda -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Ireri, Kioko -> similarity: 42.10526315789473
# [DEBUG] Comparing: results for odoyo vs Nyaribo, Cyprian Mose -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Kakai, Pius Wanyonyi -> similarity: 35.71428571428571
# [DEBUG] Comparing: results for odoyo vs Mutisya Mutungi, Mary Mumbua -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Njeru, Godwin Kinyua -> similarity: 37.03703703703704
# [DEBUG] Comparing: results for odoyo vs Mbugua, John Chege -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs Mage, Grace Nduta -> similarity: 34.78260869565217
# [DEBUG] Comparing: results for odoyo vs Muindi, Peter M. -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Mulindi, Patrick M. -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Maranga,, Vincent Nyamari -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Terefe, Ermias Mergia -> similarity: 31.999999999999996
# [DEBUG] Comparing: results for odoyo vs Obbanda, Luka Epainito -> similarity: 24.0
# [DEBUG] Comparing: results for odoyo vs Kimani, Joan Wanjiru -> similarity: 27.02702702702703
# [DEBUG] Comparing: results for odoyo vs Macharia, Hannah Muthoni -> similarity: 26.086956521739136
# [DEBUG] Comparing: results for odoyo vs Maumo, Leonard Oluoch -> similarity: 41.17647058823529
# [DEBUG] Comparing: results for odoyo vs Njuguna, Joseph Kimani -> similarity: 24.242424242424242
# [DEBUG] Comparing: results for odoyo vs Njoroge, Simon Githaiga -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Mwakina, Rozina Munna -> similarity: 21.42857142857143
# [DEBUG] Comparing: results for odoyo vs Behr, Agnes Wanjiru -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Ylonen, Aleksi Erik -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Maganda, Willis Otieno -> similarity: 37.03703703703704
# [DEBUG] Comparing: results for odoyo vs Ali, Fatuma Ahmed -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Gathua, Michael M. -> similarity: 27.27272727272727
# [DEBUG] Comparing: results for odoyo vs Muliro, Wilfred Nasong'o -> similarity: 38.70967741935484
# [DEBUG] Comparing: results for odoyo vs Odaba, Dan Noel -> similarity: 34.78260869565217
# [DEBUG] Comparing: results for odoyo vs Nyaanga, Gideon Nyamweya -> similarity: 27.586206896551722
# [DEBUG] Comparing: results for odoyo vs Katete, George Onyango -> similarity: 47.05882352941176
# [DEBUG] Comparing: results for odoyo vs Ndungu, Pauline W. -> similarity: 24.0
# [DEBUG] Comparing: results for odoyo vs Wangechi, Chege -> similarity: 17.391304347826086
# [DEBUG] Comparing: results for odoyo vs Munyi, Elijah N -> similarity: 26.086956521739136
# [DEBUG] Comparing: results for odoyo vs Githigaro, John Mwangi -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs F   Veney, Cassandra Rachel -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Magero, Patrick L.K -> similarity: 26.086956521739136
# [DEBUG] Comparing: results for odoyo vs Gisore, Billiah N. -> similarity: 31.999999999999996
# [DEBUG] Comparing: results for odoyo vs Kabongah, George Odhiambo -> similarity: 45.16129032258065
# [DEBUG] Comparing: results for odoyo vs Ng'eno, Weldon Kibet -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Mashiwa, Maurice -> similarity: 22.22222222222222
# [DEBUG] Comparing: results for odoyo vs F   Munene, Macharia -> similarity: 22.85714285714286
# [DEBUG] Comparing: results for odoyo vs Mbae, Justus -> similarity: 42.10526315789473
# [DEBUG] Comparing: results for odoyo vs Kavoo, Mark Kavoo -> similarity: 40.0
# [DEBUG] Comparing: results for odoyo vs S   Maina, Ann Wambui -> similarity: 30.000000000000004
# [DEBUG] Comparing: results for odoyo vs Machoka, Philip Gichaba -> similarity: 20.0
# [DEBUG] Comparing: results for odoyo vs Macharia, Jimmy -> similarity: 27.27272727272727
# [DEBUG] Comparing: results for odoyo vs Wangai, Njoroge Mambo -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs S   Mutune, Loraine -> similarity: 37.5
# [DEBUG] Comparing: results for odoyo vs Sifuna, Austin Makokha -> similarity: 27.586206896551722
# [DEBUG] Comparing: results for odoyo vs Karoki, Samuel Githinji -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Baraza, Cyrus M -> similarity: 37.5
# [DEBUG] Comparing: results for odoyo vs Gachie, Richard K. -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs Nakamura, Katsuji -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Githinji, Keziah Wangui,, Ms. -> similarity: 17.647058823529417
# [DEBUG] Comparing: results for odoyo vs Omondi, Daniel Onyango -> similarity: 44.44444444444444
# [DEBUG] Comparing: results for odoyo vs Telewa, Christabel -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Oiye, Fredrick Ogutu,, Mr. -> similarity: 37.03703703703704
# [DEBUG] Comparing: results for odoyo vs Karanja, Moses Mwangi,, Mr -> similarity: 25.806451612903224
# [DEBUG] Comparing: results for odoyo vs Kidaha, Alfred Usagi -> similarity: 37.83783783783784
# [DEBUG] Comparing: results for odoyo vs Waga, Fred -> similarity: 40.0
# [DEBUG] Comparing: results for odoyo vs Mwangi, Isaac -> similarity: 12.5
# [DEBUG] Comparing: results for odoyo vs Mwilu, Asha Ahmed -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs Bosire, Julius Ombui,, Dr. -> similarity: 42.42424242424242
# [DEBUG] Comparing: results for odoyo vs Kamau, Sheila Wanjiku -> similarity: 20.68965517241379
# [DEBUG] Comparing: results for odoyo vs Oranga, James Odhiambo -> similarity: 42.85714285714286
# [DEBUG] Comparing: results for odoyo vs Muindi, Benjamin -> similarity: 16.666666666666664
# [DEBUG] Comparing: results for odoyo vs Owilla, Hesbon Hansen -> similarity: 27.586206896551722
# [DEBUG] Comparing: results for odoyo vs Mule, Daniel -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Kimotho, Stephen Gichuhi -> similarity: 29.268292682926827
# [DEBUG] Comparing: results for odoyo vs Karume, Michelle Wariara -> similarity: 27.586206896551722
# [DEBUG] Comparing: results for odoyo vs Githua, Oscar Wanyutu -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Nyambegera, Stephen Morangi -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Mairura, Christopher Joseph -> similarity: 42.42424242424242
# [DEBUG] Comparing: results for odoyo vs Kaluyu, Veronicah -> similarity: 27.586206896551722
# [DEBUG] Comparing: results for odoyo vs Matula, Phylisters Daizy -> similarity: 42.85714285714286
# [DEBUG] Comparing: results for odoyo vs Linge, Teresia K.K. -> similarity: 29.629629629629626
# [DEBUG] Comparing: results for odoyo vs Obila, Onyango James,, Mr. -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Njenga, Kefah Muiruri -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Owino, Edward Otieno -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Kangu, Maureen -> similarity: 25.0
# [DEBUG] Comparing: results for odoyo vs Maore, Stephen K. -> similarity: 40.0
# [DEBUG] Comparing: results for odoyo vs S   Kiptum, Purity Jebotibin -> similarity: 30.000000000000004
# [DEBUG] Comparing: results for odoyo vs Were, Jamen H. -> similarity: 30.76923076923077
# [DEBUG] Comparing: results for odoyo vs Wafula, Maurine Maraka -> similarity: 30.769230769230774
# [DEBUG] Comparing: results for odoyo vs Khadioli, Nancy -> similarity: 31.57894736842105
# [DEBUG] Comparing: results for odoyo vs Mbugua, Levi Ng'ang'a -> similarity: 19.999999999999996
# [DEBUG] Comparing: results for odoyo vs Njuguna, Lydia Nyambura -> similarity: 23.529411764705888
# [DEBUG] Comparing: results for odoyo vs Kahiri, Caroline Njeri,, Dr. -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Githiri, John Gitonga -> similarity: 30.303030303030297
# [DEBUG] Comparing: results for odoyo vs Nyakundi, Jane -> similarity: 19.354838709677423
# [DEBUG] Comparing: results for odoyo vs Oyigo, Josephat DR -> similarity: 34.28571428571429
# [DEBUG] Comparing: results for odoyo vs Ndangili, Peter Munyao -> similarity: 42.85714285714286
# [DEBUG] Comparing: results for odoyo vs Maima, Apollo Odhiambo -> similarity: 42.85714285714286
# [DEBUG] Comparing: results for odoyo vs Gitau, Samuel -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Kimani, Larry M -> similarity: 24.0
# [DEBUG] Comparing: results for odoyo vs Njogu, Peter Mbugua -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Munyendo, Lincoln Were -> similarity: 35.8974358974359
# [DEBUG] Comparing: results for odoyo vs Odongo, Elizabeth Amwayi -> similarity: 34.78260869565217
# [DEBUG] Comparing: results for odoyo vs Defersha, Amsalu Degu -> similarity: 31.578947368421055
# [DEBUG] Comparing: results for odoyo vs Ndungu, Tabitha K. -> similarity: 22.85714285714286
# [DEBUG] Comparing: results for odoyo vs Mwaniki, Moses -> similarity: 23.529411764705888
# [DEBUG] Comparing: results for odoyo vs Mbugua, Paul Mungai -> similarity: 23.076923076923073
# [DEBUG] Comparing: results for odoyo vs Simiyu, Lucy -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Musau, Josephine Ndanu -> similarity: 35.29411764705882
# [DEBUG] Comparing: results for odoyo vs Ireri, Niceta Wanja -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Ndero, Peter K. -> similarity: 37.5
# [DEBUG] Comparing: results for odoyo vs Awuor, Anita Margaret -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Ogunde, Jane  Awuor -> similarity: 34.28571428571429
# [DEBUG] Comparing: results for odoyo vs Waithima, Charity Wangui -> similarity: 23.529411764705888
# [DEBUG] Comparing: results for odoyo vs Munyae, Margaret M. -> similarity: 34.78260869565217
# [DEBUG] Comparing: results for odoyo vs Bironga, Sophia Moraa -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Kihara, Michael -> similarity: 30.000000000000004
# [DEBUG] Comparing: results for odoyo vs Njoroge, Margaret -> similarity: 30.000000000000004
# [DEBUG] Comparing: results for odoyo vs Mutwiri, Marion Kirumba -> similarity: 32.25806451612904
# [DEBUG] Comparing: results for odoyo vs Mwangi, William K. -> similarity: 17.14285714285714
# [DEBUG] Comparing: results for odoyo vs F   Munywoki, Samson -> similarity: 40.0
# [DEBUG] Comparing: results for odoyo vs Njoroge, Joseph -> similarity: 34.78260869565217
# [DEBUG] Comparing: results for odoyo vs Panchani, Roopam Lalji -> similarity: 26.66666666666667
# [DEBUG] Comparing: results for odoyo vs Omollo, Joseph Owade -> similarity: 37.83783783783784
# [DEBUG] Comparing: results for odoyo vs Webbo, Roselynne Kyambi -> similarity: 33.333333333333336
# [DEBUG] Comparing: results for odoyo vs Ongecha, Francisca Atieno -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Muturi, Lucy N. -> similarity: 34.48275862068966
# [DEBUG] Comparing: results for odoyo vs Nyaga, Nancy Ng'endo -> similarity: 28.57142857142857
# [DEBUG] Comparing: results for odoyo vs Brown, Dana Basnight -> similarity: 31.999999999999996
# [DEBUG] Comparing: results for odoyo vs Kinuthia, Annie Njoki -> similarity: 29.411764705882348
# [DEBUG] Comparing: results for odoyo vs Kiai, Gachanja -> similarity: 9.999999999999998
# [DEBUG] Comparing: results for odoyo vs Ogore, Fredrick Michae -> similarity: 42.85714285714286
# [DEBUG] Comparing: results for odoyo vs Otiende, Noah Ochieng -> similarity: 31.25
# [DEBUG] Comparing: results for odoyo vs Odek, Anthony W. -> similarity: 38.095238095238095
# [DEBUG] Comparing: results for odoyo vs Rubio Gijon, Pablo -> similarity: 37.03703703703704
# [DEBUG] Comparing: results for odoyo vs Koigi, Rachel Wanjiru -> similarity: 32.25806451612904
# No evaluation data found for Results for Odoyo.
#
# Query: Which instructors got an A?
# Instructors with grade A:
# - Sikolia, Geoffrey Serede,, Dr.: 4.75
# - Macharia, Jimmy: 4.71
# - Kamau, Joseph: 4.71
# - Ali, Fatuma Ahmed: 4.71
# - Nguru, Faith Wariara: 4.70
# - Kimotho, Stephen Gichuhi: 4.70
# - Sifuna, Austin Makokha: 4.64
# - Gachukia, Jennifer Wangari: 4.63
# - Mwangi, Jonathan Maina: 4.60
# - Adan, Ali: 4.60
# - Wachana, Paul: 4.59
# - Mwilu, Asha Ahmed: 4.59
# - Mulindi, Patrick M.: 4.59
# - Ylonen, Aleksi Erik: 4.58
# - Wetiba, Johnson Kwanusu: 4.58
# - Nyete, Abraham Mutunga: 4.58
# - Mburu, Esther Njambi: 4.58
# - Munyi, Elijah N: 4.57
# - Oranga, James Odhiambo: 4.56
# - Nginye, Michael Gichangi: 4.56
# - Nakamura, Katsuji: 4.56
# - Achoki, George: 4.56
# - Ondiek, Collins Oduor: 4.55
# - Kimani, Nathan Muya: 4.55
# - Karume, Michelle Wariara: 4.55
# - Karimi, James Mark,, Ngari: 4.55
# - Kakumu, Muema Pius: 4.55
# - Njeru, Godwin Kinyua: 4.54
# - Njenga, Kefah Muiruri: 4.54
# - Mutisya Mutungi, Mary Mumbua: 4.54
# - Mbugua, Paul Mungai: 4.54
# - Mbotu, Michael Mulandi: 4.54
# - Koshal, Jeremiah Ntaloi_Ole: 4.54
# - Kabongah, George Odhiambo: 4.54
# - Were, Jamen H.: 4.53
# - Sule, Odhiambo F.E.: 4.53
# - Scott, Bellows J: 4.53
# - Ndirangu, Dalton: 4.53
# - Kabacho, Mwangi: 4.53
# - Gatumo, Francis Mambo: 4.53
# - Brown, Dana Basnight: 4.53
# - S   Kiruthu, Lucy Nyaguthii: 4.52
# - Ogada, Agnes Owuor: 4.52
# - Noah, Naumih M.: 4.52
# - Njuguna, Amos Gitau: 4.52
# - Namuye, Maria: 4.52
# - F   Buyu, Matthew: 4.52
# - Ndungu, Francis Gitonga: 4.51
# - Musebe, Edward Achieng: 4.51
# - Mbatia, Betty Nyambura: 4.51
# - Kariuki, Lucy Nyawira: 4.51
# - F   Iraki, Fredrick Kang'ethe: 4.51
# - Okech, Timothy C.: 4.50
# - Ogore, Fredrick Michae: 4.50
# - Ogola, Mary Ganga: 4.50
# - Njoroge, Joseph: 4.50
# - Mohamed, Abdullahi Mohamed: 4.50
# - Mbugua, Wanjiku: 4.50
# - Magut, Zuhra C.: 4.50
# - Kiai, Gachanja: 4.50
# - Getecha, Ciru W.: 4.50
# - Ahenda, John Ang'udi: 4.50
# - Rubio Gijon, Pablo: 4.49
# - Oteri, Malack Omae: 4.49
# - Oriedi, David Opondo: 4.49
# - Onditi, Tom: 4.49
# - Oduol, Charles: 4.49
# - Gitahi, Jesse Elikanah_Machirah: 4.49
# - Akuma, Samson Mainye: 4.49
# - Ongecha, Francisca Atieno: 4.48
# - Njihia, David Thiru: 4.48
# - Ndegwa, Joyce Watetu: 4.48
# - Mosoti, Zachary: 4.48
# - Githinji, Stanley Muturi,, Dr.: 4.48
# - F   Wambalaba, Francis: 4.48
#
# Query: Who received a C?
# Instructors with grade A:
# - Sikolia, Geoffrey Serede,, Dr.: 4.75
# - Macharia, Jimmy: 4.71
# - Kamau, Joseph: 4.71
# - Ali, Fatuma Ahmed: 4.71
# - Nguru, Faith Wariara: 4.70
# - Kimotho, Stephen Gichuhi: 4.70
# - Sifuna, Austin Makokha: 4.64
# - Gachukia, Jennifer Wangari: 4.63
# - Mwangi, Jonathan Maina: 4.60
# - Adan, Ali: 4.60
# - Wachana, Paul: 4.59
# - Mwilu, Asha Ahmed: 4.59
# - Mulindi, Patrick M.: 4.59
# - Ylonen, Aleksi Erik: 4.58
# - Wetiba, Johnson Kwanusu: 4.58
# - Nyete, Abraham Mutunga: 4.58
# - Mburu, Esther Njambi: 4.58
# - Munyi, Elijah N: 4.57
# - Oranga, James Odhiambo: 4.56
# - Nginye, Michael Gichangi: 4.56
# - Nakamura, Katsuji: 4.56
# - Achoki, George: 4.56
# - Ondiek, Collins Oduor: 4.55
# - Kimani, Nathan Muya: 4.55
# - Karume, Michelle Wariara: 4.55
# - Karimi, James Mark,, Ngari: 4.55
# - Kakumu, Muema Pius: 4.55
# - Njeru, Godwin Kinyua: 4.54
# - Njenga, Kefah Muiruri: 4.54
# - Mutisya Mutungi, Mary Mumbua: 4.54
# - Mbugua, Paul Mungai: 4.54
# - Mbotu, Michael Mulandi: 4.54
# - Koshal, Jeremiah Ntaloi_Ole: 4.54
# - Kabongah, George Odhiambo: 4.54
# - Were, Jamen H.: 4.53
# - Sule, Odhiambo F.E.: 4.53
# - Scott, Bellows J: 4.53
# - Ndirangu, Dalton: 4.53
# - Kabacho, Mwangi: 4.53
# - Gatumo, Francis Mambo: 4.53
# - Brown, Dana Basnight: 4.53
# - S   Kiruthu, Lucy Nyaguthii: 4.52
# - Ogada, Agnes Owuor: 4.52
# - Noah, Naumih M.: 4.52
# - Njuguna, Amos Gitau: 4.52
# - Namuye, Maria: 4.52
# - F   Buyu, Matthew: 4.52
# - Ndungu, Francis Gitonga: 4.51
# - Musebe, Edward Achieng: 4.51
# - Mbatia, Betty Nyambura: 4.51
# - Kariuki, Lucy Nyawira: 4.51
# - F   Iraki, Fredrick Kang'ethe: 4.51
# - Okech, Timothy C.: 4.50
# - Ogore, Fredrick Michae: 4.50
# - Ogola, Mary Ganga: 4.50
# - Njoroge, Joseph: 4.50
# - Mohamed, Abdullahi Mohamed: 4.50
# - Mbugua, Wanjiku: 4.50
# - Magut, Zuhra C.: 4.50
# - Kiai, Gachanja: 4.50
# - Getecha, Ciru W.: 4.50
# - Ahenda, John Ang'udi: 4.50
# - Rubio Gijon, Pablo: 4.49
# - Oteri, Malack Omae: 4.49
# - Oriedi, David Opondo: 4.49
# - Onditi, Tom: 4.49
# - Oduol, Charles: 4.49
# - Gitahi, Jesse Elikanah_Machirah: 4.49
# - Akuma, Samson Mainye: 4.49
# - Ongecha, Francisca Atieno: 4.48
# - Njihia, David Thiru: 4.48
# - Ndegwa, Joyce Watetu: 4.48
# - Mosoti, Zachary: 4.48
# - Githinji, Stanley Muturi,, Dr.: 4.48
# - F   Wambalaba, Francis: 4.48
#
# Query: List instructors with scores below 3.5
# Instructors with scores < 3.5:
# - Gitau, Samuel: 3.44 (D+)
#
# Query: Which instructors scored exactly 4.0?
# Instructors with scores = 4.0:
# - S   Maina, Ann Wambui: 4.00 (C+)
# - Ogunde, Jane  Awuor: 4.00 (B)
#
# Query: Top 5 performers
# Top 5 performers:
# - Nguru, Faith Wariara: 4.70 (A)
# - Adan, Ali: 4.60 (A)
# - Mwilu, Asha Ahmed: 4.59 (A)
# - Kimani, Nathan Muya: 4.55 (A)
# - Mbugua, Paul Mungai: 4.54 (A)
#
# Query: What feedback did students give Gitahi?
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Evaluation for a nonexistent instructor
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.

# %% [markdown]
# Also ive noticed its still struggling with matching Afundi. Because in the debugging stress testing, '[DEBUG] Comparing: tell me about afundi vs Afundi, Patrick Omuhinda -> similarity: 46.15384615384615' it completely mismatches him, with this '[DEBUG] Comparing: tell me about afundi vs Muindi, Peter M. -> similarity: 50.0' being the highest matching it found, but giving this response 'No evaluation data found for Tell me about Afundi. ' even with odoyo '[DEBUG] Comparing: results for odoyo vs Odoyo, Fredrick -> similarity: 50.0' with its output being this 'No evaluation data found for Results for Odoyo.'
# there must be sth up with the fuzzy matching

# %%
# Turn off debug output
DEBUG = False

# Qualitative stress test queries
test_queries = [
    "What feedback did students give Afundi?",          # direct feedback query
    "Summarize feedback for Mohamed",                   # summarization
    "Show sample feedback for Odoyo",                   # sample quotes
    "How did students feel about Gitahi?",              # synonym phrasing
    "Qualitative feedback for Gatumo",                  # alternate phrasing
    "Summarize student comments for Aloo",              # fuzzy match test
    "What did learners say about Basweti?",             # partial surname
    "Give me feedback themes for Ondiek",               # theme extraction
    "Summarize qualitative feedback for Njuguna",       # consultant-style summary
    "Feedback for a nonexistent instructor"             # edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: What feedback did students give Afundi?
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Summarize feedback for Mohamed
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Show sample feedback for Odoyo
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: How did students feel about Gitahi?
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Qualitative feedback for Gatumo
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Summarize student comments for Aloo
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: What did learners say about Basweti?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Give me feedback themes for Ondiek
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Summarize qualitative feedback for Njuguna
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Feedback for a nonexistent instructor
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.

# %% [markdown]
# ok gotta fix that fuzzy matching now. Cause its like its reading the entire string of the wuestion so the matching drops by alot.

# %%
# Revised fuzzy matching
import re

STOPWORDS = {
    "tell","me","about","results","for","evaluation","of","how","did",
    "performance","review","summarize","feedback","comments","student",
    "learners","say","give","themes","qualitative","what","did","show"
}

def extract_name_tokens(user_input):
    # Split into words, remove punctuation
    words = re.findall(r"[A-Za-z]+", user_input)
    # Keep words not in stopwords
    filtered = [w for w in words if w.lower() not in STOPWORDS]
    # Join back into a string
    return " ".join(filtered)

def find_best_faculty(user_input, threshold=70):
    # Extract likely name tokens
    q = extract_name_tokens(user_input).lower()
    if not q:
        return None

    cursor.execute("SELECT faculty_id, full_name FROM Faculty")
    rows = cursor.fetchall()
    best, best_score = None, -1

    for fid, name in rows:
        sim = max(
            fuzz.partial_ratio(q, name.lower()),
            fuzz.token_set_ratio(q, name.lower())
        )
        if sim > best_score:
            best_score = sim
            best = (fid, name)

    return best if best_score >= threshold else None

# %%
# Ok lets test things out now
# Turn off debug output
DEBUG = True

# Qualitative stress test queries
test_queries = [
    "What feedback did students give Afundi Patrick?",          # direct feedback query
    "Summarize feedback for Mohamed",                   # summarization
    "Show sample feedback for Odoyo Fred",                   # sample quotes
    "How did students feel about Gitahi?",              # synonym phrasing
    "Qualitative feedback for Gatumo",                  # alternate phrasing
    "Summarize student comments for Aloo",              # fuzzy match test
    "What did learners say about Basweti?",             # partial surname
    "Give me feedback themes for Ondiek",               # theme extraction
    "Summarize qualitative feedback for Njuguna",       # consultant-style summary
    "Feedback for a nonexistent instructor"             # edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: What feedback did students give Afundi Patrick?
# Feedback for Mulindi, Patrick M. is mostly positive.
# Breakdown: 42% positive, 55% neutral, 2% negative.
# Representative comments:
# - "good"
# - "sweet He had arranged the slides properly which made it easier to learn .."
# - "-- his explanation."
#
# Query: Summarize feedback for Mohamed
# No qualitative feedback available for Mohamed, Mwanashehe S..
#
# Query: Show sample feedback for Odoyo Fred
# No qualitative feedback available for Odoyo, Fredrick.
#
# Query: How did students feel about Gitahi?
# I couldn’t find that instructor. Try a full or closer name.
#
# Query: Qualitative feedback for Gatumo
# Feedback for Gatumo, Francis Mambo is mostly positive.
# Breakdown: 44% positive, 56% neutral, 0% negative.
# Representative comments:
# - "Good"
# - "N/A"
# - "N/A"
#
# Query: Summarize student comments for Aloo
# Feedback for Aloo, Linus Alwal is mostly positive.
# Breakdown: 37% positive, 63% neutral, 0% negative.
# Representative comments:
# - "good"
# - "communicator always engaged students Practical examples, in class practicals and proper explanation of the coursework to help us understand the theory."
# - "NONE"
#
# Query: What did learners say about Basweti?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Give me feedback themes for Ondiek
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Summarize qualitative feedback for Njuguna
# No qualitative feedback available for Njuguna, Amos Gitau.
#
# Query: Feedback for a nonexistent instructor
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.

# %% [markdown]
# ok so slight change in the response. Ok ive realised if you add in the second name and re-ask the question it accuretly matches the lecturer, even if the second name is a partial like with Odoyo, hes full name is Odoyo Fredrick, but if you place in odoyo fred, it matches him accuretly. So if that's the case we let the fuzzy matching rest, as long as you do actually provide full name or closer name it can find the lecturer that's fine with me. Lets move to the next level of complexity for the qualitative section

# %%
# Right now the system is just saying “No qualitative feedback available” because it’s pulling raw comments but not analyzing or summarizing them.
# so lets do so sentinment theme extraction
from nltk.sentiment import SentimentIntensityAnalyzer
import re
from collections import Counter

sia = SentimentIntensityAnalyzer()

def analyze_feedback(comments, top_k=5):
    # Sentiment scores
    scores = [sia.polarity_scores(c)["compound"] for c in comments if c.strip()]
    pos = sum(1 for s in scores if s > 0.05)
    neg = sum(1 for s in scores if s < -0.05)
    neu = len(scores) - pos - neg
    total = len(scores)
    avg = sum(scores) / total if total else 0

    sentiment_label = "positive" if avg > 0.1 else "mixed" if abs(avg) <= 0.1 else "negative"

    # Keyword extraction (naive)
    stop = {"the","and","to","of","in","for","on","is","was","are","with","that","this","it","as","at","by","from","or","an","be","but","not"}
    tokens = []
    for c in comments:
        words = re.findall(r"[a-zA-Z][a-zA-Z'-]+", c.lower())
        tokens.extend(w for w in words if len(w) > 3 and w not in stop)
    common = Counter(tokens).most_common(top_k)
    themes = [w for w, _ in common]

    return {
        "sentiment": sentiment_label,
        "pos_pct": pos/total if total else 0,
        "neu_pct": neu/total if total else 0,
        "neg_pct": neg/total if total else 0,
        "themes": themes
    }

# %%
# then lets add in the responses to give out
def feedback_response(user_input, sample_n=3):
    match = find_best_faculty(user_input)
    if not match:
        return "I couldn’t find that instructor. Try a full or closer name."
    fid, full_name = match

    cursor.execute("SELECT comment_text FROM FeedbackCorpus WHERE faculty_id = ?", (fid,))
    comments = [r[0] for r in cursor.fetchall()]
    if not comments:
     return f"Students provided numeric evaluations for {full_name}, but no written comments were submitted."

    analysis = analyze_feedback(comments)
    response = [
        f"Feedback for {full_name} is mostly {analysis['sentiment']}.",
        f"Breakdown: {analysis['pos_pct']:.0%} positive, {analysis['neu_pct']:.0%} neutral, {analysis['neg_pct']:.0%} negative.",
        f"Common themes: {', '.join(analysis['themes']) or 'none detected'}."
    ]

    # Add sample comments
    sample_comments = comments[:sample_n]
    if sample_comments:
        response.append("Representative comments:")
        for c in sample_comments:
            response.append(f"- \"{c}\"")

    return "\n".join(response)

# %%
# now to do some stress testing
# Ok lets test things out now
# Turn off debug output
DEBUG = False

# Qualitative stress test queries
test_queries = [
    "What feedback did students give Afundi Patrick?",             # direct feedback query
    "Summarize feedback for Mohamed",                              # summarization
    "Show sample feedback for Odoyo Fred",                         # sample quotes
    "How did students feel about Gitahi Jesse Elikanah_Machirah?", # synonym phrasing
    "Qualitative feedback for Gatumo",                             # alternate phrasing
    "Summarize student comments for Aloo",                         # fuzzy match test
    "What did learners say about Basweti?",                        # partial surname
    "Give me feedback themes for Ondiek",                          # theme extraction
    "Summarize qualitative feedback for Njuguna",                  # consultant-style summary
    "Feedback for a nonexistent instructor"                        # edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: What feedback did students give Afundi Patrick?
# Feedback for Mulindi, Patrick M. is mostly positive.
# Breakdown: 42% positive, 55% neutral, 2% negative.
# Common themes: good, none, excellent, great, which.
# Representative comments:
# - "good"
# - "sweet He had arranged the slides properly which made it easier to learn .."
# - "-- his explanation."
#
# Query: Summarize feedback for Mohamed
# Students provided numeric evaluations for Mohamed, Mwanashehe S., but no written comments were submitted.
#
# Query: Show sample feedback for Odoyo Fred
# Students provided numeric evaluations for Odoyo, Fredrick, but no written comments were submitted.
#
# Query: How did students feel about Gitahi Jesse Elikanah_Machirah?
# Students provided numeric evaluations for Gitahi, Jesse Elikanah_Machirah, but no written comments were submitted.
#
# Query: Qualitative feedback for Gatumo
# Feedback for Gatumo, Francis Mambo is mostly positive.
# Breakdown: 44% positive, 56% neutral, 0% negative.
# Common themes: good, none, excellent, okay, explanations.
# Representative comments:
# - "Good"
# - "N/A"
# - "N/A"
#
# Query: Summarize student comments for Aloo
# Feedback for Aloo, Linus Alwal is mostly positive.
# Breakdown: 37% positive, 63% neutral, 0% negative.
# Common themes: good, none, excellent, practicals, everything.
# Representative comments:
# - "good"
# - "communicator always engaged students Practical examples, in class practicals and proper explanation of the coursework to help us understand the theory."
# - "NONE"
#
# Query: What did learners say about Basweti?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Give me feedback themes for Ondiek
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Summarize qualitative feedback for Njuguna
# Students provided numeric evaluations for Njuguna, Amos Gitau, but no written comments were submitted.
#
# Query: Feedback for a nonexistent instructor
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.

# %% [markdown]
# ok so had to go back and revise the DB, For the 5th time, so the mark downs no longer make sense. So just ignore those that dont make any sense at all.

# %% [markdown]
# ## Patched intent logic

# %%
def parse_intent(user_input: str):
    text = user_input.lower()

    # Qualitative feedback intent
    qualitative_keywords = [
        "feedback", "comments", "say", "feel", "themes",
        "qualitative", "students", "learners", "opinions"
    ]
    if any(k in text for k in qualitative_keywords):
        return {"intent": "qualitative", "name": extract_name_tokens(user_input)}

    # Lookup intent
    if "tell me about" in text or "evaluation" in text or "results" in text or "performance" in text:
        return {"intent": "lookup", "name": extract_name_tokens(user_input)}

    # Ranking intent
    if "top" in text or "best" in text or "performers" in text:
        count = 5
        for word in text.split():
            if word.isdigit():
                count = int(word)
        return {"intent": "top_ranked", "count": count}

    # Score filters
    if "above" in text or "below" in text or "exactly" in text:
        return {"intent": "score_filter", "condition": text}

    # Grade filters
    if "grade" in text or "received" in text or "got" in text:
        return {"intent": "grade_filter", "condition": text}

    return {"intent": "unknown"}

# %%
# then gotta improve the theme extraction a bit by accounting for na, trivial words like good, excellent etc. They dont provide much value
import re
from collections import Counter

def extract_themes(comments, top_k=5):
    stop = {
        "the","and","to","of","in","for","on","is","was","are","with","that","this","it","as","at","by","from","or","an","be","but","not",
        "none","n/a","na","ok","good","excellent","great"
    }
    tokens = []
    for c in comments:
        words = re.findall(r"[a-zA-Z][a-zA-Z'-]+", c.lower())
        tokens.extend(w for w in words if len(w) > 3 and w not in stop)
    common = Counter(tokens).most_common(top_k)
    return [w for w, _ in common]

# %%
# then lets intergrate the changes back into the feedback response
def get_feedback_summary(fid, full_name, limit=3):
    query = """
    SELECT comment_text
    FROM FeedbackCorpus
    WHERE faculty_id = ?
    LIMIT ?
    """
    cursor.execute(query, (fid, limit))
    rows = cursor.fetchall()
    comments = [r[0] for r in rows if r[0]]

    if not comments:
        return f"Students provided numeric evaluations for {full_name}, but no written comments were submitted."

    analysis = analyze_feedback(comments)  # your sentiment logic
    themes = extract_themes(comments)

    response = [
        f"Feedback is mostly {analysis['sentiment']}.",
        f"Breakdown: {analysis['pos_pct']:.0%} positive, {analysis['neu_pct']:.0%} neutral, {analysis['neg_pct']:.0%} negative.",
        f"Common themes: {', '.join(themes) or 'none detected'}."
    ]

    # Filter sample comments: select comments with at least min_words words
    def filter_sample_comments(comments, min_words=3, limit=3):
        filtered = [c for c in comments if len(c.split()) >= min_words]
        return filtered[:limit]

    sample_comments = filter_sample_comments(comments, min_words=3, limit=3)
    if sample_comments:
        response.append("Representative comments:")
        for c in sample_comments:
            response.append(f"- \"{c}\"")

    return "\n".join(response)

# %%
# now to do some stress testing
# Ok lets test things out now
# Turn off debug output
DEBUG = False

# Qualitative stress test queries
test_queries = [
    "What feedback did students give Afundi Patrick?",             # direct feedback query
    "Summarize feedback for Mohamed",                              # summarization
    "Show sample feedback for Odoyo Fred",                         # sample quotes
    "How did students feel about Gitahi Jesse Elikanah_Machirah?", # synonym phrasing
    "Qualitative feedback for Gatumo",                             # alternate phrasing
    "Summarize student comments for Aloo",                         # fuzzy match test
    "What did learners say about Basweti?",                        # partial surname
    "Give me feedback themes for Ondiek",                          # theme extraction
    "Summarize qualitative feedback for Njuguna",                  # consultant-style summary
    "Feedback for a nonexistent instructor"                        # edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: What feedback did students give Afundi Patrick?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Summarize feedback for Mohamed
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Show sample feedback for Odoyo Fred
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: How did students feel about Gitahi Jesse Elikanah_Machirah?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Qualitative feedback for Gatumo
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Summarize student comments for Aloo
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: What did learners say about Basweti?
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Give me feedback themes for Ondiek
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Summarize qualitative feedback for Njuguna
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.
#
# Query: Feedback for a nonexistent instructor
# I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback.

# %% [markdown]
# ok this si bad.
# the patch regressed because the parser now returns “qualitative”, but your router doesn’t handle that intent. Plus, name extraction is brittle, and grade parsing is misclassifying “C” queries. Let’s fix all three: routing, name resolution, and grade parsing.

# %%
import re
from rapidfuzz import fuzz, process

def extract_name_tokens(text: str):
    # Strip leading verbs/phrases commonly used in queries
    cleaned = re.sub(r"(?i)\b(tell me about|what did|what’s|whats|how did|results for|show|give me|summarize|qualitative feedback for|feedback for|student comments for|themes for|evaluation of|evaluation for)\b", "", text)
    # Remove filler words
    cleaned = re.sub(r"(?i)\b(students|learners|feedback|comments|themes|evaluation|results|sample|qualitative)\b", "", cleaned)
    # Keep letters, commas, spaces, periods, underscores
    cleaned = re.sub(r"[^a-zA-Z ,._-]", " ", cleaned)
    cleaned = re.sub(r"\s+", " ", cleaned).strip()
    return cleaned

def resolve_instructor_name(name_query: str, cursor, top_n=1, threshold=70):
    # Get all faculty names
    cursor.execute("SELECT faculty_id, full_name FROM Faculty")
    rows = cursor.fetchall()
    # Use RapidFuzz for better matching
    choices = {full_name: fid for (fid, full_name) in rows}
    matches = process.extract(name_query, choices.keys(), scorer=fuzz.token_set_ratio, limit=top_n)
    if matches and matches[0][1] >= threshold:
        best_name, score, _ = matches[0]
        return choices[best_name], best_name, score
    return None, None, 0

# %%
def get_consultant_response(user_input: str):
    intent = parse_intent(user_input)

    if intent["intent"] == "qualitative":
        name_query = extract_name_tokens(user_input)
        result = resolve_instructor_name(name_query, cursor)

        if result == (None, None, 0):
            return "I couldn’t find that instructor in the records."

        if isinstance(result[0], str) and result[0] == "AMBIGUOUS":
            candidates = result[1]
            return (
                "There are multiple instructors with that name. "
                "Please specify the full name, e.g.: " + ", ".join(candidates)
            )

        fid, full_name, score = result
        feedback = get_feedback_summary(fid, full_name, limit=3)

        cursor.execute(
            "SELECT mean_score, letter_grade FROM Evaluations "
            "WHERE faculty_id = ? ORDER BY mean_score DESC LIMIT 1",
            (fid,)
        )
        row = cursor.fetchone()
        if row:
            ms, lg = row
            head = f"Based on evaluations, {full_name} has a mean score of {ms:.2f} ({lg})."
            return head + "\n" + feedback
        return feedback


    if intent["intent"] == "lookup":
        name_query = extract_name_tokens(user_input)
        fid, full_name, score = resolve_instructor_name(name_query, cursor)
        if not fid or score < 70:
            return "I couldn’t find that instructor in the records."
        return lookup_instructor_evaluation(full_name)  # or use fid in your implementation

    if intent["intent"] == "top_ranked":
        return get_top_performers(intent["count"])

    if intent["intent"] == "score_filter":
        return filter_by_score_condition(intent["condition"])

    if intent["intent"] == "grade_filter":
        return filter_by_grade_condition(intent["condition"])

    return "I couldn’t interpret that question. Try asking about an instructor, scores, grades, top performers, or feedback."

# %% [markdown]
# this function has been revised like 3 times now.
# What Changed
# - Two‑stage resolver: looks in FeedbackCorpus.instructor first, then Faculty.full_name.
# - Confidence cutoff: if fuzzy match score < 70, returns “I couldn’t find that instructor.”
# - Fixed call: get_feedback_summary(fid, full_name, limit=3) so no missing argument error.
# - Consistent fallback: both qualitative and lookup intents use the same cutoff logic.
#
# This version should restore matches for lecturers like Afundi, Gatumo, Aloo, Basweti, while still protecting against false positives.

# %%
def parse_intent(user_input: str):
    text = user_input.lower()

    qualitative_keywords = [
        "feedback", "comments", "say", "feel", "themes",
        "qualitative", "students", "learners", "opinions", "sample feedback"
    ]
    if any(k in text for k in qualitative_keywords):
        return {"intent": "qualitative", "name": extract_name_tokens(user_input)}

    # Grade filters: capture exact letter if provided
    m = re.search(r"(?i)\b(grade|got|received)\s+([abcdf][+-]?)\b", text)
    if m:
        letter = m.group(2).upper()
        return {"intent": "grade_filter", "condition": {"type": "letter", "value": letter}}

    if re.search(r"(?i)\bwho.*grade\s+([abcdf][+-]?)\b", text):
        letter = re.search(r"(?i)\b([abcdf][+-]?)\b", text).group(1).upper()
        return {"intent": "grade_filter", "condition": {"type": "letter", "value": letter}}

    # Numeric score filters
    if "above" in text or "below" in text or "exactly" in text:
        # Extract numeric target if present
        mnum = re.search(r"(?i)\b(above|below|exactly)\s+(\d+(?:\.\d+)?)", text)
        cond = {"type": "score", "op": mnum.group(1).lower(), "value": float(mnum.group(2))} if mnum else {"raw": text}
        return {"intent": "score_filter", "condition": cond}

    # Ranking
    if "top" in text or "best" in text or "performers" in text:
        count = 5
        mcount = re.search(r"\b(\d+)\b", text)
        if mcount:
            count = int(mcount.group(1))
        return {"intent": "top_ranked", "count": count}

    # Lookup
    if "tell me about" in text or "evaluation" in text or "results" in text or "performance" in text:
        return {"intent": "lookup", "name": extract_name_tokens(user_input)}

    return {"intent": "unknown"}

# %%
# lets fix the grade and score filtering functions
def filter_by_grade_condition(condition):
    if isinstance(condition, dict) and condition.get("type") == "letter":
        letter = condition["value"]
        q = "SELECT full_name, mean_score, letter_grade FROM Evaluations WHERE letter_grade = ? ORDER BY mean_score DESC"
        cursor.execute(q, (letter,))
        rows = cursor.fetchall()
        if not rows:
            return f"No instructors found with grade {letter}."
        lines = [f"Instructors with grade {letter}:"]
        for name, score, lg in rows:
            lines.append(f"- {name}: {score:.2f}")
        return "\n".join(lines)
    return "I couldn’t interpret that grade request."

# %%
def filter_by_score_condition(condition):
    if isinstance(condition, dict) and condition.get("type") == "score":
        op = condition["op"]; val = condition["value"]
        if op == "above":
            q = "SELECT full_name, mean_score, letter_grade FROM Evaluations WHERE mean_score > ? ORDER BY mean_score DESC"
        elif op == "below":
            q = "SELECT full_name, mean_score, letter_grade FROM Evaluations WHERE mean_score < ? ORDER BY mean_score ASC"
        elif op == "exactly":
            q = "SELECT full_name, mean_score, letter_grade FROM Evaluations WHERE ABS(mean_score - ?) < 1e-9 ORDER BY full_name"
        else:
            return "I couldn’t interpret that score condition."
        cursor.execute(q, (val,))
        rows = cursor.fetchall()
        if not rows:
            return f"No instructors found with scores {op} {val:.2f}."
        hdr = f"Instructors with scores {op} {val:.2f}:" if op != "exactly" else f"Instructors with scores = {val:.2f}:"
        lines = [hdr]
        for name, score, lg in rows:
            grade = lg if lg else ""
            lines.append(f"- {name}: {score:.2f} ({grade})" if grade else f"- {name}: {score:.2f}")
        return "\n".join(lines)
    return "I couldn’t interpret that score request."

# %%
# lets imporve the theme extraction a bit more
import re
from collections import Counter

def extract_themes(comments, top_k=5):
    stop = {
        "the","and","to","of","in","for","on","is","was","are","with","that","this","it","as","at","by","from","or","an","be","but","not",
        "none","n/a","na","ok","good","excellent","great","fine","nice","fair"
    }
    tokens = []
    for c in comments:
        # normalize punctuation like double hyphens, underscores
        c = c.replace("_", " ")
        words = re.findall(r"[a-zA-Z][a-zA-Z'-]+", c.lower())
        tokens.extend(w for w in words if len(w) > 3 and w not in stop)
    common = Counter(tokens).most_common(top_k)
    return [w for w, _ in common]

# %%
def extract_name_tokens(text: str):
    cleaned = re.sub(r"(?i)\b(tell me about|what did|what’s|whats|how did|results for|show|give me|summarize|qualitative feedback for|feedback for|student comments for|themes for|evaluation of|evaluation for|say about|learners|students)\b", "", text)
    cleaned = re.sub(r"[^a-zA-Z ,._-]", " ", cleaned)
    return cleaned.strip()

# %%
# now to do some stress testing
# Ok lets test things out now
# Turn off debug output
DEBUG = False

# Qualitative stress test queries
test_queries = [
    "What feedback did students give Afundi Patrick?",             # direct feedback query
    "Summarize feedback for Mohamed",                              # summarization
    "Show sample feedback for Odoyo Fred",                         # sample quotes
    "How did students feel about Gitahi Jesse Elikanah_Machirah?", # synonym phrasing
    "Qualitative feedback for Gatumo",                             # alternate phrasing
    "Summarize student comments for Aloo",                         # fuzzy match test
    "What did learners say about Basweti?",                        # partial surname
    "Give me feedback themes for Ondiek",                          # theme extraction
    "Summarize qualitative feedback for Njuguna",                  # consultant-style summary
    "Feedback for a nonexistent instructor"                        # edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: What feedback did students give Afundi Patrick?
# I couldn’t find that instructor in the records.
#
# Query: Summarize feedback for Mohamed
# Based on evaluations, Mohamed, Abdullahi Mohamed has a mean score of 4.50 (A).
# Students provided numeric evaluations for Mohamed, Abdullahi Mohamed, but no written comments were submitted.
#
# Query: Show sample feedback for Odoyo Fred
# I couldn’t find that instructor in the records.
#
# Query: How did students feel about Gitahi Jesse Elikanah_Machirah?
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah has a mean score of 4.49 (A).
# Students provided numeric evaluations for Gitahi, Jesse Elikanah_Machirah, but no written comments were submitted.
#
# Query: Qualitative feedback for Gatumo
# I couldn’t find that instructor in the records.
#
# Query: Summarize student comments for Aloo
# I couldn’t find that instructor in the records.
#
# Query: What did learners say about Basweti?
# I couldn’t find that instructor in the records.
#
# Query: Give me feedback themes for Ondiek
# I couldn’t find that instructor in the records.
#
# Query: Summarize qualitative feedback for Njuguna
# I couldn’t find that instructor in the records.
#
# Query: Feedback for a nonexistent instructor
# I couldn’t find that instructor in the records.

# %%
# gotta run a quick pragma check on the db
cursor.execute("PRAGMA table_info(Evaluations)")
print(cursor.fetchall())
# Out:
# [(0, 'faculty_id', 'INTEGER', 0, None, 0), (1, 'full_name', 'TEXT', 0, None, 0), (2, 'course_code', 'TEXT', 0, None, 0), (3, 'section_code', 'TEXT', 0, None, 0), (4, 'total_students', 'INTEGER', 0, None, 0), (5, 'total_respondents', 'INTEGER', 0, None, 0), (6, 'response_rate', 'REAL', 0, None, 0), (7, 'mean_score', 'REAL', 0, None, 0), (8, 'percent_score', 'REAL', 0, None, 0), (9, 'letter_grade', 'TEXT', 0, None, 0), (10, 'section_id', 'TEXT', 0, None, 0)]

# %%
# gotta tun a pragma check on the db
cursor.execute("PRAGMA table_info(FeedbackCorpus)")
print(cursor.fetchall())
# Out:
# [(0, 'feedback_id', 'INTEGER', 0, None, 1), (1, 'faculty_id', 'INTEGER', 0, None, 0), (2, 'instructor', 'TEXT', 0, None, 0), (3, 'course_code', 'TEXT', 0, None, 0), (4, 'section_code', 'TEXT', 0, None, 0), (5, 'semester', 'TEXT', 0, None, 0), (6, 'comment_type', 'TEXT', 0, None, 0), (7, 'comment_text', 'TEXT', 0, None, 0)]

# %%
print(parse_intent("What did learners say about Basweti?"))
# Out:
# {'intent': 'qualitative', 'name': 'Basweti'}

# %%
# now to do some stress testing
# Ok lets test things out now
# Turn off debug output
DEBUG = False

# Qualitative stress test queries
test_queries = [
    "What feedback did students give Afundi Patrick?",             # direct feedback query
    "Summarize feedback for Mohamed",                              # summarization
    "Show sample feedback for Odoyo Fred",                         # sample quotes
    "How did students feel about Gitahi Jesse Elikanah_Machirah?", # synonym phrasing
    "Qualitative feedback for Gatumo",                             # alternate phrasing
    "Summarize student comments for Aloo",                         # fuzzy match test
    "What did learners say about Basweti?",                        # partial surname
    "Give me feedback themes for Ondiek",                          # theme extraction
    "Summarize qualitative feedback for Njuguna",                  # consultant-style summary
    "Feedback for a nonexistent instructor"                        # edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: What feedback did students give Afundi Patrick?
# I couldn’t find that instructor in the records.
#
# Query: Summarize feedback for Mohamed
# Based on evaluations, Mohamed, Abdullahi Mohamed has a mean score of 4.50 (A).
# Students provided numeric evaluations for Mohamed, Abdullahi Mohamed, but no written comments were submitted.
#
# Query: Show sample feedback for Odoyo Fred
# I couldn’t find that instructor in the records.
#
# Query: How did students feel about Gitahi Jesse Elikanah_Machirah?
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah has a mean score of 4.49 (A).
# Students provided numeric evaluations for Gitahi, Jesse Elikanah_Machirah, but no written comments were submitted.
#
# Query: Qualitative feedback for Gatumo
# I couldn’t find that instructor in the records.
#
# Query: Summarize student comments for Aloo
# I couldn’t find that instructor in the records.
#
# Query: What did learners say about Basweti?
# I couldn’t find that instructor in the records.
#
# Query: Give me feedback themes for Ondiek
# I couldn’t find that instructor in the records.
#
# Query: Summarize qualitative feedback for Njuguna
# I couldn’t find that instructor in the records.
#
# Query: Feedback for a nonexistent instructor
# I couldn’t find that instructor in the records.

# %% [markdown]
# ok let me try lowering the matching thresholds so that we can get some matches

# %%
def resolve_instructor_name(name_query: str, cursor, threshold=70):
    cursor.execute("SELECT faculty_id, full_name FROM Faculty")
    rows = cursor.fetchall()
    choices = {full_name: fid for (fid, full_name) in rows}
    matches = process.extract(name_query, choices.keys(), scorer=fuzz.token_set_ratio, limit=1)
    if matches:
        best_name, score, _ = matches[0]
        fid = choices[best_name]
        if score >= threshold:
            return fid, best_name, score
        else:
            # fallback: return anyway, but note low confidence
            return fid, best_name, score
    return None, None, 0

# %%
def normalize_name(name: str):
    return re.sub(r"[^a-zA-Z ]", "", name).lower().strip()

# %%
def resolve_instructor_name(name_query: str, cursor, threshold=70):
    # Try FeedbackCorpus first
    cursor.execute("SELECT DISTINCT faculty_id, instructor FROM FeedbackCorpus WHERE instructor IS NOT NULL")
    rows = cursor.fetchall()
    for fid, instr in rows:
        if fuzz.token_set_ratio(name_query.lower(), instr.lower()) >= threshold:
            return fid, instr, 100
    # Fallback to Faculty
    cursor.execute("SELECT faculty_id, full_name FROM Faculty")
    rows = cursor.fetchall()
    choices = {full_name: fid for (fid, full_name) in rows}
    matches = process.extract(name_query, choices.keys(), scorer=fuzz.token_set_ratio, limit=1)
    if matches:
        best_name, score, _ = matches[0]
        return choices[best_name], best_name, score
    return None, None, 0

# %%
# now to do some stress testing
# Ok lets test things out now
# Turn off debug output
DEBUG = False

# Qualitative stress test queries
test_queries = [
    "What feedback did students give Afundi Patrick?",             # direct feedback query
    "Summarize feedback for Mohamed",                              # summarization
    "Show sample feedback for Odoyo Fred",                         # sample quotes
    "How did students feel about Gitahi Jesse Elikanah_Machirah?", # synonym phrasing
    "Qualitative feedback for Gatumo",                             # alternate phrasing
    "Summarize student comments for Aloo",                         # fuzzy match test
    "What did learners say about Basweti?",                        # partial surname
    "Give me feedback themes for Ondiek",                          # theme extraction
    "Summarize qualitative feedback for Njuguna",                  # consultant-style summary
    "Feedback for a nonexistent instructor"                        # edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: What feedback did students give Afundi Patrick?
# Based on evaluations, Afundi, Patrick Omuhinda has a mean score of 4.35 (A-).
# Feedback is mostly mixed.
# Breakdown: 33% positive, 67% neutral, 0% negative.
# Common themes: none detected.
#
# Query: Summarize feedback for Mohamed
# Based on evaluations, Mohamed, Abdullahi Mohamed has a mean score of 4.50 (A).
# Students provided numeric evaluations for Mohamed, Abdullahi Mohamed, but no written comments were submitted.
#
# Query: Show sample feedback for Odoyo Fred
# Based on evaluations, Odoyo, Fredrick has a mean score of 4.10 (B).
# Students provided numeric evaluations for Odoyo, Fredrick, but no written comments were submitted.
#
# Query: How did students feel about Gitahi Jesse Elikanah_Machirah?
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah has a mean score of 4.49 (A).
# Students provided numeric evaluations for Gitahi, Jesse Elikanah_Machirah, but no written comments were submitted.
#
# Query: Qualitative feedback for Gatumo
# Based on evaluations, Gatumo, Francis Mambo has a mean score of 4.53 (A).
# Feedback is mostly positive.
# Breakdown: 33% positive, 67% neutral, 0% negative.
# Common themes: none detected.
#
# Query: Summarize student comments for Aloo
# Based on evaluations, Aloo, Linus Alwal has a mean score of 4.45 (A-).
# Feedback is mostly positive.
# Breakdown: 67% positive, 33% neutral, 0% negative.
# Common themes: communicator, always, engaged, students, practical.
# Representative comments:
# - "communicator always engaged students Practical examples, in class practicals and proper explanation of the coursework to help us understand the theory."
#
# Query: What did learners say about Basweti?
# Based on evaluations, Basweti, Kevin Ogachi has a mean score of 4.03 (B).
# Feedback is mostly positive.
# Breakdown: 33% positive, 67% neutral, 0% negative.
# Common themes: none detected.
#
# Query: Give me feedback themes for Ondiek
# Based on evaluations, Ogendi, Paul has a mean score of 4.34 (A-).
# Students provided numeric evaluations for Ogendi, Paul, but no written comments were submitted.
#
# Query: Summarize qualitative feedback for Njuguna
# Based on evaluations, Njuguna, Amos Gitau has a mean score of 4.52 (A).
# Students provided numeric evaluations for Njuguna, Amos Gitau, but no written comments were submitted.
#
# Query: Feedback for a nonexistent instructor
# Based on evaluations, Ondiek, Collins Oduor has a mean score of 4.55 (A).
# Feedback is mostly mixed.
# Breakdown: 0% positive, 100% neutral, 0% negative.
# Common themes: everything, simple, approaches, topics, localized.
# Representative comments:
# - "Everything Everything A Simple approaches to topics. Localized examples."

# %% [markdown]
# ok some red flags with the no qualitative comments.
# mohammed,odoyo, gitahi, Njuguna are fine they don't have any comments fro the parsing or in the complete pdf. So those results are perfectly fine and are expected.
# but with ondiek collins its not, he does have comments that appeared in the parsing and in the pdf, so that's a false negative. That's something of concern. But ill deal with it later but ive left a flag for it.
# Anyways ive read over the answers and they are fantastic but the na, nils and one word response aren't exactly useful. So we need to filter those out.
# As well as improving the fallback for no qualitative feedback and the nonexistent instructor. Sample comments also need a new threshold of lets say currently 3 words

# %% [markdown]
# new update had to make some changes to functions up above so that marked down isnt fully right.  im thinking we just redo the function for no qualitative and the instructor match, based off of what we learnt from previous output because rn Afundi our lecturer 0 is no longer being found again.

# %%
# revised theme extraction
import re
from collections import Counter

def extract_themes(comments, top_k=5):
    stop = {
        "the","and","to","of","in","for","on","is","was","are","with","that","this","it","as","at","by","from","or","an","be","but","not",
        "none","n/a","na","nil","ok","good","excellent","great","fine","nice","fair",".","-","--"
    } # why are students so stubborn about punctuation
    tokens = []
    for c in comments:
        # normalize punctuation like underscores, double hyphens
        c = c.replace("_", " ").replace("--", " ")
        words = re.findall(r"[a-zA-Z][a-zA-Z'-]+", c.lower())
        # only keep words longer than 3 chars and not in stoplist
        tokens.extend(w for w in words if len(w) > 3 and w not in stop)
    common = Counter(tokens).most_common(top_k)
    return [w for w, _ in common]

# %%
# comments threshold i want the displayed comment to have atleast 3 words for now
def filter_sample_comments(comments, min_words=3, limit=3):
    filtered = []
    for c in comments:
        if not c: 
            continue
        # count words
        word_count = len(c.split())
        if word_count >= min_words and c.lower() not in {"n/a","na","nil","none","ok","good","."}:
            filtered.append(c)
    return filtered[:limit]

# %%
from rapidfuzz import fuzz, process
import re

def normalize_name(name: str):
    return re.sub(r"[^a-zA-Z ]", "", name).lower().strip()

def resolve_instructor_name(name_query: str, cursor, threshold=70):
    nq = normalize_name(name_query)

    # Collect candidates from Faculty
    cursor.execute("SELECT faculty_id, full_name FROM Faculty")
    faculty_rows = cursor.fetchall()
    matches = []
    for fid, full_name in faculty_rows:
        score = fuzz.token_set_ratio(nq, normalize_name(full_name))
        if score >= threshold:
            matches.append((fid, full_name, score))

    if not matches:
        return None, None, 0

    if len(matches) == 1:
        return matches[0]  # fid, full_name, score

    # Multiple matches → ambiguous
    return "AMBIGUOUS", [m[1] for m in matches], max(m[2] for m in matches)

# %%
# now to do some stress testing
# Ok lets test things out now
# Turn off debug output
DEBUG = False

# Qualitative stress test queries
test_queries = [
    "What feedback did students give Afundi Patrick?",             # direct feedback query
    "Summarize feedback for Mohamed",                              # summarization
    "Show sample feedback for Odoyo Fred",                         # sample quotes
    "How did students feel about Gitahi Jesse Elikanah_Machirah?", # synonym phrasing
    "Qualitative feedback for Gatumo",                             # alternate phrasing
    "Summarize student comments for Aloo",                         # fuzzy match test
    "What did learners say about Basweti?",                        # partial surname
    "Give me feedback themes for Ondiek Collins",                  # theme extraction
    "Summarize qualitative feedback for Njuguna",                  # consultant-style summary
    "Feedback for a nonexistent instructor"                        # edge case handling
]

for q in test_queries:
    print("\nQuery:", q)
    print(get_consultant_response(q))
# Out:
# Query: What feedback did students give Afundi Patrick?
# Based on evaluations, Afundi, Patrick Omuhinda has a mean score of 4.35 (A-).
# Feedback is mostly mixed.
# Breakdown: 33% positive, 67% neutral, 0% negative.
# Common themes: none detected.
#
# Query: Summarize feedback for Mohamed
# There are multiple instructors with that name. Please specify the full name, e.g.: Mohamed, Mwanashehe S., Mohamed, Abdullahi Mohamed, Mohamed, Hussein Abdi
#
# Query: Show sample feedback for Odoyo Fred
# I couldn’t find that instructor in the records.
#
# Query: How did students feel about Gitahi Jesse Elikanah_Machirah?
# Based on evaluations, Gitahi, Jesse Elikanah_Machirah has a mean score of 4.49 (A).
# Students provided numeric evaluations for Gitahi, Jesse Elikanah_Machirah, but no written comments were submitted.
#
# Query: Qualitative feedback for Gatumo
# Based on evaluations, Gatumo, Francis Mambo has a mean score of 4.53 (A).
# Feedback is mostly positive.
# Breakdown: 33% positive, 67% neutral, 0% negative.
# Common themes: none detected.
#
# Query: Summarize student comments for Aloo
# Based on evaluations, Aloo, Linus Alwal has a mean score of 4.45 (A-).
# Feedback is mostly positive.
# Breakdown: 67% positive, 33% neutral, 0% negative.
# Common themes: communicator, always, engaged, students, practical.
# Representative comments:
# - "communicator always engaged students Practical examples, in class practicals and proper explanation of the coursework to help us understand the theory."
#
# Query: What did learners say about Basweti?
# Based on evaluations, Basweti, Kevin Ogachi has a mean score of 4.03 (B).
# Feedback is mostly positive.
# Breakdown: 33% positive, 67% neutral, 0% negative.
# Common themes: none detected.
#
# Query: Give me feedback themes for Ondiek Collins
# Based on evaluations, Ondiek, Collins Oduor has a mean score of 4.55 (A).
# Feedback is mostly mixed.
# Breakdown: 0% positive, 100% neutral, 0% negative.
# Common themes: everything, simple, approaches, topics, localized.
# Representative comments:
# - "Everything Everything A Simple approaches to topics. Localized examples."
#
# Query: Summarize qualitative feedback for Njuguna
# There are multiple instructors with that name. Please specify the full name, e.g.: Njuguna, Amos Gitau, Njuguna, Joseph Kimani, Njuguna, Lydia Nyambura
#
# Query: Feedback for a nonexistent instructor
# I couldn’t find that instructor in the records.

# %% [markdown]
# alright seems like things are good here i can start adding another level of complexity. ive decided i just need to  change the fallback message when only name is given for a lec. Cause with the ondiek case we have two ondieks one with a second name of collins and another one with a second name of benard and the response changes when you add in the second name. So the code was fine the AI did its best and choose not to answer. Because we never specified which one. So there should be a fallback for such cases. a message should be placed to ask for a second name because there are more than one in the system. Or i could be lazy with it now and just recommend to place in two names for now then comeback and ran an update on the response later.

# %% [markdown]
# decided not to be lazy let me update the resolver code.

# %% [markdown]
# ok so now you can see that it asks you to specify so thats good. But ill stay say to use both names

# %% [markdown]
# Anyways we are done with the micro level AI consulant and have a greate base foundation lets move onto the meso level

# %% [markdown]
# # Meso level

# %% [markdown]
# At this level, we’re aggregating across multiple lecturers/courses within a department or school, so the outputs shift from individual consultant summaries to patterns, outliers, and trends.

# %% [markdown]
# - Department Sentiment Overview
# - Aggregate closed‑ended ratings (mean scores, grade distributions).
# - Aggregate open‑ended sentiment (positive/neutral/negative percentages).
# - Top Strengths (Consensus Themes)
# - Themes mentioned positively in ≥ X% of courses.
# - Example student voice.
# - Common Areas for Improvement
# - Themes mentioned constructively in ≥ Y% of courses.
# - Example student voice.
# - Notable Outliers
# - High performers (lecturers/courses with standout positive scores).
# - Needs attention (lowest scores or recurring negative themes).
# - Emerging Trends vs. Last Semester
# - Positive themes increasing.
# - Negative themes rising.
# - Recommended Department‑Level Actions
# - Practical, role‑specific recommendations (e.g., pacing workshops, feedback turnaround policy).

# %%
# ayt lets beign with a baseline report that agregrates numeric data and qualitative sentiment
def generate_meso_sentiment_report(department_id, cursor):
    """
    Baseline meso-level report: aggregate numeric and qualitative sentiment
    for a given department.
    """

    # 1. Aggregate numeric evaluations
    cursor.execute("""
        SELECT AVG(mean_score), COUNT(*)
        FROM Evaluations
        WHERE department_id = ?
    """, (department_id,))
    avg_score, course_count = cursor.fetchone()

    cursor.execute("""
        SELECT letter_grade, COUNT(*)
        FROM Evaluations
        WHERE department_id = ?
        GROUP BY letter_grade
    """, (department_id,))
    grade_distribution = {lg: cnt for lg, cnt in cursor.fetchall()}

    # 2. Collect qualitative comments
    cursor.execute("""
        SELECT comment_text
        FROM FeedbackCorpus
        WHERE department_id = ?
    """, (department_id,))
    comments = [r[0] for r in cursor.fetchall() if r[0]]

    # 3. Sentiment analysis (reuse your analyze_feedback function)
    sentiment_summary = analyze_feedback(comments) if comments else None

    # 4. Build baseline narrative
    report_lines = []
    report_lines.append(f"Department ID {department_id} — Baseline Sentiment Report")
    report_lines.append(f"Average score: {avg_score:.2f} across {course_count} courses.")
    report_lines.append("Grade distribution:")
    for lg, cnt in grade_distribution.items():
        report_lines.append(f"  - {lg}: {cnt} courses")

    if sentiment_summary:
        report_lines.append(
            f"Open-ended sentiment: {sentiment_summary['pos_pct']:.0%} positive, "
            f"{sentiment_summary['neu_pct']:.0%} neutral, "
            f"{sentiment_summary['neg_pct']:.0%} negative."
        )
    else:
        report_lines.append("No qualitative comments available for this department.")

    return "\n".join(report_lines)

# %%
# gotta tun a pragma check on the db
cursor.execute("PRAGMA table_info(FeedbackCorpus)")
print(cursor.fetchall())
# Out:
# [(0, 'feedback_id', 'INTEGER', 0, None, 1), (1, 'faculty_id', 'INTEGER', 0, None, 0), (2, 'instructor', 'TEXT', 0, None, 0), (3, 'course_code', 'TEXT', 0, None, 0), (4, 'section_code', 'TEXT', 0, None, 0), (5, 'semester', 'TEXT', 0, None, 0), (6, 'comment_type', 'TEXT', 0, None, 0), (7, 'comment_text', 'TEXT', 0, None, 0)]

# %%
# ayt lets now test out the function by testing out chandaria as our baseline
# Example baseline test for meso-level reporting

# Pick a department_id that exists in your Evaluations/FeedbackCorpus tables
test_department_id = "School of Scie and Tech"   # replace with a real ID from your DB

# The baseline meso sentiment report
print("=== Baseline Meso-Level Sentiment Report ===")
print(generate_meso_sentiment_report(test_department_id, cursor))
# Out:
# === Baseline Meso-Level Sentiment Report ===
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[65], line 9
#       7 # The baseline meso sentiment report
#       8 print("=== Baseline Meso-Level Sentiment Report ===")
# ----> 9 print(generate_meso_sentiment_report(test_department_id, cursor))
#
# Cell In[64], line 9, in generate_meso_sentiment_report(department_id, cursor)
#       3 """
#       4 Baseline meso-level report: aggregate numeric and qualitative sentiment
#       5 for a given department.
#       6 """
#       8 # 1. Aggregate numeric evaluations
# ----> 9 cursor.execute("""
#      10     SELECT AVG(mean_score), COUNT(*)
#      11     FROM Evaluations
#      12     WHERE department_id = ?
#      13 """, (department_id,))
#      14 avg_score, course_count = cursor.fetchone()
#      16 cursor.execute("""
#      17     SELECT letter_grade, COUNT(*)
#      18     FROM Evaluations
#      19     WHERE department_id = ?
#      20     GROUP BY letter_grade
#      21 """, (department_id,))
#
# OperationalError: no such column: department_id
